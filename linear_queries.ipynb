# %%
# This code creates a (k, lambda, eta, beta)- base synopsis generator that is (epsilon,delta)-DP 



import numpy as np
import math
import sympy as sp
from itertools import combinations
import pandas as pd
import time
import copy


lower_bound = -1 # data lower bound
upper_bound = 1  # data upper bound
data_precision = 2 # data precision

n = 100
num_points = 2*n # number of data points
m = num_points*math.ceil(math.log2(((upper_bound - lower_bound)/10**(-data_precision)) +1)) # size of the domain universe

epsilon = 50
delta =  0.5 # DP parameter
eta = 0.001 # edge for boosting
beta = 0.4 # failure probability of the base synopsis

############## This line needs to be changed to k = # queries needed for generalization #####################
k = math.ceil(2*((math.log(2/beta)+m)/(1-2*eta))) # number of query sample as demanded by Lemma 6.5 
# k = 1000
#######################################################################################################

# Assume coefficient \in (0,1], changing one x_i can at most change 1*[(1+x_j)^2 - (-1+x_j)^2] = 4x_j <= 4.

# consider the following query:
# q(X) = (c_1x_1 + ... + c_nx_n)/n
rho = (upper_bound-lower_bound)/num_points # l_1 sensitivity 




# Llambda = 0.01 # parameter lambda, the amount of query output error tolerated 
# epsilon = (math.log(2*k/beta)*4*rho*math.sqrt(2*k*math.log(1/delta)))/Llambda
# epsilon = round(epsilon,2)+10**(-data_precision) # round epsilon up to 2 decimal points 

Llambda = (math.log(2*k/beta)*4*rho*math.sqrt(2*k*math.log(1/delta)))/epsilon
Llambda = round(Llambda,2)+10**(-data_precision) # round epsilon up to 2 decimal points 

# to study just one query, set k=1
# k = 2

tau = 0.001 # total loss stopping criterion

# %%
print(k)
print(epsilon)
print(Llambda)
# Out:
# 3210
# 50
# 0.53

# %%
import random 
# decide on a set of real data 
real_X = np.random.choice(np.arange(lower_bound, upper_bound+0.01, 0.01), num_points, replace=False)
# sum_real_X_squared = np.sum(np.square(real_X))

# initialize the synopsis to be some arbirary set of data, say from the standard normal
# for verification purposes, if fake_X = real_X, the initial error should be the same as the added laplace noise
# fake_X = real_X 
fake_X = np.random.randn(num_points)
# fake_X = np.ones(num_points)*(-0.9)


# fake_X_normalizer = np.max(np.abs(fake_X))
# for idx, i in enumerate(fake_X):
#     if np.abs(i)>=1 :
#         fake_X[idx] = i/fake_X_normalizer
# # fake_X = np.random.uniform(low=lower_bound, high=upper_bound, size=num_points)

fake_X_copy = copy.copy(fake_X) # save a copy of fake_X
fake_X_original = copy.copy(fake_X)
# sum_fake_X_squared = np.sum(np.square(fake_X_copy))



all_coeff = np.round(1-np.linspace(0,100,100, endpoint=False)/100,2)
# sampled_queries = np.array(random.sample(list(all_coeff),k))
sampled_queries = np.random.choice(all_coeff, size=(k, num_points), replace=True)

# %%
# np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=2).reshape(-1,1)
sampled_queries.shape
# Out:
# (3210, 200)

# %%
# fake_X = copy.copy(fake_X_original)



#### BOOSTING LOOP STARTS ####

# initialize all-zero arrays to store noiselss query output, noisy output, and laplace noise  
real_output = np.zeros(k)
real_data_noisy_output = np.zeros(k)
lap_noise = np.zeros(k)
fake_output = np.zeros(k)
error = np.zeros(k) # store |q(X) - noisy_output| for each q



# # for each query, compute its real output, noisy output, and initial error
real_output = np.dot(sampled_queries, real_X.reshape(-1,1))/num_points
lap_noise = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=k).reshape(-1,1)

# save a copy of lap_noise
lap_noise_copy = copy.copy(lap_noise)
lap_noise_copy = copy.copy(lap_noise) 

real_data_noisy_output = real_output+lap_noise

fake_output = np.dot(sampled_queries, fake_X.reshape(-1,1))/num_points

error = abs(fake_output - real_data_noisy_output)






# for index, item in enumerate(sampled_queries):
    
#     # real output 
#     real_output[index] = item*sum_real_X_squared/num_points # quadratic query
#     # real_output[index] = item*np.sum(real_X)/num_points # linear query

    
#     # # compute noisy output on the real data
#     # k_actual = math.ceil(2*((math.log(2/beta)+m)/(1-2*eta))) # number of query sample as demanded by Lemma 6.5 
#     # lap_noise[index] = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=None) 
#     # artificially tune the lap noise down by a half
#     lap_noise[index] = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=None)
#     # lap_noise[index] = 0


#     real_data_noisy_output[index] = real_output[index] + lap_noise[index]

#     # # compute query output on fake data 
#     fake_output[index] = item*sum_fake_X_squared/num_points # quadratic query
#     # fake_output[index] = item*np.sum(fake_X)/num_points # linear query

#     # # calculate initial error
#     # # notice that this is |q(X) - real_data_noisy_output|
#     error[index] = abs(fake_output[index]-real_data_noisy_output[index])

# %%
print("# lap noise above lambda/2 = ",sum(abs(lap_noise)>=Llambda/2) )

# calculate total loss on real_X
total_loss_plus = np.sum(np.exp((real_output-real_data_noisy_output)/Llambda-1))
total_loss_minus = np.sum(np.exp((real_data_noisy_output-real_output)/Llambda-1))
total_loss = total_loss_plus + total_loss_minus 
total_loss_real_X = copy.copy(total_loss)
print("Total loss of real_output: ", total_loss_real_X)
print("# queries = ", k, "# queries above lambda/2 error = ",sum(error>Llambda/2))
# Out:
# # lap noise above lambda/2 =  [1]
# Total loss of real_output:  2367.904014077962
# # queries =  3210 # queries above lambda/2 error =  [1]

# %%
# query_grad_wrt_xi_array = sampled_queries[:,0].reshape(-1,1)/num_points
# aaa = query_grad_wrt_xi_array*np.exp((fake_output-real_data_noisy_output)/Llambda - 1)/Llambda
# aaa

# %%
## NON-STOCHASTIC 
#### COORDINATE DESCENT LOOP STARTS HERE ###
#### In this loop, we do coordinate descent, NOT multivariate Newton's method ####

# initialize number of coordinate descent iterations = 0
num_iter_descent = 0

x_coord_changed = np.full(num_points, False, dtype=bool)
x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}


# while we don't have |q(X) - noisy_output|<lambda/2 for all q, continue coordinate descent 
# while not np.all(error < Llambda/2) and sum(error>Llambda/2)>sum(abs(lap_noise)>=Llambda/2) :
while (num_iter_descent == 0 or  total_loss_update > tau) :
    
    # calculate the current total loss, which includes two copies of loss for each query function
    total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
    total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
    total_loss = total_loss_plus + total_loss_minus 

    ### compute the partial derivative of the loss function with respect to each coordinate 
    loss_gradient = np.zeros(num_points) # initialize the partial derivative of each coordinate to be zero
    
    # fix xi    
    for i in range(num_points):
        xi = fake_X[i]

        # calculate the dq_j/dx_i for all j = 1, ..., k
        query_grad_wrt_xi_array = sampled_queries[:,i].reshape(-1,1)/num_points
        loss_gradient_plus = np.sum(query_grad_wrt_xi_array*np.exp((fake_output-real_data_noisy_output)/Llambda - 1)/Llambda)
        loss_gradient_minus = np.sum(-query_grad_wrt_xi_array*np.exp(-(fake_output-real_data_noisy_output)/Llambda - 1)/Llambda)
        loss_gradient[i] = loss_gradient_plus + loss_gradient_minus

    # create a dictionary for loss_gradient
    loss_gradient_dict = {i: loss_gradient[i] for i in range(len(loss_gradient))}


    # find the coordinate with the max absolute value part_derivative 
    filtered_loss_grad_dict = {k: v for k, v in loss_gradient_dict.items() if not x_coord_changed[k]}
    x_coord_descent = max(filtered_loss_grad_dict, key=lambda k: abs(filtered_loss_grad_dict[k]))

    
        

    # update x value at the coordinate x_coord_descent
    # First, we calculate the 2nd derivative wrt x_coord_descent
    xi = fake_X[x_coord_descent] 
    # quadratic query
    query_grad_wrt_x_coord_descent = sampled_queries[:,x_coord_descent].reshape(-1,1)/num_points
    loss_hessian_wrt_chosen_xi_plus = np.sum((query_grad_wrt_x_coord_descent/num_points)**2*np.exp((fake_output-real_data_noisy_output)/Llambda -1))
    loss_hessian_wrt_chosen_xi_minus = np.sum((query_grad_wrt_x_coord_descent/num_points)**2*np.exp(-(fake_output-real_data_noisy_output)/Llambda -1))
    loss_hessian_wrt_chosen_x_coord = loss_hessian_wrt_chosen_xi_plus + loss_hessian_wrt_chosen_xi_minus
    # loss_hessian_wrt_chosen_x_coord = sampled_queries/num_points # linear queries

    
    ### Backtracking Line Search Sub-routine ###
    # Backtracking line search 
    # initialize a step size, constants alpha1 and alpha2
    t = 1
    alpha1 = 0.05 # usually 0 < alpha1 < 0.5
    alpha2 = 0.5 # usually 0 < alpha2 < 1

    # initialize AG_condition = 0
    AG_condition = 0

    # make a copy of the curent fake_X
    fake_X_copy_linesearch = copy.copy(fake_X)

    while AG_condition == 0: 

        # calculate f(x+t*Delta x)
        fake_X_copy_linesearch[x_coord_descent] = xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord

        # update fake_output 
        fake_output_linesearch = np.dot(sampled_queries, fake_X_copy_linesearch.reshape(-1,1))/num_points

        
        # fake_output_linesearch = sampled_queries*np.sum(fake_X_copy_linesearch) /num_points
        # loss_current_stepsize = np.sum(np.square(fake_output_linesearch-real_data_noisy_output))/Llambda
        loss_current_stepsize_plus = np.sum(np.exp((fake_output_linesearch-real_data_noisy_output)/Llambda-1))
        loss_current_stepsize_minus = np.sum(np.exp((real_data_noisy_output-fake_output_linesearch)/Llambda-1))
        loss_current_stepsize = loss_current_stepsize_plus + loss_current_stepsize_minus 

        # print('loss_current', loss_current_stepsize)

        # calculate f(x)+alpha1*t*grad_f*Delta x
        loss_damped_stepsize = total_loss + alpha1*t*loss_gradient[x_coord_descent]*(- loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord)
        # print('loss_dampened', loss_damped_stepsize)
        
        # if loss_current_stepsize > loss_damped_stepsize or -1>xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord or xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord>1:
        if loss_current_stepsize > loss_damped_stepsize:
            t = t* alpha2
            
            
            # print("t = ", t)

        else: 
            AG_condition = 1 
            print("t = ", t)
    ############



    # update fake_X at coordinate = x_coord_descent using 2nd order Newton's method 
    xi_update = - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
    fake_X[x_coord_descent] = xi + xi_update

    # if fake_X[x_coord_descent] <= 3*lower_bound or fake_X[x_coord_descent] >= 3*upper_bound:
    #     x_coord_changed[x_coord_descent] = True 
        
    # if xi+xi_update <= 1 and xi+xi_update >= -1:
    #     fake_X[x_coord_descent] = xi + xi_update
    # # if the proposed update will overshoot, we skip this coordinate 
    # else:
    #     x_coord_changed[x_coord_descent] = True
    

    # update fake_output
    fake_output = np.dot(sampled_queries, fake_X.reshape(-1,1))/num_points 


    # update error
    error = abs(fake_output-real_data_noisy_output)

    # update total loss
    total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
    total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
    total_loss_after = total_loss_plus + total_loss_minus 

    total_loss_update = total_loss-total_loss_after 

    # print current progress
    print(f"#iter {num_iter_descent} x_co={x_coord_descent}, 1st={loss_gradient[x_coord_descent]}, 2nd={loss_hessian_wrt_chosen_x_coord}, # queries above err={sum(error>Llambda/2)}, xi={xi} fake x={fake_X[x_coord_descent]}")
    print('Total loss = ', total_loss,"; Total_loss - Total_loss_real_X = ", total_loss-total_loss_real_X, "Total_loss_update = ", total_loss_update)
    
    num_iter_descent += 1
# Out:
# t =  7.62939453125e-06
# #iter 0 x_co=32, 1st=0.9322310675984387, 2nd=5.124050596379145e-07, # queries above err=[1], xi=1.4905502712853342 fake x=-12.38979395096483
# Total loss =  2377.4709972402984 ; Total_loss - Total_loss_real_X =  9.566983162336328 Total_loss_update =  5.924406845565954
# t =  7.62939453125e-06
# #iter 1 x_co=56, 1st=0.17908902727237752, 2nd=5.010618484518601e-07, # queries above err=[1], xi=2.6442368200275395 fake x=-0.08265378140293711
# Total loss =  2371.5465903947324 ; Total_loss - Total_loss_real_X =  3.6425763167703735 Total_loss_update =  0.2231038482113945
# /tmp/ipykernel_2131686/2955271590.py:81: RuntimeWarning: overflow encountered in exp
#   loss_current_stepsize_minus = np.sum(np.exp((real_data_noisy_output-fake_output_linesearch)/Llambda-1))
# /tmp/ipykernel_2131686/2955271590.py:80: RuntimeWarning: overflow encountered in exp
#   loss_current_stepsize_plus = np.sum(np.exp((fake_output_linesearch-real_data_noisy_output)/Llambda-1))
# t =  7.62939453125e-06
# #iter 2 x_co=32, 1st=-0.22561027642678688, 2nd=5.108770611288545e-07, # queries above err=[1], xi=-12.38979395096483 fake x=-9.020549292845043
# Total loss =  2371.323486546521 ; Total_loss - Total_loss_real_X =  3.419472468558979 Total_loss_update =  0.3473118706015157
# t =  7.62939453125e-06
# #iter 3 x_co=195, 1st=0.21352214226636868, 2nd=4.992764827203374e-07, # queries above err=[1], xi=1.8034311779353438 fake x=-1.4593795509655478
# Total loss =  2370.9761746759195 ; Total_loss - Total_loss_real_X =  3.0721605979574633 Total_loss_update =  0.3182881844477379
# t =  7.62939453125e-06
# #iter 4 x_co=32, 1st=-0.15523698125371954, 2nd=5.106973484762224e-07, # queries above err=[1], xi=-9.020549292845043 fake x=-6.701437632370014
# Total loss =  2370.657886491472 ; Total_loss - Total_loss_real_X =  2.7538724135097254 Total_loss_update =  0.1644697399292454
# t =  7.62939453125e-06
# #iter 5 x_co=198, 1st=0.1583598828281172, 2nd=5.04732368904358e-07, # queries above err=[1], xi=2.3729166931704055 fake x=-0.02080738408838556
# Total loss =  2370.4934167515426 ; Total_loss - Total_loss_real_X =  2.58940267358048 Total_loss_update =  0.17317115683363227
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# t =  7.62939453125e-06
# #iter 6 x_co=32, 1st=-0.11736339855306888, 2nd=5.106111416130139e-07, # queries above err=[1], xi=-6.701437632370014 fake x=-4.947829851190184
# Total loss =  2370.320245594709 ; Total_loss - Total_loss_real_X =  2.4162315167468478 Total_loss_update =  0.09401787148135554
# t =  7.62939453125e-06
# #iter 7 x_co=28, 1st=0.1226918160752053, 2nd=4.902700044924061e-07, # queries above err=[1], xi=1.9834512377289708 fake x=0.07416806311900759
# Total loss =  2370.2262277232276 ; Total_loss - Total_loss_real_X =  2.3222136452654922 Total_loss_update =  0.10701069673405073
# t =  7.62939453125e-06
# #iter 8 x_co=32, 1st=-0.09319461734845902, 2nd=5.105568992995002e-07, # queries above err=[1], xi=-4.947829851190184 fake x=-3.555196620857171
# Total loss =  2370.1192170264935 ; Total_loss - Total_loss_real_X =  2.2152029485314415 Total_loss_update =  0.05928716296239145
# t =  7.62939453125e-06
# #iter 9 x_co=101, 1st=0.09602320058062563, 2nd=5.111620296906996e-07, # queries above err=[1], xi=2.166339198123594 fake x=0.7331363410447198
# Total loss =  2370.059929863531 ; Total_loss - Total_loss_real_X =  2.15591578556905 Total_loss_update =  0.06286630597787735
# t =  7.62939453125e-06
# #iter 10 x_co=148, 1st=-0.09098649470754694, 2nd=5.011371851933134e-07, # queries above err=[1], xi=-2.8044239200305223 fake x=-1.419230632345057
# Total loss =  2369.9970635575532 ; Total_loss - Total_loss_real_X =  2.0930494795911727 Total_loss_update =  0.05757300702680368
# t =  7.62939453125e-06
# #iter 11 x_co=51, 1st=0.08759463003216794, 2nd=4.90766045105917e-07, # queries above err=[1], xi=1.0942515837908535 fake x=-0.26748482401229445
# Total loss =  2369.9394905505264 ; Total_loss - Total_loss_real_X =  2.035476472564369 Total_loss_update =  0.05448808223945889
# t =  7.62939453125e-06
# #iter 12 x_co=109, 1st=-0.08317079052675957, 2nd=4.880404698462964e-07, # queries above err=[1], xi=-1.0813026819629643 fake x=0.21888206420048784
# Total loss =  2369.885002468287 ; Total_loss - Total_loss_real_X =  1.9809883903249101 Total_loss_update =  0.04939767443011078
# t =  7.62939453125e-06
# #iter 13 x_co=142, 1st=0.07983702536559889, 2nd=4.9883613013477e-07, # queries above err=[1], xi=1.483288163717188 fake x=0.26222952758550755
# Total loss =  2369.835604793857 ; Total_loss - Total_loss_real_X =  1.9315907158947994 Total_loss_update =  0.04453147327649276
# t =  7.62939453125e-06
# #iter 14 x_co=144, 1st=-0.07922621979410849, 2nd=5.19869889268601e-07, # queries above err=[1], xi=-1.7006393519740464 fake x=-0.5379482623262637
# Total loss =  2369.7910733205804 ; Total_loss - Total_loss_real_X =  1.8870592426183066 Total_loss_update =  0.042078552777184086
# t =  7.62939453125e-06
# #iter 15 x_co=71, 1st=0.07510650204832192, 2nd=4.920774058596576e-07, # queries above err=[1], xi=3.263741032148143 fake x=2.099255263922867
# Total loss =  2369.748994767803 ; Total_loss - Total_loss_real_X =  1.8449806898411225 Total_loss_update =  0.03995204934835783
# t =  7.62939453125e-06
# #iter 16 x_co=23, 1st=-0.07391161273731495, 2nd=5.097545725652245e-07, # queries above err=[1], xi=-2.7606575999936545 fake x=-1.6544373042614648
# Total loss =  2369.709042718455 ; Total_loss - Total_loss_real_X =  1.8050286404927647 Total_loss_update =  0.0373492255534984
# t =  7.62939453125e-06
# #iter 17 x_co=55, 1st=0.07308072633873408, 2nd=5.020274054469903e-07, # queries above err=[1], xi=2.0757154121327233 fake x=0.9650953786067065
# Total loss =  2369.6716934929013 ; Total_loss - Total_loss_real_X =  1.7676794149392663 Total_loss_update =  0.03707611893833018
# t =  7.62939453125e-06
# #iter 18 x_co=119, 1st=-0.07259685706704122, 2nd=4.894253838194138e-07, # queries above err=[1], xi=-1.2452122764660287 fake x=-0.11353810793212427
# Total loss =  2369.634617373963 ; Total_loss - Total_loss_real_X =  1.730603296000936 Total_loss_update =  0.03752891238218581
# t =  7.62939453125e-06
# #iter 19 x_co=194, 1st=0.07271649641099476, 2nd=5.015264675557783e-07, # queries above err=[1], xi=1.3426539094785426 fake x=0.23646535126849688
# Total loss =  2369.597088461581 ; Total_loss - Total_loss_real_X =  1.6930743836187503 Total_loss_update =  0.036744079556228826
# t =  7.62939453125e-06
# #iter 20 x_co=149, 1st=-0.06945212554146973, 2nd=4.915627447871542e-07, # queries above err=[1], xi=-1.3229272082491406 fake x=-0.24498207833655194
# Total loss =  2369.5603443820246 ; Total_loss - Total_loss_real_X =  1.6563303040625215 Total_loss_update =  0.03419859602536235
# t =  7.62939453125e-06
# #iter 21 x_co=68, 1st=0.07011816461484877, 2nd=4.96615687726118e-07, # queries above err=[1], xi=0.4868717369496372 fake x=-0.5903377730907358
# Total loss =  2369.5261457859992 ; Total_loss - Total_loss_real_X =  1.6221317080371591 Total_loss_update =  0.034502962530950754
# t =  7.62939453125e-06
# #iter 22 x_co=47, 1st=-0.06414221860298497, 2nd=4.978743053178999e-07, # queries above err=[1], xi=-1.318024857108419 fake x=-0.33511353470268024
# Total loss =  2369.4916428234683 ; Total_loss - Total_loss_real_X =  1.5876287455062084 Total_loss_update =  0.028799404088204028
# t =  7.62939453125e-06
# #iter 23 x_co=39, 1st=0.06374393093303521, 2nd=4.92929447849744e-07, # queries above err=[1], xi=1.38165098154049 fake x=0.3950440742389808
# Total loss =  2369.46284341938 ; Total_loss - Total_loss_real_X =  1.5588293414180043 Total_loss_update =  0.028727980235998984
# t =  7.62939453125e-06
# #iter 24 x_co=123, 1st=-0.06343982602749865, 2nd=5.066238980879874e-07, # queries above err=[1], xi=-1.1655146809238006 fake x=-0.21015615246845698
# Total loss =  2369.434115439144 ; Total_loss - Total_loss_real_X =  1.5301013611820053 Total_loss_update =  0.02768545005528722
# t =  7.62939453125e-06
# #iter 25 x_co=114, 1st=0.061199240639469465, 2nd=4.938862130064579e-07, # queries above err=[1], xi=1.8996798562621715 fake x=0.9542937742957249
# Total loss =  2369.406429989089 ; Total_loss - Total_loss_real_X =  1.5024159111267181 Total_loss_update =  0.026428767072502524
# t =  7.62939453125e-06
# #iter 26 x_co=32, 1st=-0.0606738463612535, 2nd=5.103831214084332e-07, # queries above err=[1], xi=-3.555196620857171 fake x=-2.648221659888563
# Total loss =  2369.3800012220163 ; Total_loss - Total_loss_real_X =  1.4759871440542156 Total_loss_update =  0.025137363079466013
# t =  7.62939453125e-06
# #iter 27 x_co=31, 1st=0.059918150795962966, 2nd=5.059869528289744e-07, # queries above err=[1], xi=1.05950877956453 fake x=0.1560483060296569
# Total loss =  2369.354863858937 ; Total_loss - Total_loss_real_X =  1.4508497809747496 Total_loss_update =  0.024728122637952765
# t =  7.62939453125e-06
# #iter 28 x_co=164, 1st=-0.05953196738626598, 2nd=4.937857879065553e-07, # queries above err=[1], xi=-2.0269345807217922 fake x=-1.1071169643887697
# Total loss =  2369.330135736299 ; Total_loss - Total_loss_real_X =  1.4261216583367968 Total_loss_update =  0.025013469116856868
# t =  7.62939453125e-06
# #iter 29 x_co=42, 1st=0.05852410664334062, 2nd=5.137791385499806e-07, # queries above err=[1], xi=1.015939572838969 fake x=0.1468822957546082
# Total loss =  2369.305122267182 ; Total_loss - Total_loss_real_X =  1.40110818921994 Total_loss_update =  0.023233041379171482
# t =  7.62939453125e-06
# #iter 30 x_co=138, 1st=-0.057683623575917053, 2nd=4.959723009290574e-07, # queries above err=[1], xi=-1.3355521651140922 fake x=-0.44822212384282645
# Total loss =  2369.281889225803 ; Total_loss - Total_loss_real_X =  1.3778751478407685 Total_loss_update =  0.023380890984299185
# t =  7.62939453125e-06
# #iter 31 x_co=9, 1st=0.057070968521275134, 2nd=4.951321781119407e-07, # queries above err=[1], xi=1.1553792266966227 fake x=0.2759838765707069
# Total loss =  2369.2585083348185 ; Total_loss - Total_loss_real_X =  1.3544942568564693 Total_loss_update =  0.022925599840164068
# t =  7.62939453125e-06
# #iter 32 x_co=65, 1st=-0.05635022813805435, 2nd=5.021482244836815e-07, # queries above err=[1], xi=-1.4488353733956745 fake x=-0.592677566936811
# Total loss =  2369.2355827349784 ; Total_loss - Total_loss_real_X =  1.3315686570163052 Total_loss_update =  0.022037969506527588
# t =  7.62939453125e-06
# #iter 33 x_co=168, 1st=0.0556844492690276, 2nd=4.86788441098128e-07, # queries above err=[1], xi=1.6693540823219422 fake x=0.7966163653572387
# Total loss =  2369.213544765472 ; Total_loss - Total_loss_real_X =  1.3095306875097776 Total_loss_update =  0.02219936698293168
# t =  7.62939453125e-06
# #iter 34 x_co=110, 1st=-0.05592286241659217, 2nd=4.947462622343056e-07, # queries above err=[1], xi=-1.7910099331114613 fake x=-0.9286333711013075
# Total loss =  2369.191345398489 ; Total_loss - Total_loss_real_X =  1.287331320526846 Total_loss_update =  0.02202965719607164
# t =  7.62939453125e-06
# #iter 35 x_co=115, 1st=0.054393920581163435, 2nd=4.94858381400413e-07, # queries above err=[1], xi=1.751630221774024 fake x=0.9130212463318457
# Total loss =  2369.169315741293 ; Total_loss - Total_loss_real_X =  1.2653016633307743 Total_loss_update =  0.02083687859794736
# t =  7.62939453125e-06
# #iter 36 x_co=106, 1st=-0.05465022449453816, 2nd=4.909522508173913e-07, # queries above err=[1], xi=-0.7773979198223826 fake x=0.07186618518178667
# Total loss =  2369.148478862695 ; Total_loss - Total_loss_real_X =  1.244464784732827 Total_loss_update =  0.021201018848842068
# t =  7.62939453125e-06
# #iter 37 x_co=63, 1st=0.05534899431499163, 2nd=4.907596870116495e-07, # queries above err=[1], xi=1.3508482070047645 fake x=0.49038772968165345
# Total loss =  2369.127277843846 ; Total_loss - Total_loss_real_X =  1.2232637658839849 Total_loss_update =  0.02175519905404144
# t =  7.62939453125e-06
# #iter 38 x_co=148, 1st=-0.05281410483500082, 2nd=5.009361544014048e-07, # queries above err=[1], xi=-1.419230632345057 fake x=-0.6148573822598972
# Total loss =  2369.105522644792 ; Total_loss - Total_loss_real_X =  1.2015085668299434 Total_loss_update =  0.019405659213589388
# t =  7.62939453125e-06
# #iter 39 x_co=2, 1st=0.051461237997475706, 2nd=4.92660727906085e-07, # queries above err=[1], xi=1.134958768815666 fake x=0.3380247622874657
# Total loss =  2369.0861169855784 ; Total_loss - Total_loss_real_X =  1.182102907616354 Total_loss_update =  0.018733751118361397
# t =  7.62939453125e-06
# #iter 40 x_co=72, 1st=-0.051765144831043663, 2nd=5.071497023142362e-07, # queries above err=[1], xi=-0.9633521423796954 fake x=-0.1846142054724168
# Total loss =  2369.06738323446 ; Total_loss - Total_loss_real_X =  1.1633691564979927 Total_loss_update =  0.018414039523122483
# t =  7.62939453125e-06
# #iter 41 x_co=143, 1st=0.05070441986896501, 2nd=5.04434875367779e-07, # queries above err=[1], xi=-0.2367158065078426 fake x=-1.003601766516934
# Total loss =  2369.048969194937 ; Total_loss - Total_loss_real_X =  1.1449551169748702 Total_loss_update =  0.017762194392616948
# t =  7.62939453125e-06
# #iter 42 x_co=151, 1st=-0.05089117844425317, 2nd=5.03767344022932e-07, # queries above err=[1], xi=-0.8083994868698058 fake x=-0.037668944054432996
# Total loss =  2369.0312070005443 ; Total_loss - Total_loss_real_X =  1.1271929225822532 Total_loss_update =  0.01791704514516823
# t =  7.62939453125e-06
# #iter 43 x_co=86, 1st=0.05054705274561577, 2nd=5.055485735875037e-07, # queries above err=[1], xi=0.6902971065229507 fake x=-0.07252456469961976
# Total loss =  2369.013289955399 ; Total_loss - Total_loss_real_X =  1.109275877437085 Total_loss_update =  0.017613224061278743
# t =  7.62939453125e-06
# #iter 44 x_co=191, 1st=-0.05017051510218007, 2nd=5.084853989133145e-07, # queries above err=[1], xi=-0.9977967997141092 fake x=-0.24503053667373798
# Total loss =  2368.995676731338 ; Total_loss - Total_loss_real_X =  1.0916626533758063 Total_loss_update =  0.01725159768557205
# t =  7.62939453125e-06
# #iter 45 x_co=97, 1st=0.05030293313232548, 2nd=5.041807132011074e-07, # queries above err=[1], xi=0.5578420673580468 fake x=-0.2033550845697304
# Total loss =  2368.9784251336523 ; Total_loss - Total_loss_real_X =  1.0744110556902342 Total_loss_update =  0.017490877405180072
# t =  7.62939453125e-06
# #iter 46 x_co=79, 1st=-0.05003058369413704, 2nd=4.87842014382421e-07, # queries above err=[1], xi=-1.1331055114104631 fake x=-0.3506738011886448
# Total loss =  2368.960934256247 ; Total_loss - Total_loss_real_X =  1.0569201782850541 Total_loss_update =  0.01788151497476065
# t =  7.62939453125e-06
# #iter 47 x_co=112, 1st=0.04871510415596436, 2nd=5.115578478984383e-07, # queries above err=[1], xi=1.2685468503508206 fake x=0.5420078073791308
# Total loss =  2368.9430527412724 ; Total_loss - Total_loss_real_X =  1.0390386633102935 Total_loss_update =  0.016167477398084884
# t =  7.62939453125e-06
# #iter 48 x_co=53, 1st=-0.048412627260219665, 2nd=5.026905512815532e-07, # queries above err=[1], xi=-0.4833556445363879 fake x=0.25140858113072506
# Total loss =  2368.9268852638743 ; Total_loss - Total_loss_real_X =  1.0228711859122086 Total_loss_update =  0.01624904859545495
# t =  7.62939453125e-06
# #iter 49 x_co=101, 1st=0.04783339246359741, 2nd=5.108965005170194e-07, # queries above err=[1], xi=0.7331363410447198 fake x=0.018823711180174785
# Total loss =  2368.910636215279 ; Total_loss - Total_loss_real_X =  1.0066221373167537 Total_loss_update =  0.015607757221914653
# t =  7.62939453125e-06
# #iter 50 x_co=18, 1st=-0.04756612265197724, 2nd=4.918631348856223e-07, # queries above err=[1], xi=-0.9944033752043425 fake x=-0.2565950494835082
# Total loss =  2368.895028458057 ; Total_loss - Total_loss_real_X =  0.991014380094839 Total_loss_update =  0.016031056509291375
# t =  7.62939453125e-06
# #iter 51 x_co=136, 1st=0.048077901207149054, 2nd=5.010626657936928e-07, # queries above err=[1], xi=0.71806497611609 fake x=-0.013989718006399143
# Total loss =  2368.8789974015476 ; Total_loss - Total_loss_real_X =  0.9749833235855476 Total_loss_update =  0.01607712749591883
# t =  7.62939453125e-06
# #iter 52 x_co=23, 1st=-0.04639461086354668, 2nd=5.095800149432765e-07, # queries above err=[1], xi=-1.6544373042614648 fake x=-0.9598206002660855
# Total loss =  2368.8629202740517 ; Total_loss - Total_loss_real_X =  0.9589061960896288 Total_loss_update =  0.01472087196452776
# t =  7.62939453125e-06
# #iter 53 x_co=121, 1st=0.04596942635802659, 2nd=4.964474717237465e-07, # queries above err=[1], xi=1.4992745526034306 fake x=0.7928173541351323
# Total loss =  2368.848199402087 ; Total_loss - Total_loss_real_X =  0.944185324125101 Total_loss_update =  0.014834550260729884
# t =  7.62939453125e-06
# #iter 54 x_co=87, 1st=-0.04578126636527102, 2nd=4.918832521830762e-07, # queries above err=[1], xi=-0.7039485657590985 fake x=0.006145428477763559
# Total loss =  2368.8333648518264 ; Total_loss - Total_loss_real_X =  0.9293507738643711 Total_loss_update =  0.014849923017209221
# t =  7.62939453125e-06
# #iter 55 x_co=100, 1st=0.04565415838492726, 2nd=5.063063585814872e-07, # queries above err=[1], xi=0.9352752768259117 fake x=0.2473250261384592
# Total loss =  2368.8185149288092 ; Total_loss - Total_loss_real_X =  0.9145008508471619 Total_loss_update =  0.01434687182700145
# t =  7.62939453125e-06
# #iter 56 x_co=109, 1st=-0.045388921112748726, 2nd=4.878032200519628e-07, # queries above err=[1], xi=0.21888206420048784 fake x=0.9287789494241127
# Total loss =  2368.8041680569822 ; Total_loss - Total_loss_real_X =  0.9001539790201605 Total_loss_update =  0.014718563802034623
# t =  7.62939453125e-06
# #iter 57 x_co=21, 1st=0.04572411913907182, 2nd=4.935843767945911e-07, # queries above err=[1], xi=0.01676372359635138 fake x=-0.6899996200315881
# Total loss =  2368.78944949318 ; Total_loss - Total_loss_real_X =  0.8854354152181259 Total_loss_update =  0.014761784497295594
# t =  7.62939453125e-06
# #iter 58 x_co=147, 1st=-0.044733982623455404, 2nd=5.01882914315142e-07, # queries above err=[1], xi=-1.6572701160974652 fake x=-0.9772445709877176
# Total loss =  2368.774687708683 ; Total_loss - Total_loss_real_X =  0.8706736307208303 Total_loss_update =  0.013895763375330716
# t =  7.62939453125e-06
# #iter 59 x_co=28, 1st=0.04481821995735835, 2nd=4.899386302620802e-07, # queries above err=[1], xi=0.07416806311900759 fake x=-0.623747678001711
# Total loss =  2368.7607919453076 ; Total_loss - Total_loss_real_X =  0.8567778673454995 Total_loss_update =  0.014288184047018149
# t =  7.62939453125e-06
# #iter 60 x_co=144, 1st=-0.04533467754719833, 2nd=5.196250758120542e-07, # queries above err=[1], xi=-0.5379482623262637 fake x=0.12767808454326035
# Total loss =  2368.7465037612606 ; Total_loss - Total_loss_real_X =  0.8424896832984814 Total_loss_update =  0.013784170599592471
# t =  7.62939453125e-06
# #iter 61 x_co=142, 1st=0.04219540705028901, 2nd=4.985870518054202e-07, # queries above err=[1], xi=0.26222952758550755 fake x=-0.38344589986016553
# Total loss =  2368.732719590661 ; Total_loss - Total_loss_real_X =  0.8287055126988889 Total_loss_update =  0.012445088817003125
# t =  7.62939453125e-06
# #iter 62 x_co=83, 1st=-0.042049922867550826, 2nd=4.949071179672676e-07, # queries above err=[1], xi=-1.0087166305790665 fake x=-0.3604829723466648
# Total loss =  2368.720274501844 ; Total_loss - Total_loss_real_X =  0.8162604238818858 Total_loss_update =  0.012451337696347764
# t =  7.62939453125e-06
# #iter 63 x_co=159, 1st=0.04211386092760527, 2nd=5.022837983147267e-07, # queries above err=[1], xi=0.9052995078413911 fake x=0.2656148090138791
# Total loss =  2368.7078231641476 ; Total_loss - Total_loss_real_X =  0.803809086185538 Total_loss_update =  0.012305812210342992
# t =  7.62939453125e-06
# #iter 64 x_co=134, 1st=-0.04224070433949745, 2nd=4.943020799003204e-07, # queries above err=[1], xi=0.03793080507215848 fake x=0.6899025684701564
# Total loss =  2368.6955173519373 ; Total_loss - Total_loss_real_X =  0.791503273975195 Total_loss_update =  0.012579962058225647
# t =  7.62939453125e-06
# #iter 65 x_co=145, 1st=0.04082638998598398, 2nd=4.880013754430387e-07, # queries above err=[1], xi=1.438205618438443 fake x=0.7999274246383458
# Total loss =  2368.682937389879 ; Total_loss - Total_loss_real_X =  0.7789233119169694 Total_loss_update =  0.011903377891940181
# t =  7.62939453125e-06
# #iter 66 x_co=135, 1st=-0.040709408753025755, 2nd=5.038056057544021e-07, # queries above err=[1], xi=0.43252104673870995 fake x=1.049005136957751
# Total loss =  2368.671034011987 ; Total_loss - Total_loss_real_X =  0.7670199340250292 Total_loss_update =  0.011463998486760829
# t =  7.62939453125e-06
# #iter 67 x_co=78, 1st=0.040096148750564886, 2nd=4.959136244131863e-07, # queries above err=[1], xi=1.3743710708240229 fake x=0.7575109505485854
# Total loss =  2368.6595700135003 ; Total_loss - Total_loss_real_X =  0.7555559355382684 Total_loss_update =  0.011298197596261161
# t =  7.62939453125e-06
# #iter 68 x_co=94, 1st=-0.04039874417286171, 2nd=5.020648766427449e-07, # queries above err=[1], xi=-1.8899991520291755 fake x=-1.276098494562714
# Total loss =  2368.648271815904 ; Total_loss - Total_loss_real_X =  0.7442577379420072 Total_loss_update =  0.01132881447483669
# t =  7.62939453125e-06
# #iter 69 x_co=105, 1st=0.04028654665136422, 2nd=5.079290252890799e-07, # queries above err=[1], xi=0.6956679544809811 fake x=0.0905401838639428
# Total loss =  2368.6369430014292 ; Total_loss - Total_loss_real_X =  0.7329289234671705 Total_loss_update =  0.01113591279636239
# t =  7.62939453125e-06
# #iter 70 x_co=24, 1st=-0.03987413987637467, 2nd=4.999403386671952e-07, # queries above err=[1], xi=-0.849401652116732 fake x=-0.2408979544112676
# Total loss =  2368.625807088633 ; Total_loss - Total_loss_real_X =  0.7217930106708081 Total_loss_update =  0.011083393030276056
# t =  7.62939453125e-06
# #iter 71 x_co=55, 1st=0.04010369232969335, 2nd=5.017911755534751e-07, # queries above err=[1], xi=0.9650953786067065 fake x=0.35534593332079867
# Total loss =  2368.6147236956026 ; Total_loss - Total_loss_real_X =  0.7107096176405321 Total_loss_update =  0.01117003848639797
# t =  7.62939453125e-06
# #iter 72 x_co=149, 1st=-0.0397461425504364, 2nd=4.913519511741319e-07, # queries above err=[1], xi=-0.24498207833655194 fake x=0.3721702538928493
# Total loss =  2368.603553657116 ; Total_loss - Total_loss_real_X =  0.6995395791541341 Total_loss_update =  0.011204864856154018
# t =  7.62939453125e-06
# #iter 73 x_co=194, 1st=0.03953555022764377, 2nd=5.012921295499814e-07, # queries above err=[1], xi=0.23646535126849688 fake x=-0.3652442964922322
# Total loss =  2368.59234879226 ; Total_loss - Total_loss_real_X =  0.6883347142979801 Total_loss_update =  0.01086658975782484
# t =  7.62939453125e-06
# #iter 74 x_co=0, 1st=-0.03868526909460446, 2nd=4.896819259990555e-07, # queries above err=[1], xi=-0.3080110684340958 fake x=0.2947172839921262
# Total loss =  2368.5814822025022 ; Total_loss - Total_loss_real_X =  0.6774681245401553 Total_loss_update =  0.010650890693341353
# t =  7.62939453125e-06
# #iter 75 x_co=45, 1st=0.03873273912010866, 2nd=5.057198771846345e-07, # queries above err=[1], xi=0.17914283590330546 fake x=-0.4051872672921488
# Total loss =  2368.570831311809 ; Total_loss - Total_loss_real_X =  0.6668172338468139 Total_loss_update =  0.010338430754472938
# t =  7.62939453125e-06
# #iter 76 x_co=119, 1st=-0.03768303730811695, 2nd=4.891861056960601e-07, # queries above err=[1], xi=-0.11353810793212427 fake x=0.4741702415320471
# Total loss =  2368.5604928810544 ; Total_loss - Total_loss_real_X =  0.656478803092341 Total_loss_update =  0.010116412344814307
# t =  7.62939453125e-06
# #iter 77 x_co=68, 1st=0.038059130824954046, 2nd=4.964205155814657e-07, # queries above err=[1], xi=-0.5903377730907358 fake x=-1.1752614727890038
# Total loss =  2368.5503764687096 ; Total_loss - Total_loss_real_X =  0.6463623907475267 Total_loss_update =  0.010168971257826342
# t =  7.62939453125e-06
# #iter 78 x_co=125, 1st=-0.03782524642204255, 2nd=4.920481398314334e-07, # queries above err=[1], xi=-1.620619711241466 fake x=-1.0341248038643576
# Total loss =  2368.540207497452 ; Total_loss - Total_loss_real_X =  0.6361934194897003 Total_loss_update =  0.010133633285477117
# t =  7.62939453125e-06
# #iter 79 x_co=30, 1st=0.0379552699852308, 2nd=5.139959287729797e-07, # queries above err=[1], xi=1.6034519404405072 fake x=1.0400705729096058
# Total loss =  2368.5300738641663 ; Total_loss - Total_loss_real_X =  0.6260597862042232 Total_loss_update =  0.009767709703737637
# t =  7.62939453125e-06
# #iter 80 x_co=196, 1st=-0.03729053540882532, 2nd=4.994502908818375e-07, # queries above err=[1], xi=-0.5168002866688867 fake x=0.05283439391794653
# Total loss =  2368.5203061544626 ; Total_loss - Total_loss_real_X =  0.6162920765004856 Total_loss_update =  0.009703179382995586
# t =  7.62939453125e-06
# #iter 81 x_co=51, 1st=0.03721489323220961, 2nd=4.904550851753098e-07, # queries above err=[1], xi=-0.26748482401229445 fake x=-0.8463902355147256
# Total loss =  2368.5106029750796 ; Total_loss - Total_loss_real_X =  0.60658889711749 Total_loss_update =  0.009841085568950803
# t =  7.62939453125e-06
# #iter 82 x_co=174, 1st=-0.03746551611195148, 2nd=4.808043614048597e-07, # queries above err=[1], xi=-0.958107913679465 fake x=-0.3636058112031286
# Total loss =  2368.5007618895106 ; Total_loss - Total_loss_real_X =  0.5967478115485392 Total_loss_update =  0.01017427806800697
# t =  7.62939453125e-06
# #iter 83 x_co=71, 1st=0.03734588109718828, 2nd=4.918045011628534e-07, # queries above err=[1], xi=2.099255263922867 fake x=1.5199062332940234
# Total loss =  2368.4905876114426 ; Total_loss - Total_loss_real_X =  0.5865735334805322 Total_loss_update =  0.00988329547635658
# t =  7.62939453125e-06
# #iter 84 x_co=95, 1st=-0.03603563237068297, 2nd=5.072768602990617e-07, # queries above err=[1], xi=-0.5641536031611537 fake x=-0.02218120493872955
# Total loss =  2368.4807043159662 ; Total_loss - Total_loss_real_X =  0.5766902380041756 Total_loss_update =  0.008921280594677228
# t =  7.62939453125e-06
# #iter 85 x_co=12, 1st=0.035634001763547474, 2nd=5.070042492778705e-07, # queries above err=[1], xi=2.1990223817627315 fake x=1.6628023035906407
# Total loss =  2368.4717830353716 ; Total_loss - Total_loss_real_X =  0.5677689574094984 Total_loss_update =  0.008728240788059338
# t =  7.62939453125e-06
# #iter 86 x_co=27, 1st=-0.03540093087735219, 2nd=5.036477298697197e-07, # queries above err=[1], xi=-0.4689751969606479 fake x=0.06728785441197432
# Total loss =  2368.4630547945835 ; Total_loss - Total_loss_real_X =  0.5590407166214391 Total_loss_update =  0.008671825959481794
# t =  7.62939453125e-06
# #iter 87 x_co=43, 1st=0.03478040303526253, 2nd=5.063192463701077e-07, # queries above err=[1], xi=-0.11297460882388828 fake x=-0.6370578203831337
# Total loss =  2368.454382968624 ; Total_loss - Total_loss_real_X =  0.5503688906619573 Total_loss_update =  0.0083263250339769
# t =  7.62939453125e-06
# #iter 88 x_co=93, 1st=-0.03454422644702415, 2nd=4.930963334581196e-07, # queries above err=[1], xi=-0.9507348383371078 fake x=-0.416251990953348
# Total loss =  2368.44605664359 ; Total_loss - Total_loss_real_X =  0.5420425656279804 Total_loss_update =  0.008433873579633655
# t =  7.62939453125e-06
# #iter 89 x_co=172, 1st=0.03518951618971666, 2nd=5.017668880299923e-07, # queries above err=[1], xi=0.7552794896613845 fake x=0.22022086227920057
# Total loss =  2368.4376227700104 ; Total_loss - Total_loss_real_X =  0.5336086920483467 Total_loss_update =  0.00860068152724125
# t =  7.62939453125e-06
# #iter 90 x_co=32, 1st=-0.0346131116701649, 2nd=5.101480235660739e-07, # queries above err=[1], xi=-2.648221659888563 fake x=-2.1305736975580793
# Total loss =  2368.429022088483 ; Total_loss - Total_loss_real_X =  0.5250080105211055 Total_loss_update =  0.008184521796920308
# t =  7.62939453125e-06
# #iter 91 x_co=31, 1st=0.03359830386635565, 2nd=5.057808063215021e-07, # queries above err=[1], xi=0.1560483060296569 fake x=-0.35076158587104345
# Total loss =  2368.4208375666863 ; Total_loss - Total_loss_real_X =  0.5168234887241852 Total_loss_update =  0.007778231624797627
# t =  7.62939453125e-06
# #iter 92 x_co=123, 1st=-0.03399600140979242, 2nd=5.063973969514008e-07, # queries above err=[1], xi=-0.21015615246845698 fake x=0.3020283666496959
# Total loss =  2368.4130593350615 ; Total_loss - Total_loss_real_X =  0.5090452570993875 Total_loss_update =  0.007953757573432085
# t =  7.62939453125e-06
# #iter 93 x_co=168, 1st=0.03363330123718011, 2nd=4.866353731578571e-07, # queries above err=[1], xi=0.7966163653572387 fake x=0.2693186416802792
# Total loss =  2368.405105577488 ; Total_loss - Total_loss_real_X =  0.5010914995259554 Total_loss_update =  0.008101100409476203
# t =  7.62939453125e-06
# #iter 94 x_co=88, 1st=-0.03372720251435091, 2nd=5.093095532563909e-07, # queries above err=[1], xi=-1.9726367519314283 fake x=-1.467407402173259
# Total loss =  2368.3970044770786 ; Total_loss - Total_loss_real_X =  0.49299039911647924 Total_loss_update =  0.007783715255300194
# t =  7.62939453125e-06
# #iter 95 x_co=60, 1st=0.03305981192155105, 2nd=4.941355420266195e-07, # queries above err=[1], xi=1.1541871625446267 fake x=0.6437475628267674
# Total loss =  2368.3892207618233 ; Total_loss - Total_loss_real_X =  0.48520668386117904 Total_loss_update =  0.007708385181558697
# t =  7.62939453125e-06
# #iter 96 x_co=138, 1st=-0.03295441615906469, 2nd=4.957793000448894e-07, # queries above err=[1], xi=-0.44822212384282645 fake x=0.05890320874314525
# Total loss =  2368.3815123766417 ; Total_loss - Total_loss_real_X =  0.47749829867962035 Total_loss_update =  0.007633918160081521
# t =  7.62939453125e-06
# #iter 97 x_co=158, 1st=0.03240511670640345, 2nd=5.102851564240909e-07, # queries above err=[1], xi=0.6417904862587603 fake x=0.1572938923996165
# Total loss =  2368.3738784584816 ; Total_loss - Total_loss_real_X =  0.4698643805195388 Total_loss_update =  0.007171699764967343
# t =  7.62939453125e-06
# #iter 98 x_co=177, 1st=-0.03218033555638122, 2nd=4.995346411410013e-07, # queries above err=[1], xi=-1.225526743820528 fake x=-0.7340363527900807
# Total loss =  2368.3667067587166 ; Total_loss - Total_loss_real_X =  0.4626926807545715 Total_loss_update =  0.007224772379686328
# t =  7.62939453125e-06
# #iter 99 x_co=150, 1st=0.032851397488977696, 2nd=4.919596774170531e-07, # queries above err=[1], xi=1.9577352396129355 fake x=1.4482701678772851
# Total loss =  2368.359481986337 ; Total_loss - Total_loss_real_X =  0.45546790837488516 Total_loss_update =  0.00764515297169055
# t =  7.62939453125e-06
# #iter 100 x_co=72, 1st=-0.03295952092754639, 2nd=5.06993675511597e-07, # queries above err=[1], xi=-0.1846142054724168 fake x=0.311370657580358
# Total loss =  2368.3518368333653 ; Total_loss - Total_loss_real_X =  0.4478227554031946 Total_loss_update =  0.00746735640859697
# t =  7.62939453125e-06
# #iter 101 x_co=63, 1st=0.031805842359269754, 2nd=4.905972023707475e-07, # queries above err=[1], xi=0.49038772968165345 fake x=-0.0042325384018017664
# Total loss =  2368.3443694769567 ; Total_loss - Total_loss_real_X =  0.44035539899459764 Total_loss_update =  0.0071861604610603536
# t =  7.62939453125e-06
# #iter 102 x_co=47, 1st=-0.03187487218047558, 2nd=4.976007628359865e-07, # queries above err=[1], xi=-0.33511353470268024 fake x=0.1536035124980077
# Total loss =  2368.3371833164956 ; Total_loss - Total_loss_real_X =  0.4331692385335373 Total_loss_update =  0.007115813997643272
# t =  7.62939453125e-06
# #iter 103 x_co=136, 1st=0.03205500709895315, 2nd=5.009298772565944e-07, # queries above err=[1], xi=-0.013989718006399143 fake x=-0.5022023540729447
# Total loss =  2368.330067502498 ; Total_loss - Total_loss_real_X =  0.426053424535894 Total_loss_update =  0.007148619672534551
# t =  7.62939453125e-06
# #iter 104 x_co=157, 1st=-0.031122179127489602, 2nd=4.97627623086699e-07, # queries above err=[1], xi=-1.3985554495319585 fake x=-0.9214047203119217
# Total loss =  2368.3229188828254 ; Total_loss - Total_loss_real_X =  0.41890480486335946 Total_loss_update =  0.006783328544770484
# t =  7.62939453125e-06
# #iter 105 x_co=140, 1st=0.03089699725673878, 2nd=5.043246327782123e-07, # queries above err=[1], xi=1.2995540066317013 fake x=0.8321459789808401
# Total loss =  2368.3161355542807 ; Total_loss - Total_loss_real_X =  0.412121476318589 Total_loss_update =  0.006596747092771693
# t =  7.62939453125e-06
# #iter 106 x_co=110, 1st=-0.030815968931081628, 2nd=4.94558120996961e-07, # queries above err=[1], xi=-0.9286333711013075 fake x=-0.4532449893191614
# Total loss =  2368.309538807188 ; Total_loss - Total_loss_real_X =  0.4055247292258173 Total_loss_update =  0.00669178365933476
# t =  7.62939453125e-06
# #iter 107 x_co=42, 1st=0.030820028060313476, 2nd=5.13546457952967e-07, # queries above err=[1], xi=0.1468822957546082 fake x=-0.31098894431509205
# Total loss =  2368.3028470235286 ; Total_loss - Total_loss_real_X =  0.3988329455664825 Total_loss_update =  0.006446060495363781
# t =  7.62939453125e-06
# #iter 108 x_co=164, 1st=-0.030328041816300555, 2nd=4.935733001068972e-07, # queries above err=[1], xi=-1.1071169643887697 fake x=-0.6383221646565072
# Total loss =  2368.296400963033 ; Total_loss - Total_loss_real_X =  0.39238688507111874 Total_loss_update =  0.006494482918697031
# t =  7.62939453125e-06
# #iter 109 x_co=73, 1st=0.03063521643909972, 2nd=4.963850249060613e-07, # queries above err=[1], xi=0.8969905858974155 fake x=0.4261299816550544
# Total loss =  2368.2899064801145 ; Total_loss - Total_loss_real_X =  0.3858924021524217 Total_loss_update =  0.006589176372926886
# t =  7.62939453125e-06
# #iter 110 x_co=166, 1st=-0.030284972110838027, 2nd=4.970404313324247e-07, # queries above err=[1], xi=-0.7550330230260985 fake x=-0.29016943037611903
# Total loss =  2368.2833173037416 ; Total_loss - Total_loss_real_X =  0.3793032257794948 Total_loss_update =  0.006430881604501337
# t =  7.62939453125e-06
# #iter 111 x_co=189, 1st=0.029880948084037406, 2nd=5.036010823179478e-07, # queries above err=[1], xi=-0.4012463955341796 fake x=-0.8539331547675313
# Total loss =  2368.276886422137 ; Total_loss - Total_loss_real_X =  0.3728723441749935 Total_loss_update =  0.006178880802508502
# t =  7.62939453125e-06
# #iter 112 x_co=106, 1st=-0.029044332594227562, 2nd=4.907536920015079e-07, # queries above err=[1], xi=0.07186618518178667 fake x=0.5233975253831458
# Total loss =  2368.2707075413346 ; Total_loss - Total_loss_real_X =  0.366693463372485 Total_loss_update =  0.005990554204345244
# t =  7.62939453125e-06
# #iter 113 x_co=128, 1st=0.029719101259495062, 2nd=4.948443121181146e-07, # queries above err=[1], xi=1.100017835605695 fake x=0.641815643380161
# Total loss =  2368.26471698713 ; Total_loss - Total_loss_real_X =  0.36070290916813974 Total_loss_update =  0.006220294318609376
# t =  7.62939453125e-06
# #iter 114 x_co=79, 1st=-0.02934657103387117, 2nd=4.876833616957635e-07, # queries above err=[1], xi=-0.3506738011886448 fake x=0.10842853065681213
# Total loss =  2368.2584966928116 ; Total_loss - Total_loss_real_X =  0.35448261484953036 Total_loss_update =  0.0061543943720607786
# t =  7.62939453125e-06
# #iter 115 x_co=8, 1st=0.029055100732616523, 2nd=4.946747016911931e-07, # queries above err=[1], xi=0.1987079487913523 fake x=-0.24941043259441023
# Total loss =  2368.2523422984395 ; Total_loss - Total_loss_real_X =  0.3483282204774696 Total_loss_update =  0.005947478962752939
# t =  7.62939453125e-06
# #iter 116 x_co=148, 1st=-0.028426808333858133, 2nd=5.007524520371028e-07, # queries above err=[1], xi=-0.6148573822598972 fake x=-0.18175049449340513
# Total loss =  2368.246394819477 ; Total_loss - Total_loss_real_X =  0.34238074151471665 Total_loss_update =  0.005623937591280992
# t =  7.62939453125e-06
# #iter 117 x_co=86, 1st=0.028525656899699214, 2nd=5.053832861872623e-07, # queries above err=[1], xi=-0.07252456469961976 fake x=-0.5031551310421682
# Total loss =  2368.2407708818855 ; Total_loss - Total_loss_real_X =  0.33675680392343565 Total_loss_update =  0.0056112222555384506
# t =  7.62939453125e-06
# #iter 118 x_co=191, 1st=-0.028466059957199974, 2nd=5.083151904049579e-07, # queries above err=[1], xi=-0.24503053667373798 fake x=0.18222170025169587
# Total loss =  2368.23515965963 ; Total_loss - Total_loss_real_X =  0.3311455816678972 Total_loss_update =  0.005555577870381967
# t =  7.62939453125e-06
# #iter 119 x_co=9, 1st=0.028097205540309034, 2nd=4.948925047224542e-07, # queries above err=[1], xi=0.2759838765707069 fake x=-0.1571701199984289
# Total loss =  2368.2296040817596 ; Total_loss - Total_loss_real_X =  0.32559000379751524 Total_loss_update =  0.005559331185395422
# t =  7.62939453125e-06
# #iter 120 x_co=53, 1st=-0.02824998455248373, 2nd=5.02534389060107e-07, # queries above err=[1], xi=0.25140858113072506 fake x=0.6802952052993195
# Total loss =  2368.224044750574 ; Total_loss - Total_loss_real_X =  0.3200306726121198 Total_loss_update =  0.005534503160561144
# t =  7.62939453125e-06
# #iter 121 x_co=112, 1st=0.028158998620916087, 2nd=5.113921965991938e-07, # queries above err=[1], xi=0.5420078073791308 fake x=0.12190732185632885
# Total loss =  2368.2185102474136 ; Total_loss - Total_loss_real_X =  0.31449616945155867 Total_loss_update =  0.005403653441135248
# t =  7.62939453125e-06
# #iter 122 x_co=76, 1st=-0.028270234762476143, 2nd=5.015664184410501e-07, # queries above err=[1], xi=-0.2882315730967468 fake x=0.1417907859845738
# Total loss =  2368.2131065939725 ; Total_loss - Total_loss_real_X =  0.3090925160104234 Total_loss_update =  0.005553133786634135
# t =  7.62939453125e-06
# #iter 123 x_co=121, 1st=0.027783906521661628, 2nd=4.962954329686938e-07, # queries above err=[1], xi=0.7928173541351323 fake x=0.36570404542471807
# Total loss =  2368.207553460186 ; Total_loss - Total_loss_real_X =  0.3035393822237893 Total_loss_update =  0.005420677156052989
# t =  7.62939453125e-06
# #iter 124 x_co=108, 1st=-0.027692341710563895, 2nd=4.937083012372421e-07, # queries above err=[1], xi=0.22686535599598234 fake x=0.6548018518471184
# Total loss =  2368.20213278303 ; Total_loss - Total_loss_real_X =  0.2981187050677363 Total_loss_update =  0.005413227826466027
# t =  7.62939453125e-06
# #iter 125 x_co=62, 1st=0.027832872907921136, 2nd=5.120463690405465e-07, # queries above err=[1], xi=1.102408369054389 fake x=0.6877038008908465
# Total loss =  2368.1967195552033 ; Total_loss - Total_loss_real_X =  0.2927054772412703 Total_loss_update =  0.005272463676647021
# t =  7.62939453125e-06
# #iter 126 x_co=65, 1st=-0.027444173609351807, 2nd=5.019397167357829e-07, # queries above err=[1], xi=-0.592677566936811 fake x=-0.17553100317907283
# Total loss =  2368.1914470915267 ; Total_loss - Total_loss_real_X =  0.28743301356462325 Total_loss_update =  0.005229452812727686
# t =  7.62939453125e-06
# #iter 127 x_co=111, 1st=0.02754581035754633, 2nd=5.13204467807457e-07, # queries above err=[1], xi=-0.36519066622117236 fake x=-0.7746918847093172
# Total loss =  2368.186217638714 ; Total_loss - Total_loss_real_X =  0.28220356075189557 Total_loss_update =  0.005152615427959972
# t =  7.62939453125e-06
# #iter 128 x_co=152, 1st=-0.027322556246448748, 2nd=4.803026313098274e-07, # queries above err=[1], xi=0.6587807688326321 fake x=1.0927874713109273
# Total loss =  2368.181065023286 ; Total_loss - Total_loss_real_X =  0.2770509453239356 Total_loss_update =  0.0054167019688975415
# t =  7.62939453125e-06
# #iter 129 x_co=115, 1st=0.027743428518702373, 2nd=4.946440676818672e-07, # queries above err=[1], xi=0.9130212463318457 fake x=0.485106356316735
# Total loss =  2368.175648321317 ; Total_loss - Total_loss_real_X =  0.27163424335503805 Total_loss_update =  0.005422947242095688
# t =  7.62939453125e-06
# #iter 130 x_co=90, 1st=-0.027069372256722346, 2nd=4.969299252959487e-07, # queries above err=[1], xi=-1.0099955192670917 fake x=-0.5943978461408208
# Total loss =  2368.170225374075 ; Total_loss - Total_loss_real_X =  0.26621129611294236 Total_loss_update =  0.005138883017025364
# t =  7.62939453125e-06
# #iter 131 x_co=159, 1st=0.026892059750593944, 2nd=5.021670788576707e-07, # queries above err=[1], xi=0.2656148090138791 fake x=-0.14295465368755994
# Total loss =  2368.165086491058 ; Total_loss - Total_loss_real_X =  0.261072413095917 Total_loss_update =  0.0050188852756036795
# t =  7.62939453125e-06
# #iter 132 x_co=182, 1st=-0.026542273450873566, 2nd=5.170965353902123e-07, # queries above err=[1], xi=-0.9875258061610255 fake x=-0.5959132888576077
# Total loss =  2368.1600676057824 ; Total_loss - Total_loss_real_X =  0.2560535278203133 Total_loss_update =  0.004748013464450196
# t =  7.62939453125e-06
# #iter 133 x_co=15, 1st=0.02599361776907383, 2nd=5.03151801286531e-07, # queries above err=[1], xi=-0.08087440441217486 fake x=-0.47502099148131166
# Total loss =  2368.155319592318 ; Total_loss - Total_loss_real_X =  0.2513055143558631 Total_loss_update =  0.004679956053223577
# t =  7.62939453125e-06
# #iter 134 x_co=69, 1st=-0.026582917908443804, 2nd=4.902468256085999e-07, # queries above err=[1], xi=-0.4021348724483317 fake x=0.011557900092470541
# Total loss =  2368.1506396362647 ; Total_loss - Total_loss_real_X =  0.24662555830263955 Total_loss_update =  0.005023396454816975
# t =  7.62939453125e-06
# #iter 135 x_co=48, 1st=0.026621082115442007, 2nd=4.999228973224983e-07, # queries above err=[1], xi=0.6782343090482891 fake x=0.27196618371277426
# Total loss =  2368.14561623981 ; Total_loss - Total_loss_real_X =  0.24160216184782257 Total_loss_update =  0.004940327593430993
# t =  7.62939453125e-06
# #iter 136 x_co=5, 1st=-0.0264004446982824, 2nd=4.922755886499037e-07, # queries above err=[1], xi=0.062023559433573024 fake x=0.47118341429464583
# Total loss =  2368.1406759122165 ; Total_loss - Total_loss_real_X =  0.23666183425439158 Total_loss_update =  0.004934256313390506
# t =  7.62939453125e-06
# #iter 137 x_co=100, 1st=0.026741832297386026, 2nd=5.061590104220197e-07, # queries above err=[1], xi=0.2473250261384592 fake x=-0.1557577697504704
# Total loss =  2368.135741655903 ; Total_loss - Total_loss_real_X =  0.23172757794100107 Total_loss_update =  0.004923825954392669
# t =  7.62939453125e-06
# #iter 138 x_co=147, 1st=-0.026437924652870315, 2nd=5.017364333966826e-07, # queries above err=[1], xi=-0.9772445709877176 fake x=-0.5752299985184782
# Total loss =  2368.1308178299487 ; Total_loss - Total_loss_real_X =  0.2268037519866084 Total_loss_update =  0.00485496744113334
# t =  7.62939453125e-06
# #iter 139 x_co=39, 1st=0.026555724188211727, 2nd=4.926271514428371e-07, # queries above err=[1], xi=0.3950440742389808 fake x=-0.01622862216341281
# Total loss =  2368.1259628625075 ; Total_loss - Total_loss_real_X =  0.22194878454547506 Total_loss_update =  0.004988900026546617
# t =  7.62939453125e-06
# #iter 140 x_co=144, 1st=-0.026620083942605177, 2nd=5.194838786165443e-07, # queries above err=[1], xi=0.12767808454326035 fake x=0.5186336679850365
# Total loss =  2368.120973962481 ; Total_loss - Total_loss_real_X =  0.21695988451892845 Total_loss_update =  0.0047539434153804905
# t =  7.62939453125e-06
# #iter 141 x_co=56, 1st=0.02590828352482255, 2nd=5.002844239108275e-07, # queries above err=[1], xi=-0.08265378140293711 fake x=-0.47775806047117386
# Total loss =  2368.1162200190656 ; Total_loss - Total_loss_real_X =  0.21220594110354796 Total_loss_update =  0.004675927670177771
# t =  7.62939453125e-06
# #iter 142 x_co=18, 1st=-0.026024120295160103, 2nd=4.916893191904622e-07, # queries above err=[1], xi=-0.2565950494835082 fake x=0.14721335820650383
# Total loss =  2368.1115440913954 ; Total_loss - Total_loss_real_X =  0.2075300134333702 Total_loss_update =  0.0048003059278016735
# t =  7.62939453125e-06
# #iter 143 x_co=160, 1st=0.025972002167035768, 2nd=5.176151316932721e-07, # queries above err=[1], xi=1.7069396282245308 fake x=1.3241249862905007
# Total loss =  2368.1067437854676 ; Total_loss - Total_loss_real_X =  0.2027297075055685 Total_loss_update =  0.004541623648492532
# t =  7.62939453125e-06
# #iter 144 x_co=104, 1st=-0.025452228297837998, 2nd=5.085612543794502e-07, # queries above err=[1], xi=0.20653016796343968 fake x=0.5883624245725234
# Total loss =  2368.102202161819 ; Total_loss - Total_loss_real_X =  0.19818808385707598 Total_loss_update =  0.00443930810160964
# t =  7.62939453125e-06
# #iter 145 x_co=188, 1st=0.025624711723750693, 2nd=5.040065142005116e-07, # queries above err=[1], xi=0.4237107341328007 fake x=0.03581686772085968
# Total loss =  2368.0977628537175 ; Total_loss - Total_loss_real_X =  0.19374877575546634 Total_loss_update =  0.004540348973478103
# t =  7.62939453125e-06
# #iter 146 x_co=24, 1st=-0.02563686041928115, 2nd=4.998380176117727e-07, # queries above err=[1], xi=-0.2408979544112676 fake x=0.15041626297425753
# Total loss =  2368.093222504744 ; Total_loss - Total_loss_real_X =  0.18920842678198824 Total_loss_update =  0.004582549778660905
# t =  7.62939453125e-06
# #iter 147 x_co=143, 1st=0.025625260025510244, 2nd=5.042354942516419e-07, # queries above err=[1], xi=-1.003601766516934 fake x=-1.3913277813042209
# Total loss =  2368.0886399549654 ; Total_loss - Total_loss_real_X =  0.18462587700332733 Total_loss_update =  0.004538475590834423
# t =  7.62939453125e-06
# #iter 148 x_co=22, 1st=-0.02535688176853501, 2nd=5.016801071741766e-07, # queries above err=[1], xi=-0.8530928411960828 fake x=-0.467473295338252
# Total loss =  2368.0841014793746 ; Total_loss - Total_loss_real_X =  0.1800874014124929 Total_loss_update =  0.004466548747586785
# t =  7.62939453125e-06
# #iter 149 x_co=28, 1st=0.025267557525076256, 2nd=4.897868168968001e-07, # queries above err=[1], xi=-0.623747678001711 fake x=-1.0173396624108795
# Total loss =  2368.079634930627 ; Total_loss - Total_loss_real_X =  0.17562085266490612 Total_loss_update =  0.004542829422462091
# t =  7.62939453125e-06
# #iter 150 x_co=151, 1st=-0.025384785078315097, 2nd=5.035743916533183e-07, # queries above err=[1], xi=-0.037668944054432996 fake x=0.3469227739985865
# Total loss =  2368.0750921012045 ; Total_loss - Total_loss_real_X =  0.17107802324244403 Total_loss_update =  0.0044595472404580505
# t =  7.62939453125e-06
# #iter 151 x_co=101, 1st=0.02516627264109328, 2nd=5.107086176647909e-07, # queries above err=[1], xi=0.018823711180174785 fake x=-0.35713121931979785
# Total loss =  2368.070632553964 ; Total_loss - Total_loss_real_X =  0.16661847600198598 Total_loss_update =  0.004321875100231409
# t =  7.62939453125e-06
# #iter 152 x_co=87, 1st=-0.025182072274116507, 2nd=4.91733244307245e-07, # queries above err=[1], xi=0.006145428477763559 fake x=0.3968531276579389
# Total loss =  2368.066310678864 ; Total_loss - Total_loss_real_X =  0.16229660090175457 Total_loss_update =  0.004494288254591083
# t =  7.62939453125e-06
# #iter 153 x_co=16, 1st=0.025126698671474657, 2nd=4.999162556949345e-07, # queries above err=[1], xi=0.9756155323681249 fake x=0.5921483111111749
# Total loss =  2368.0618163906092 ; Total_loss - Total_loss_real_X =  0.1578023126471635 Total_loss_update =  0.004401296385367459
# t =  7.62939453125e-06
# #iter 154 x_co=153, 1st=-0.024669096986866812, 2nd=5.102166086724814e-07, # queries above err=[1], xi=-1.3699610514264413 fake x=-1.0010779722727134
# Total loss =  2368.057415094224 ; Total_loss - Total_loss_real_X =  0.15340101626179603 Total_loss_update =  0.004156801667704713
# t =  7.62939453125e-06
# #iter 155 x_co=80, 1st=0.024435765868381587, 2nd=4.989223004818722e-07, # queries above err=[1], xi=0.8372483082014095 fake x=0.4635827127708648
# Total loss =  2368.053258292556 ; Total_loss - Total_loss_real_X =  0.14924421459409132 Total_loss_update =  0.004170860213889682
# t =  7.62939453125e-06
# #iter 156 x_co=135, 1st=-0.024490257736014875, 2nd=5.03674222712011e-07, # queries above err=[1], xi=1.049005136957751 fake x=1.4199707929605379
# Total loss =  2368.0490874323423 ; Total_loss - Total_loss_real_X =  0.14507335438020164 Total_loss_update =  0.004149963847339677
# t =  7.62939453125e-06
# #iter 157 x_co=2, 1st=0.02446687864850805, 2nd=4.924239565859293e-07, # queries above err=[1], xi=0.3380247622874657 fake x=-0.041054012538776385
# Total loss =  2368.044937468495 ; Total_loss - Total_loss_real_X =  0.14092339053286196 Total_loss_update =  0.004236679257246578
# t =  7.62939453125e-06
# #iter 158 x_co=83, 1st=-0.024505754347647013, 2nd=4.947526358734982e-07, # queries above err=[1], xi=-0.3604829723466648 fake x=0.017411059231366655
# Total loss =  2368.0407007892377 ; Total_loss - Total_loss_real_X =  0.13668671127561538 Total_loss_update =  0.004230143650602258
# t =  7.62939453125e-06
# ...
# #iter 287 x_co=73, 1st=0.014459647404980736, 2nd=4.962739359329186e-07, # queries above err=[1], xi=0.4261299816550544 fake x=0.2038367140709292
# Total loss =  2367.714078919853 ; Total_loss - Total_loss_real_X =  -0.18993515810916506 Total_loss_update =  0.001468251069127291
# t =  7.62939453125e-06
# #iter 288 x_co=148, 1st=-0.014624861966238356, 2nd=5.006378117997466e-07, # queries above err=[1], xi=-0.18175049449340513 fake x=0.04112288677276299
# Total loss =  2367.712610668784 ; Total_loss - Total_loss_real_X =  -0.19140340917829235 Total_loss_update =  0.0014889023050272954
# t =  7.62939453125e-06
# #iter 289 x_co=140, 1st=0.014584820583706026, 2nd=5.042037508802073e-07, # queries above err=[1], xi=0.8321459789808401 fake x=0.611454740158568
# Total loss =  2367.7111217664788 ; Total_loss - Total_loss_real_X =  -0.19289231148331965 Total_loss_update =  0.001470287897518574
# t =  7.62939453125e-06
# #iter 290 x_co=193, 1st=-0.014511651399426562, 2nd=5.182412379287131e-07, # queries above err=[1], xi=-0.20019839300884695 fake x=0.013437855369791113
# Total loss =  2367.7096514785812 ; Total_loss - Total_loss_real_X =  -0.19436259938083822 Total_loss_update =  0.0014161461131152464
# t =  7.62939453125e-06
# #iter 291 x_co=68, 1st=0.01433983523377691, 2nd=4.962558204563357e-07, # queries above err=[1], xi=-1.1752614727890038 fake x=-1.3957208729649053
# Total loss =  2367.708235332468 ; Total_loss - Total_loss_real_X =  -0.19577874549395347 Total_loss_update =  0.0014440733134506445
# t =  7.62939453125e-06
# #iter 292 x_co=182, 1st=-0.014406428794210058, 2nd=5.169949484327442e-07, # queries above err=[1], xi=-0.5959132888576077 fake x=-0.383314830418923
# Total loss =  2367.7067912591547 ; Total_loss - Total_loss_real_X =  -0.1972228188074041 Total_loss_update =  0.0013990485549584264
# t =  7.62939453125e-06
# #iter 293 x_co=101, 1st=0.014128054009167279, 2nd=5.106179575650655e-07, # queries above err=[1], xi=-0.35713121931979785 fake x=-0.5682254364302695
# Total loss =  2367.7053922105997 ; Total_loss - Total_loss_real_X =  -0.19862186736236254 Total_loss_update =  0.0013623078275486478
# t =  7.62939453125e-06
# #iter 294 x_co=87, 1st=-0.01415795298426925, 2nd=4.916629667474047e-07, # queries above err=[1], xi=0.3968531276579389 fake x=0.6165495790430454
# Total loss =  2367.704029902772 ; Total_loss - Total_loss_real_X =  -0.19998417518991118 Total_loss_update =  0.0014208231114025693
# t =  7.62939453125e-06
# #iter 295 x_co=28, 1st=0.014287641476506963, 2nd=4.89703020060166e-07, # queries above err=[1], xi=-1.0173396624108795 fake x=-1.2399359080536574
# Total loss =  2367.7026090796608 ; Total_loss - Total_loss_real_X =  -0.20140499830131375 Total_loss_update =  0.00145276226930946
# t =  7.62939453125e-06
# #iter 296 x_co=69, 1st=-0.014311297378098331, 2nd=4.901489589069991e-07, # queries above err=[1], xi=0.011557900092470541 fake x=0.23431984208462509
# Total loss =  2367.7011563173915 ; Total_loss - Total_loss_real_X =  -0.2028577605706232 Total_loss_update =  0.001456250566207018
# t =  7.62939453125e-06
# #iter 297 x_co=80, 1st=0.014223612627564997, 2nd=4.988470654377921e-07, # queries above err=[1], xi=0.4635827127708648 fake x=0.24604599678331668
# Total loss =  2367.6997000668252 ; Total_loss - Total_loss_real_X =  -0.20431401113683023 Total_loss_update =  0.0014133786062302534
# t =  7.62939453125e-06
# #iter 298 x_co=151, 1st=-0.014090698620289999, 2nd=5.034993447285179e-07, # queries above err=[1], xi=0.3469227739985865 fake x=0.5604354629835092
# Total loss =  2367.698286688219 ; Total_loss - Total_loss_real_X =  -0.20572738974306048 Total_loss_update =  0.0013742717128479853
# t =  7.62939453125e-06
# #iter 299 x_co=56, 1st=0.013916922950289567, 2nd=5.001995299276688e-07, # queries above err=[1], xi=-0.47775806047117386 fake x=-0.6900287434606613
# Total loss =  2367.696912416506 ; Total_loss - Total_loss_real_X =  -0.20710166145590847 Total_loss_update =  0.001349427766399458
# t =  7.62939453125e-06
# #iter 300 x_co=96, 1st=-0.013997753817156067, 2nd=4.897578554872324e-07, # queries above err=[1], xi=0.5435432263802824 fake x=0.7615987107913504
# Total loss =  2367.6955629887398 ; Total_loss - Total_loss_real_X =  -0.20845108922230793 Total_loss_update =  0.0013942536315880716
# t =  7.62939453125e-06
# #iter 301 x_co=159, 1st=0.013967498170902815, 2nd=5.020802867714647e-07, # queries above err=[1], xi=-0.14295465368755994 fake x=-0.35519870502358775
# Total loss =  2367.694168735108 ; Total_loss - Total_loss_real_X =  -0.209845342853896 Total_loss_update =  0.0013541614557652792
# t =  7.62939453125e-06
# #iter 302 x_co=50, 1st=-0.013840781632353583, 2nd=5.009108462764568e-07, # queries above err=[1], xi=-0.8507971413839602 fake x=-0.6399876041597969
# Total loss =  2367.6928145736524 ; Total_loss - Total_loss_real_X =  -0.21119950430966128 Total_loss_update =  0.0013328067766451568
# t =  7.62939453125e-06
# #iter 303 x_co=39, 1st=0.013797786650691535, 2nd=4.925238775235162e-07, # queries above err=[1], xi=-0.01622862216341281 fake x=-0.22996193098378379
# Total loss =  2367.6914817668758 ; Total_loss - Total_loss_real_X =  -0.21253231108630644 Total_loss_update =  0.0013470933290591347
# t =  7.62939453125e-06
# #iter 304 x_co=88, 1st=-0.013584807363093532, 2nd=5.091629373472728e-07, # queries above err=[1], xi=-1.1524484476249617 fake x=-0.9488911039894398
# Total loss =  2367.6901346735467 ; Total_loss - Total_loss_real_X =  -0.21387940441536557 Total_loss_update =  0.0012631545987460413
# t =  7.62939453125e-06
# #iter 305 x_co=30, 1st=0.013401128007373586, 2nd=5.138038935870035e-07, # queries above err=[1], xi=0.6885086486186909 fake x=0.48951737196982226
# Total loss =  2367.688871518948 ; Total_loss - Total_loss_real_X =  -0.2151425590141116 Total_loss_update =  0.0012181240026620799
# t =  7.62939453125e-06
# #iter 306 x_co=107, 1st=-0.013607831919401292, 2nd=4.910492173283116e-07, # queries above err=[1], xi=-0.11218543446824986 fake x=0.09923842033984467
# Total loss =  2367.6876533949453 ; Total_loss - Total_loss_real_X =  -0.2163606830167737 Total_loss_update =  0.0013141929921403062
# t =  7.62939453125e-06
# #iter 307 x_co=7, 1st=0.013909348391687004, 2nd=5.060387782961608e-07, # queries above err=[1], xi=0.8800358678391911 fake x=0.6703288036689412
# Total loss =  2367.686339201953 ; Total_loss - Total_loss_real_X =  -0.217674876008914 Total_loss_update =  0.0013324042733984243
# t =  7.62939453125e-06
# #iter 308 x_co=192, 1st=-0.013665096562494483, 2nd=4.973298991359915e-07, # queries above err=[1], xi=-1.1358851323810273 fake x=-0.9262528276190922
# Total loss =  2367.6850067976798 ; Total_loss - Total_loss_real_X =  -0.21900728028231242 Total_loss_update =  0.001308540272020764
# t =  7.62939453125e-06
# #iter 309 x_co=45, 1st=0.01363313567602642, 2nd=5.055490455261215e-07, # queries above err=[1], xi=-0.7476787993740115 fake x=-0.953420599681873
# Total loss =  2367.6836982574077 ; Total_loss - Total_loss_real_X =  -0.22031582055433319 Total_loss_update =  0.0012812515033147065
# t =  7.62939453125e-06
# #iter 310 x_co=54, 1st=-0.013308785955699953, 2nd=4.844702707614945e-07, # queries above err=[1], xi=-0.18582877634942951 fake x=0.023756795595771096
# Total loss =  2367.6824170059044 ; Total_loss - Total_loss_real_X =  -0.2215970720576479 Total_loss_update =  0.0012741366726913839
# t =  7.62939453125e-06
# #iter 311 x_co=185, 1st=0.013567910813301332, 2nd=5.077620598710907e-07, # queries above err=[1], xi=-0.4923909244564212 fake x=-0.6962559879189592
# Total loss =  2367.6811428692317 ; Total_loss - Total_loss_real_X =  -0.22287120873033928 Total_loss_update =  0.001263491432837327
# t =  7.62939453125e-06
# #iter 312 x_co=77, 1st=-0.013295984170609287, 2nd=5.007475159400937e-07, # queries above err=[1], xi=-0.26433138594711514 fake x=-0.06175362831532541
# Total loss =  2367.679879377799 ; Total_loss - Total_loss_real_X =  -0.2241347001631766 Total_loss_update =  0.0012303499970585108
# t =  7.62939453125e-06
# #iter 313 x_co=183, 1st=0.013387854076802874, 2nd=5.018242732688689e-07, # queries above err=[1], xi=-0.9665239771627191 fake x=-1.1700637940260763
# Total loss =  2367.678649027802 ; Total_loss - Total_loss_real_X =  -0.22536505016023511 Total_loss_update =  0.0012447342505765846
# t =  7.62939453125e-06
# #iter 314 x_co=138, 1st=-0.013277319416152622, 2nd=4.956296755729541e-07, # queries above err=[1], xi=0.39356161375738147 fake x=0.5979438635210839
# Total loss =  2367.6774042935513 ; Total_loss - Total_loss_real_X =  -0.2266097844108117 Total_loss_update =  0.0012395670237310696
# t =  7.62939453125e-06
# #iter 315 x_co=62, 1st=0.01314197640881165, 2nd=5.119360802152003e-07, # queries above err=[1], xi=0.6877038008908465 fake x=0.4918486408070797
# Total loss =  2367.6761647265275 ; Total_loss - Total_loss_real_X =  -0.22784935143454277 Total_loss_update =  0.0011757410129575874
# t =  7.62939453125e-06
# #iter 316 x_co=11, 1st=-0.012942565699185948, 2nd=5.068702862412537e-07, # queries above err=[1], xi=1.0238852743428395 fake x=1.2186963387237455
# Total loss =  2367.6749889855146 ; Total_loss - Total_loss_real_X =  -0.22902509244750036 Total_loss_update =  0.0011517292405187618
# t =  7.62939453125e-06
# #iter 317 x_co=142, 1st=0.013132721221408516, 2nd=4.983726973788739e-07, # queries above err=[1], xi=-0.7529519984830629 fake x=-0.9539957394303619
# Total loss =  2367.673837256274 ; Total_loss - Total_loss_real_X =  -0.23017682168801912 Total_loss_update =  0.0012060389117323211
# t =  7.62939453125e-06
# #iter 318 x_co=109, 1st=-0.013027848233960526, 2nd=4.875561856733249e-07, # queries above err=[1], xi=1.275570430662294 fake x=1.4794332817363038
# Total loss =  2367.6726312173623 ; Total_loss - Total_loss_real_X =  -0.23138286059975144 Total_loss_update =  0.0012131851244703284
# t =  7.62939453125e-06
# #iter 319 x_co=92, 1st=0.01300521542289168, 2nd=4.864060507908433e-07, # queries above err=[1], xi=0.46513030372912945 fake x=0.2611404083242226
# Total loss =  2367.671418032238 ; Total_loss - Total_loss_real_X =  -0.23259604572422177 Total_loss_update =  0.001211832417993719
# t =  7.62939453125e-06
# #iter 320 x_co=123, 1st=-0.013017696194905781, 2nd=5.062448067053805e-07, # queries above err=[1], xi=0.6411353535418485 fake x=0.8373193713202032
# Total loss =  2367.67020619982 ; Total_loss - Total_loss_real_X =  -0.2338078781422155 Total_loss_update =  0.001166578496395232
# t =  7.62939453125e-06
# #iter 321 x_co=78, 1st=0.012910823315275266, 2nd=4.956959001585073e-07, # queries above err=[1], xi=0.3999598438655779 fake x=0.20124574361984568
# Total loss =  2367.6690396213235 ; Total_loss - Total_loss_real_X =  -0.23497445663861072 Total_loss_update =  0.001171923050605983
# t =  7.62939453125e-06
# #iter 322 x_co=149, 1st=-0.013164040470804217, 2nd=4.911495969255813e-07, # queries above err=[1], xi=0.7254404758956522 fake x=0.929927375621898
# Total loss =  2367.667867698273 ; Total_loss - Total_loss_real_X =  -0.2361463796892167 Total_loss_update =  0.001229620082085603
# t =  7.62939453125e-06
# #iter 323 x_co=41, 1st=0.012814669005979162, 2nd=5.030521562244487e-07, # queries above err=[1], xi=1.093672730176148 fake x=0.899322771778644
# Total loss =  2367.6666380781908 ; Total_loss - Total_loss_real_X =  -0.2373759997713023 Total_loss_update =  0.001137648730946239
# t =  7.62939453125e-06
# #iter 324 x_co=36, 1st=-0.012570467464549928, 2nd=5.003704929947629e-07, # queries above err=[1], xi=0.2468795903039251 fake x=0.43854767839459724
# Total loss =  2367.66550042946 ; Total_loss - Total_loss_real_X =  -0.23851364850224854 Total_loss_update =  0.0011005694013874745
# t =  7.62939453125e-06
# #iter 325 x_co=71, 1st=0.012685460391089975, 2nd=4.916208650417878e-07, # queries above err=[1], xi=1.1850630893238498 fake x=0.9881992273192463
# Total loss =  2367.6643998600584 ; Total_loss - Total_loss_real_X =  -0.23961421790363602 Total_loss_update =  0.0011407448164391099
# t =  7.62939453125e-06
# #iter 326 x_co=134, 1st=-0.012653341798197992, 2nd=4.940916717503952e-07, # queries above err=[1], xi=1.0462044172431024 fake x=1.2415878698222778
# Total loss =  2367.663259115242 ; Total_loss - Total_loss_real_X =  -0.24075496272007513 Total_loss_update =  0.0011292997141936212
# t =  7.62939453125e-06
# #iter 327 x_co=133, 1st=0.012647067812089574, 2nd=5.059158274533701e-07, # queries above err=[1], xi=-0.5144411263587467 fake x=-0.7051635049955318
# Total loss =  2367.662129815528 ; Total_loss - Total_loss_real_X =  -0.24188426243426875 Total_loss_update =  0.0011018126906492398
# t =  7.62939453125e-06
# #iter 328 x_co=72, 1st=-0.012573094538995022, 2nd=5.068415880452402e-07, # queries above err=[1], xi=0.6082590068359549 fake x=0.7975195193496512
# Total loss =  2367.661028002837 ; Total_loss - Total_loss_real_X =  -0.242986075124918 Total_loss_update =  0.001086971730728692
# t =  7.62939453125e-06
# #iter 329 x_co=64, 1st=0.012531363950259333, 2nd=4.988625611557194e-07, # queries above err=[1], xi=-0.7009152021323249 fake x=-0.8925646203001646
# Total loss =  2367.6599410311064 ; Total_loss - Total_loss_real_X =  -0.24407304685564668 Total_loss_update =  0.001097039157684776
# t =  7.62939453125e-06
# #iter 330 x_co=177, 1st=-0.012304261923993032, 2nd=4.993823858109856e-07, # queries above err=[1], xi=-0.42665609682863076 fake x=-0.2386757609152391
# Total loss =  2367.6588439919487 ; Total_loss - Total_loss_real_X =  -0.24517008601333146 Total_loss_update =  0.0010565362936176825
# t =  7.62939453125e-06
# #iter 331 x_co=105, 1st=0.01238041142109303, 2nd=5.077313005110755e-07, # queries above err=[1], xi=-0.24470314388903924 fake x=-0.4307366681087102
# Total loss =  2367.657787455655 ; Total_loss - Total_loss_real_X =  -0.24622662230694914 Total_loss_update =  0.001052064744726522
# t =  7.62939453125e-06
# #iter 332 x_co=13, 1st=-0.012171421860159626, 2nd=4.96544180942602e-07, # queries above err=[1], xi=-0.7015114492834549 fake x=-0.5144977193044649
# Total loss =  2367.6567353909104 ; Total_loss - Total_loss_real_X =  -0.24727868705167566 Total_loss_update =  0.0010397553587608854
# t =  7.62939453125e-06
# #iter 333 x_co=155, 1st=0.01237892793440043, 2nd=5.031912024932419e-07, # queries above err=[1], xi=-0.777136778787096 fake x=-0.9648263183050706
# Total loss =  2367.6556956355516 ; Total_loss - Total_loss_real_X =  -0.24831844241043655 Total_loss_update =  0.001061302676134801
# t =  7.62939453125e-06
# #iter 334 x_co=173, 1st=-0.012274616678563888, 2nd=4.871513884029951e-07, # queries above err=[1], xi=0.5552880970111722 fake x=0.7475238076957434
# Total loss =  2367.6546343328755 ; Total_loss - Total_loss_real_X =  -0.24937974508657135 Total_loss_update =  0.001077850058209151
# t =  7.62939453125e-06
# #iter 335 x_co=198, 1st=0.012418136779165145, 2nd=5.04109419070699e-07, # queries above err=[1], xi=-0.02080738408838556 fake x=-0.208748456496695
# Total loss =  2367.6535564828173 ; Total_loss - Total_loss_real_X =  -0.2504575951447805 Total_loss_update =  0.0010660911862032663
# t =  7.62939453125e-06
# #iter 336 x_co=25, 1st=-0.012341195181416964, 2nd=5.094065928991506e-07, # queries above err=[1], xi=-0.14946923698851383 fake x=0.03536513370607958
# Total loss =  2367.652490391631 ; Total_loss - Total_loss_real_X =  -0.25152368633098376 Total_loss_update =  0.001041972493112553
# t =  7.62939453125e-06
# #iter 337 x_co=91, 1st=0.012212484071725704, 2nd=5.087335635427297e-07, # queries above err=[1], xi=0.1936150840507923 fake x=0.010466446203987567
# Total loss =  2367.651448419138 ; Total_loss - Total_loss_real_X =  -0.2525656588240963 Total_loss_update =  0.001021701123136154
# t =  7.62939453125e-06
# #iter 338 x_co=38, 1st=-0.011953129146838215, 2nd=4.928448137499706e-07, # queries above err=[1], xi=-0.3434088992265293 fake x=-0.15837065676167614
# Total loss =  2367.650426718015 ; Total_loss - Total_loss_real_X =  -0.25358735994723247 Total_loss_update =  0.0010103209701810556
# t =  7.62939453125e-06
# #iter 339 x_co=43, 1st=0.012033748471534267, 2nd=5.06168159698706e-07, # queries above err=[1], xi=-0.9413590912533942 fake x=-1.1227419242506558
# Total loss =  2367.6494163970447 ; Total_loss - Total_loss_real_X =  -0.2545976809174135 Total_loss_update =  0.0009970417431759415

# %%
import matplotlib.pyplot as plt


## plot distribution of fake_X and real_X
# plt.hist(fake_X, bins=100, density=True, alpha=0.6, color='blue', label='fake_X_after')
# plt.hist(fake_X_original, bins=100, density=True, alpha=0.6, color='green', label='fake_X_original')
# plt.hist(real_X, bins=100, density=True, alpha=0.6, color='red',label='real_X')

# plot fake_X, real_X, and fake_X_after
# initialize the x-axis to be # data points
x_axis = np.arange(start=1, stop=num_points+1, step=1) 
plt.scatter(x_axis, fake_X, s = np.full(len(fake_X),20),label="fake_X_after", color='deeppink')
plt.scatter(x_axis, fake_X_original, s = np.full(len(fake_X),20),label="fake_X_original", color='cornflowerblue')
plt.scatter(x_axis, real_X, s = np.full(len(fake_X),20),label="real_X",color='gold', alpha=0.4)

# plot the difference between fake_X_original and fake_X_after

plt.quiver(x_axis, fake_X_original, x_axis-x_axis, fake_X - fake_X_original, angles='xy', scale_units='xy', scale=1, color='black', alpha=1)

 

plt.legend()

plt.xlabel('coordinates of the data set')
plt.ylabel('data value')
# plt.grid(True)

# plt.grid(True)
plt.figure(figsize=(8, 40), dpi= 100)
plt.show()

# %%
print(epsilon)
abs(fake_X-real_X)
# Out:
# 50
# array([6.60767343e-03, 9.22130988e-01, 4.48945987e-01, 1.15945039e-02,
#        1.06507449e-01, 2.32817967e-01, 5.89514810e-01, 8.30328804e-01,
#        2.70439427e-01, 8.19567074e-01, 4.53638059e-01, 3.98696339e-01,
#        1.09056152e+00, 1.55022807e-02, 2.82444804e-01, 4.11557295e-01,
#        1.52148311e-01, 3.02415344e-01, 7.82786642e-01, 4.78176411e-01,
#        4.49790381e-01, 4.64763329e-02, 8.92515669e-01, 7.03869125e-01,
#        3.45291715e-01, 7.64634866e-01, 1.80819841e-01, 2.10655885e-01,
#        3.79935908e-01, 2.46658261e-01, 7.89517372e-01, 6.20785069e-02,
#        7.69634158e-01, 3.47022194e-01, 3.88629398e-01, 2.38604634e-02,
#        5.31452322e-01, 3.05075741e-01, 1.04837066e+00, 4.40038069e-01,
#        4.46323106e-01, 3.29322772e-01, 1.48683422e-01, 1.52741924e-01,
#        9.40643711e-01, 5.53420600e-01, 2.26915453e-01, 3.49266504e-01,
#        9.58401508e-01, 2.72031737e-01, 3.00012396e-01, 3.85180204e-01,
#        1.31256771e+00, 8.74590645e-03, 1.23756796e-01, 5.97099228e-01,
#        4.99712565e-02, 1.92752154e-01, 2.19236014e-01, 6.67943778e-01,
#        3.30760159e-01, 4.77022935e-01, 2.28151359e-01, 5.90621949e-01,
#        4.12564620e-01, 2.13721765e-01, 3.57629494e-01, 5.20771278e-02,
#        5.15720873e-01, 3.85680158e-01, 5.85953648e-04, 3.48199227e-01,
#        1.12480481e-01, 1.53836714e-01, 6.01308725e-01, 9.14135581e-02,
#        1.91790786e-01, 3.88246372e-01, 4.71245744e-01, 2.76363715e-01,
#        1.16045997e-01, 2.81621454e-01, 6.67868378e-01, 4.05122487e-01,
#        3.10843529e-01, 3.23025527e-02, 1.79410506e-01, 3.56549579e-01,
#        7.38891104e-01, 3.34803129e-01, 5.90477696e-01, 7.00466446e-01,
#        4.91140408e-01, 4.56715706e-01, 1.14660150e+00, 4.49133875e-01,
#        1.38401289e-01, 2.84802255e-01, 4.12830596e-01, 7.50839284e-02,
#        2.93814166e-01, 7.17745636e-02, 8.50842915e-02, 3.96355013e-01,
#        3.00915550e-02, 4.79263332e-01, 3.38144784e-02, 4.30761580e-01,
#        3.38453581e-01, 7.89433282e-01, 4.86931677e-01, 1.58970114e-01,
#        4.64988529e-01, 4.08154780e-03, 7.52579894e-01, 8.89493331e-02,
#        3.60053865e-01, 4.17798038e-01, 4.57877937e-01, 3.13208531e-02,
#        5.27171380e-02, 6.14222728e-01, 7.68925703e-01, 1.12680629e-01,
#        6.91703135e-01, 4.68667958e-01, 2.33569826e-01, 2.95394091e-01,
#        1.71699053e-01, 4.65113241e-01, 6.11015897e-02, 8.48455566e-01,
#        1.97888031e-01, 5.16350500e-03, 6.31587870e-01, 6.49970793e-01,
#        3.99657743e-01, 5.10547747e-02, 6.17943864e-01, 2.35388092e-02,
#        3.21454740e-01, 8.28693912e-02, 2.43995739e-01, 5.01327781e-01,
#        8.73824005e-02, 3.96176986e-01, 7.75281955e-02, 9.68863688e-01,
#        6.58877113e-01, 4.19927376e-01, 1.92086773e+00, 3.50435463e-01,
#        9.11174973e-01, 9.60014284e-01, 5.51501203e-02, 5.04826318e-01,
#        4.49097772e-01, 4.17199741e-01, 3.61762257e-02, 3.94801295e-01,
#        5.08494963e-01, 2.46314117e-01, 5.15205551e-01, 4.35258670e-01,
#        5.70472043e-02, 1.05001313e+00, 2.79977881e-01, 1.00212458e+00,
#        3.48343483e-01, 1.03546433e+00, 4.57162233e-01, 1.45869977e-02,
#        1.39779138e-01, 4.17523808e-01, 7.83362346e-02, 1.07930119e-01,
#        1.17159403e+00, 1.08675761e-01, 4.03242178e-01, 2.77509164e-01,
#        1.73130195e-01, 3.23058350e-01, 2.36685170e-01, 2.70063794e-01,
#        4.55835133e-01, 1.23744012e-01, 6.89871660e-01, 5.85195743e-01,
#        2.07883387e-01, 1.06066845e-01, 7.48547258e-01, 4.30529162e-01,
#        3.76252828e-01, 3.06562145e-01, 2.24547808e-01, 4.69379551e-01,
#        3.19980551e-02, 2.52342903e-02, 9.87484565e-02, 2.05941799e-01])

# %%
# ### stochastic gradient descent 
# #### COORDINATE DESCENT LOOP STARTS HERE ###
# #### In this loop, we do coordinate descent, NOT multivariate Newton's method ####

# # initialize number of coordinate descent iterations = 0
# num_iter_descent = 0

# x_coord_changed = np.full(num_points, False, dtype=bool)
# x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}


# # while we don't have |q(X) - noisy_output|<lambda/2 for all q, continue coordinate descent 
# while not np.all(error < Llambda/2):
    
#     # calculate the current total loss, which includes two copies of loss for each query function
#     total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
#     total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
#     total_loss = total_loss_plus + total_loss_minus 

#     ### compute the partial derivative of the loss function with respect to each coordinate 
#     query_loss_gradient = np.zeros(num_points) # initialize the partial derivative of the current query wrt each coordinate to be zero

#     # go thru all queries one by one, starting with q_0 all the way to q_{k-1}
#     current_q = 0

#     while current_q < k:
#         num_iter_q = 0 
#         x_coord_changed = np.full(num_points, False, dtype=bool)
#         x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}

#         sampled_queries_q = sampled_queries[current_q]
#         fake_output_q = fake_output[current_q]
#         real_data_noisy_output_q = real_data_noisy_output[current_q]

#         # we want to gradient descent on one query until it satisfies the error bound
#         while not error[current_q] < Llambda/2:

#             query_loss_plus = np.exp((fake_output_q-real_data_noisy_output_q)/Llambda-1)
#             query_loss_minus = np.exp((real_data_noisy_output_q-fake_output_q)/Llambda-1)
#             query_loss = query_loss_plus + query_loss_minus

#             for i in range(num_points):
#                 # fix xi    
#                 xi = fake_X[i]

#                 # calculate the dq_j/dx_i for all j = 1, ..., k
#                 # query_grad_wrt_xi_array = 2*xi*sampled_queries_q/num_points
#                 loss_gradient_plus = np.sum(2*sampled_queries_q*xi*np.exp((fake_output_q-real_data_noisy_output_q)/Llambda - 1)/(Llambda*num_points))
#                 loss_gradient_minus = np.sum(-2*sampled_queries_q*xi*np.exp(-(fake_output_q-real_data_noisy_output_q)/Llambda - 1)/(Llambda*num_points))
#                 query_loss_gradient[i] = loss_gradient_plus + loss_gradient_minus

#             # create a dictionary for query_loss_gradient
#             loss_gradient_dict = {i: query_loss_gradient[i] for i in range(len(query_loss_gradient))}


#             # find the coordinate with the max absolute value part_derivative 
#             filtered_loss_grad_dict = {k: v for k, v in loss_gradient_dict.items() if not x_coord_changed[k]}
#             x_coord_descent = max(filtered_loss_grad_dict, key=lambda k: abs(filtered_loss_grad_dict[k]))

        
            

#             # update x value at the coordinate x_coord_descent
#             # First, we calculate the 2nd derivative wrt x_coord_descent
#             xi = fake_X[x_coord_descent] 
#             # quadratic query

#             loss_hessian_wrt_chosen_xi_plus = (2*sampled_queries_q)/(Llambda*num_points)*np.exp((fake_output_q-real_data_noisy_output_q)/Llambda -1)*(1+2*sampled_queries_q*xi**2/(Llambda*num_points))
#             loss_hessian_wrt_chosen_xi_minus = -(2*sampled_queries_q)/(Llambda*num_points)*np.exp(-(fake_output_q-real_data_noisy_output_q)/Llambda -1)*(1-2*sampled_queries_q*xi**2/(Llambda*num_points))
#             loss_hessian_wrt_chosen_x_coord = loss_hessian_wrt_chosen_xi_plus + loss_hessian_wrt_chosen_xi_minus
#             # loss_hessian_wrt_chosen_x_coord = sampled_queries_q/num_points # linear queries

            
#             ### Backtracking Line Search Sub-routine ###
#             # Backtracking line search 
#             # initialize a step size, constants alpha1 and alpha2
#             t = 1
#             alpha1 = 0.2 # usually 0 < alpha1 < 0.5
#             alpha2 = 0.5 # usually 0 < alpha2 < 1

#             # initialize AG_condition = 0
#             AG_condition = 0

#             # make a copy of the curent fake_X
#             fake_X_copy_linesearch = copy.copy(fake_X)

#             while AG_condition == 0: 

#                 # calculate f(x+t*Delta x)
#                 fake_X_copy_linesearch[x_coord_descent] = xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
#                 # update fake_output_q 
#                 sum_fake_X_squared_linesearch = np.sum(np.square(fake_X_copy_linesearch))
#                 fake_output_q_linesearch = sampled_queries_q*sum_fake_X_squared_linesearch /num_points
#                 # fake_output_q_linesearch = sampled_queries_q*np.sum(fake_X_copy_linesearch) /num_points
#                 # loss_current_stepsize = np.sum(np.square(fake_output_q_linesearch-real_data_noisy_output_q))/Llambda
#                 loss_current_stepsize_plus = np.exp((fake_output_q_linesearch-real_data_noisy_output_q)/Llambda-1)
#                 loss_current_stepsize_minus = np.exp((real_data_noisy_output_q-fake_output_q_linesearch)/Llambda-1)
#                 loss_current_stepsize = loss_current_stepsize_plus + loss_current_stepsize_minus 

#                 print('loss_current', loss_current_stepsize)

#                 # calculate f(x)+alpha1*t*grad_f*Delta x
#                 loss_damped_stepsize = query_loss + alpha1*t*query_loss_gradient[x_coord_descent]*(- query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord)
#                 print('loss_dampened', loss_damped_stepsize)
                
#                 # if loss_current_stepsize > loss_damped_stepsize or -1>xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord or xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord>1:
#                 if loss_current_stepsize > loss_damped_stepsize:
#                     t = t* alpha2
                    
                    
#                     print("t = ", t)

#                 else: 
#                     AG_condition = 1 
#                     print("t = ", t)
#             ############



#             # update fake_X at coordinate = x_coord_descent using 2nd order Newton's method 
#             xi_update = - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
#             fake_X[x_coord_descent] = xi + xi_update

#             if fake_X[x_coord_descent] <= -1 or fake_X[x_coord_descent] >= 1:
#                 x_coord_changed[x_coord_descent] = True 
                
#             # if xi+xi_update <= 1 and xi+xi_update >= -1:
#             #     fake_X[x_coord_descent] = xi + xi_update
#             # # if the proposed update will overshoot, we skip this coordinate 
#             # else:
#             #     x_coord_changed[x_coord_descent] = True
            

#             # update fake_output
#             sum_fake_X_squared = np.sum(np.square(fake_X))
#             fake_output = sampled_queries*sum_fake_X_squared /num_points # quadratic query 
#             # fake_output_q = sampled_queries_q*np.sum(fake_X)/num_points # linear query


#             # update error
#             error = abs(fake_output-real_data_noisy_output)

#             # update total loss
#             total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
#             total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
#             total_loss = total_loss_plus + total_loss_minus 

#             # update query loss
#             query_loss_plus = np.exp((fake_output_q-real_data_noisy_output_q)/Llambda-1)
#             query_loss_minus = np.exp((real_data_noisy_output_q-fake_output_q)/Llambda-1)
#             query_loss = query_loss_plus + query_loss_minus

#             num_iter_q = num_iter_q + 1 
#             print(f"current_q={current_q},#iter_q={num_iter_q}, x_co={x_coord_descent}, query_loss={query_loss}, total_loss={total_loss}")

#         current_q = current_q + 1 
#     # print current progress
#     # print(f"#iter {num_iter_descent} x_co={x_coord_descent}, 1st={query_loss_gradient[x_coord_descent]}, 2nd={loss_hessian_wrt_chosen_x_coord}, # queries above err={sum(error>Llambda/2)}, xi={xi} fake x={fake_X[x_coord_descent]}")
#     # print('Total loss = ', total_loss)
    
#     num_iter_descent += 1
