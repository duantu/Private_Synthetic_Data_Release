# %%
# This code creates a (k, lambda, eta, beta)- base synopsis generator that is (epsilon,delta)-DP 



import numpy as np
import math
import sympy as sp
from itertools import combinations
import pandas as pd
import time
import copy


lower_bound = -1 # data lower bound
upper_bound = 1  # data upper bound
data_precision = 2 # data precision

n = 100
num_points = 2*n # number of data points
m = num_points*math.ceil(math.log2(((upper_bound - lower_bound)/10**(-data_precision)) +1)) # size of the domain universe

epsilon = 25
delta =  0.5 # DP parameter
eta = 0.001 # edge for boosting
beta = 0.4 # failure probability of the base synopsis

############## This line needs to be changed to k = # queries needed for generalization #####################
# k = math.ceil(2*((math.log(2/beta)+m)/(1-2*eta))) # number of query sample as demanded by Lemma 6.5 
k = 1000
#######################################################################################################

# Assume coefficient \in (0,1], changing one x_i can at most change 1*[(1+x_j)^2 - (-1+x_j)^2] = 4x_j <= 4.

# consider the following query:
# q(X) = (c_1x_1 + ... + c_nx_n)/n
rho = (upper_bound-lower_bound)/num_points # l_1 sensitivity 




# Llambda = 0.01 # parameter lambda, the amount of query output error tolerated 
# epsilon = (math.log(2*k/beta)*4*rho*math.sqrt(2*k*math.log(1/delta)))/Llambda
# epsilon = round(epsilon,2)+10**(-data_precision) # round epsilon up to 2 decimal points 

Llambda = (math.log(2*k/beta)*4*rho*math.sqrt(2*k*math.log(1/delta)))/epsilon
Llambda = round(Llambda,2)+10**(-data_precision) # round epsilon up to 2 decimal points 

# to study just one query, set k=1
# k = 2

tau = 0.001 # total loss stopping criterion

# %%
print(k)
print(epsilon)
print(Llambda)
# Out:
# 1000
# 25
# 0.52

# %%
import random 
# decide on a set of real data 
real_X = np.random.choice(np.arange(lower_bound, upper_bound+0.01, 0.01), num_points, replace=False)
# sum_real_X_squared = np.sum(np.square(real_X))

# initialize the synopsis to be some arbirary set of data, say from the standard normal
# for verification purposes, if fake_X = real_X, the initial error should be the same as the added laplace noise
# fake_X = real_X 
fake_X = np.random.randn(num_points)
# fake_X = np.ones(num_points)*(-0.9)


# fake_X_normalizer = np.max(np.abs(fake_X))
# for idx, i in enumerate(fake_X):
#     if np.abs(i)>=1 :
#         fake_X[idx] = i/fake_X_normalizer
# # fake_X = np.random.uniform(low=lower_bound, high=upper_bound, size=num_points)

fake_X_copy = copy.copy(fake_X) # save a copy of fake_X
fake_X_original = copy.copy(fake_X)
# sum_fake_X_squared = np.sum(np.square(fake_X_copy))



all_coeff = np.round(1-np.linspace(0,100,100, endpoint=False)/100,2)
# sampled_queries = np.array(random.sample(list(all_coeff),k))
sampled_queries = np.random.choice(all_coeff, size=(k, num_points), replace=True)

# %%
# np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=2).reshape(-1,1)
sampled_queries.shape
# Out:
# (1000, 200)

# %%
# fake_X = copy.copy(fake_X_original)



#### BOOSTING LOOP STARTS ####

# initialize all-zero arrays to store noiselss query output, noisy output, and laplace noise  
real_output = np.zeros(k)
real_data_noisy_output = np.zeros(k)
lap_noise = np.zeros(k)
fake_output = np.zeros(k)
error = np.zeros(k) # store |q(X) - noisy_output| for each q



# # for each query, compute its real output, noisy output, and initial error
real_output = np.dot(sampled_queries, real_X.reshape(-1,1))/num_points
lap_noise = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=k).reshape(-1,1)

# save a copy of lap_noise
lap_noise_copy = copy.copy(lap_noise)
lap_noise_copy = copy.copy(lap_noise) 

real_data_noisy_output = real_output+lap_noise

fake_output = np.dot(sampled_queries, fake_X.reshape(-1,1))/num_points

error = abs(fake_output - real_data_noisy_output)






# for index, item in enumerate(sampled_queries):
    
#     # real output 
#     real_output[index] = item*sum_real_X_squared/num_points # quadratic query
#     # real_output[index] = item*np.sum(real_X)/num_points # linear query

    
#     # # compute noisy output on the real data
#     # k_actual = math.ceil(2*((math.log(2/beta)+m)/(1-2*eta))) # number of query sample as demanded by Lemma 6.5 
#     # lap_noise[index] = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=None) 
#     # artificially tune the lap noise down by a half
#     lap_noise[index] = np.random.laplace(loc=0.0, scale=rho*(2*math.sqrt(2*k*math.log(1/delta))/epsilon), size=None)
#     # lap_noise[index] = 0


#     real_data_noisy_output[index] = real_output[index] + lap_noise[index]

#     # # compute query output on fake data 
#     fake_output[index] = item*sum_fake_X_squared/num_points # quadratic query
#     # fake_output[index] = item*np.sum(fake_X)/num_points # linear query

#     # # calculate initial error
#     # # notice that this is |q(X) - real_data_noisy_output|
#     error[index] = abs(fake_output[index]-real_data_noisy_output[index])

# %%
print("# lap noise above lambda/2 = ",sum(abs(lap_noise)>=Llambda/2) )

# calculate total loss on real_X
total_loss_plus = np.sum(np.exp((real_output-real_data_noisy_output)/Llambda-1))
total_loss_minus = np.sum(np.exp((real_data_noisy_output-real_output)/Llambda-1))
total_loss = total_loss_plus + total_loss_minus 
total_loss_real_X = copy.copy(total_loss)
print("Total loss of real_output: ", total_loss_real_X)
print("# queries = ", k, "# queries above lambda/2 error = ",sum(error>Llambda/2))
# Out:
# # lap noise above lambda/2 =  [0]
# Total loss of real_output:  738.3023420834887
# # queries =  1000 # queries above lambda/2 error =  [1]

# %%
# query_grad_wrt_xi_array = sampled_queries[:,0].reshape(-1,1)/num_points
# aaa = query_grad_wrt_xi_array*np.exp((fake_output-real_data_noisy_output)/Llambda - 1)/Llambda
# aaa

# %%
## NON-STOCHASTIC 
#### COORDINATE DESCENT LOOP STARTS HERE ###
#### In this loop, we do coordinate descent, NOT multivariate Newton's method ####

# initialize number of coordinate descent iterations = 0
num_iter_descent = 0

x_coord_changed = np.full(num_points, False, dtype=bool)
x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}


# while we don't have |q(X) - noisy_output|<lambda/2 for all q, continue coordinate descent 
# while not np.all(error < Llambda/2) and sum(error>Llambda/2)>sum(abs(lap_noise)>=Llambda/2) :
while (num_iter_descent == 0 or  total_loss_update > tau) :
    
    # calculate the current total loss, which includes two copies of loss for each query function
    total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
    total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
    total_loss = total_loss_plus + total_loss_minus 

    ### compute the partial derivative of the loss function with respect to each coordinate 
    loss_gradient = np.zeros(num_points) # initialize the partial derivative of each coordinate to be zero
    
    # fix xi    
    for i in range(num_points):
        xi = fake_X[i]

        # calculate the dq_j/dx_i for all j = 1, ..., k
        query_grad_wrt_xi_array = sampled_queries[:,i].reshape(-1,1)/num_points
        loss_gradient_plus = np.sum(query_grad_wrt_xi_array*np.exp((fake_output-real_data_noisy_output)/Llambda - 1)/Llambda)
        loss_gradient_minus = np.sum(-query_grad_wrt_xi_array*np.exp(-(fake_output-real_data_noisy_output)/Llambda - 1)/Llambda)
        loss_gradient[i] = loss_gradient_plus + loss_gradient_minus

    # create a dictionary for loss_gradient
    loss_gradient_dict = {i: loss_gradient[i] for i in range(len(loss_gradient))}


    # find the coordinate with the max absolute value part_derivative 
    filtered_loss_grad_dict = {k: v for k, v in loss_gradient_dict.items() if not x_coord_changed[k]}
    x_coord_descent = max(filtered_loss_grad_dict, key=lambda k: abs(filtered_loss_grad_dict[k]))

    
        

    # update x value at the coordinate x_coord_descent
    # First, we calculate the 2nd derivative wrt x_coord_descent
    xi = fake_X[x_coord_descent] 
    # quadratic query
    query_grad_wrt_x_coord_descent = sampled_queries[:,x_coord_descent].reshape(-1,1)/num_points
    loss_hessian_wrt_chosen_xi_plus = np.sum((query_grad_wrt_x_coord_descent/num_points)**2*np.exp((fake_output-real_data_noisy_output)/Llambda -1))
    loss_hessian_wrt_chosen_xi_minus = np.sum((query_grad_wrt_x_coord_descent/num_points)**2*np.exp(-(fake_output-real_data_noisy_output)/Llambda -1))
    loss_hessian_wrt_chosen_x_coord = loss_hessian_wrt_chosen_xi_plus + loss_hessian_wrt_chosen_xi_minus
    # loss_hessian_wrt_chosen_x_coord = sampled_queries/num_points # linear queries

    
    ### Backtracking Line Search Sub-routine ###
    # Backtracking line search 
    # initialize a step size, constants alpha1 and alpha2
    t = 1
    alpha1 = 0.05 # usually 0 < alpha1 < 0.5
    alpha2 = 0.5 # usually 0 < alpha2 < 1

    # initialize AG_condition = 0
    AG_condition = 0

    # make a copy of the curent fake_X
    fake_X_copy_linesearch = copy.copy(fake_X)

    while AG_condition == 0: 

        # calculate f(x+t*Delta x)
        fake_X_copy_linesearch[x_coord_descent] = xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord

        # update fake_output 
        fake_output_linesearch = np.dot(sampled_queries, fake_X_copy_linesearch.reshape(-1,1))/num_points

        
        # fake_output_linesearch = sampled_queries*np.sum(fake_X_copy_linesearch) /num_points
        # loss_current_stepsize = np.sum(np.square(fake_output_linesearch-real_data_noisy_output))/Llambda
        loss_current_stepsize_plus = np.sum(np.exp((fake_output_linesearch-real_data_noisy_output)/Llambda-1))
        loss_current_stepsize_minus = np.sum(np.exp((real_data_noisy_output-fake_output_linesearch)/Llambda-1))
        loss_current_stepsize = loss_current_stepsize_plus + loss_current_stepsize_minus 

        # print('loss_current', loss_current_stepsize)

        # calculate f(x)+alpha1*t*grad_f*Delta x
        loss_damped_stepsize = total_loss + alpha1*t*loss_gradient[x_coord_descent]*(- loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord)
        # print('loss_dampened', loss_damped_stepsize)
        
        # if loss_current_stepsize > loss_damped_stepsize or -1>xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord or xi - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord>1:
        if loss_current_stepsize > loss_damped_stepsize:
            t = t* alpha2
            
            
            # print("t = ", t)

        else: 
            AG_condition = 1 
            print("t = ", t)
    ############



    # update fake_X at coordinate = x_coord_descent using 2nd order Newton's method 
    xi_update = - t*loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
    fake_X[x_coord_descent] = xi + xi_update

    # if fake_X[x_coord_descent] <= 3*lower_bound or fake_X[x_coord_descent] >= 3*upper_bound:
    #     x_coord_changed[x_coord_descent] = True 
        
    # if xi+xi_update <= 1 and xi+xi_update >= -1:
    #     fake_X[x_coord_descent] = xi + xi_update
    # # if the proposed update will overshoot, we skip this coordinate 
    # else:
    #     x_coord_changed[x_coord_descent] = True
    

    # update fake_output
    fake_output = np.dot(sampled_queries, fake_X.reshape(-1,1))/num_points 


    # update error
    error = abs(fake_output-real_data_noisy_output)

    # update total loss
    total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
    total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
    total_loss_after = total_loss_plus + total_loss_minus 

    total_loss_update = total_loss-total_loss_after 

    # print current progress
    print(f"#iter {num_iter_descent} x_co={x_coord_descent}, 1st={loss_gradient[x_coord_descent]}, 2nd={loss_hessian_wrt_chosen_x_coord}, # queries above err={sum(error>Llambda/2)}, xi={xi} fake x={fake_X[x_coord_descent]}")
    print('Total loss = ', total_loss,"; Total_loss - Total_loss_real_X = ", total_loss-total_loss_real_X, "Total_loss_update = ", total_loss_update)
    
    num_iter_descent += 1
# Out:
# t =  7.62939453125e-06
# #iter 0 x_co=116, 1st=0.44923728607672286, 2nd=1.6319139385009997e-07, # queries above err=[0], xi=1.092656375579269 fake x=-19.90972869367015
# Total loss =  743.9860428168092 ; Total_loss - Total_loss_real_X =  5.6837007333205065 Total_loss_update =  4.1339254871029425
# t =  7.62939453125e-06
# #iter 1 x_co=58, 1st=0.06048107145337944, 2nd=1.5803468327858076e-07, # queries above err=[0], xi=0.5776373374751158 fake x=-2.3421897929855184
# Total loss =  739.8521173297063 ; Total_loss - Total_loss_real_X =  1.549775246217564 Total_loss_update =  0.07695142514592135
# t =  7.62939453125e-06
# #iter 2 x_co=116, 1st=-0.10622455984867085, 2nd=1.6214276232419692e-07, # queries above err=[0], xi=-19.90972869367015 fake x=-14.911484773454504
# Total loss =  739.7751659045604 ; Total_loss - Total_loss_real_X =  1.4728238210716427 Total_loss_update =  0.23147091731141245
# t =  7.62939453125e-06
# #iter 3 x_co=12, 1st=0.09760439916414887, 2nd=1.5946624286129064e-07, # queries above err=[0], xi=1.2358683214397923 fake x=-3.433850208623233
# Total loss =  739.543694987249 ; Total_loss - Total_loss_real_X =  1.2413529037602302 Total_loss_update =  0.1986494007970805
# t =  7.62939453125e-06
# #iter 4 x_co=116, 1st=-0.07125886252562741, 2nd=1.6202122954718072e-07, # queries above err=[0], xi=-14.911484773454504 fake x=-11.555986376265743
# Total loss =  739.3450455864519 ; Total_loss - Total_loss_real_X =  1.0427035029631497 Total_loss_update =  0.10420892697732143
# t =  7.62939453125e-06
# #iter 5 x_co=40, 1st=0.07489290003443272, 2nd=1.5053351148172078e-07, # queries above err=[0], xi=1.7716958140304677 fake x=-2.0240535598326224
# Total loss =  739.2408366594746 ; Total_loss - Total_loss_real_X =  0.9384945759858283 Total_loss_update =  0.12388788727878364
# t =  7.62939453125e-06
# #iter 6 x_co=116, 1st=-0.056012399637082044, 2nd=1.6196414157391828e-07, # queries above err=[0], xi=-11.555986376265743 fake x=-8.917496823451298
# Total loss =  739.1169487721958 ; Total_loss - Total_loss_real_X =  0.8146066887070447 Total_loss_update =  0.06440145955775733
# t =  7.62939453125e-06
# #iter 7 x_co=9, 1st=0.05461797438038851, 2nd=1.523438343981827e-07, # queries above err=[0], xi=1.7669655556045936 fake x=-0.9683080883326467
# Total loss =  739.052547312638 ; Total_loss - Total_loss_real_X =  0.7502052291492873 Total_loss_update =  0.06509899562593091
# t =  7.62939453125e-06
# #iter 8 x_co=116, 1st=-0.04106687716080648, 2nd=1.6192782626187426e-07, # queries above err=[0], xi=-8.917496823451298 fake x=-6.982589060782577
# Total loss =  738.9874483170121 ; Total_loss - Total_loss_real_X =  0.6851062335233564 Total_loss_update =  0.03462360478113169
# t =  7.62939453125e-06
# #iter 9 x_co=62, 1st=0.04173962461455294, 2nd=1.5451925347995833e-07, # queries above err=[0], xi=2.5850143579919225 fake x=0.5241186663621291
# Total loss =  738.952824712231 ; Total_loss - Total_loss_real_X =  0.6504826287422247 Total_loss_update =  0.03748183181016884
# t =  7.62939453125e-06
# #iter 10 x_co=163, 1st=-0.03369892535816299, 2nd=1.5595886565588253e-07, # queries above err=[0], xi=-2.0358343874287113 fake x=-0.38730741363128973
# Total loss =  738.9153428804208 ; Total_loss - Total_loss_real_X =  0.6130007969320559 Total_loss_update =  0.024205771825677402
# t =  7.62939453125e-06
# #iter 11 x_co=149, 1st=0.03535065165448481, 2nd=1.530998805369515e-07, # queries above err=[0], xi=3.4221791352822826 fake x=1.6605574575713349
# Total loss =  738.8911371085951 ; Total_loss - Total_loss_real_X =  0.5887950251063785 Total_loss_update =  0.027134792014294362
# /tmp/ipykernel_1807498/2955271590.py:81: RuntimeWarning: overflow encountered in exp
#   loss_current_stepsize_minus = np.sum(np.exp((real_data_noisy_output-fake_output_linesearch)/Llambda-1))
# /tmp/ipykernel_1807498/2955271590.py:80: RuntimeWarning: overflow encountered in exp
#   loss_current_stepsize_plus = np.sum(np.exp((fake_output_linesearch-real_data_noisy_output)/Llambda-1))
# t =  7.62939453125e-06
# #iter 12 x_co=69, 1st=-0.033815384516049374, 2nd=1.604349653987238e-07, # queries above err=[0], xi=-1.8718516534333933 fake x=-0.26378006468909043
# Total loss =  738.8640023165808 ; Total_loss - Total_loss_real_X =  0.5616602330920841 Total_loss_update =  0.0236932214825174
# t =  7.62939453125e-06
# #iter 13 x_co=60, 1st=0.03314227423663785, 2nd=1.5375992529063878e-07, # queries above err=[0], xi=1.0827605894033951 fake x=-0.5617217770925707
# Total loss =  738.8403090950983 ; Total_loss - Total_loss_real_X =  0.5379670116095667 Total_loss_update =  0.02374740630989436
# t =  7.62939453125e-06
# #iter 14 x_co=132, 1st=-0.03353308748507211, 2nd=1.5689993492411579e-07, # queries above err=[0], xi=-0.35268882359172704 fake x=1.2778864497394689
# Total loss =  738.8165616887884 ; Total_loss - Total_loss_real_X =  0.5142196052996724 Total_loss_update =  0.023824222787425242
# t =  7.62939453125e-06
# #iter 15 x_co=157, 1st=0.03276416324002707, 2nd=1.5777081055829425e-07, # queries above err=[0], xi=2.0136811971010613 fake x=0.42928971834850804
# Total loss =  738.792737466001 ; Total_loss - Total_loss_real_X =  0.4903953825122471 Total_loss_update =  0.02261865668322116
# t =  7.62939453125e-06
# #iter 16 x_co=116, 1st=-0.03289154646250125, 2nd=1.6188765467274077e-07, # queries above err=[0], xi=-6.982589060782577 fake x=-5.432485779512316
# Total loss =  738.7701188093178 ; Total_loss - Total_loss_real_X =  0.46777672582902596 Total_loss_update =  0.022215211631305465
# t =  7.62939453125e-06
# #iter 17 x_co=151, 1st=0.03244336350682797, 2nd=1.5804131614462252e-07, # queries above err=[0], xi=1.2048574725192729 fake x=-0.3613356354136068
# Total loss =  738.7479035976864 ; Total_loss - Total_loss_real_X =  0.4455615141977205 Total_loss_update =  0.022139982378803325
# t =  7.62939453125e-06
# #iter 18 x_co=169, 1st=-0.030892232329049918, 2nd=1.5340131330044106e-07, # queries above err=[0], xi=-1.1105890793927307 fake x=0.4258321110031682
# Total loss =  738.7257636153076 ; Total_loss - Total_loss_real_X =  0.4234215318189172 Total_loss_update =  0.02068077359263043
# t =  7.62939453125e-06
# #iter 19 x_co=147, 1st=0.03070681001680642, 2nd=1.5252278120652285e-07, # queries above err=[0], xi=0.785617204680559 fake x=-0.7503787072818471
# Total loss =  738.705082841715 ; Total_loss - Total_loss_real_X =  0.40274075822628674 Total_loss_update =  0.020550912108092234
# t =  7.62939453125e-06
# #iter 20 x_co=76, 1st=-0.030323884382873034, 2nd=1.5012107704665427e-07, # queries above err=[0], xi=-1.2869203392627573 fake x=0.25418822609245595
# Total loss =  738.6845319296069 ; Total_loss - Total_loss_real_X =  0.3821898461181945 Total_loss_update =  0.020362193514756655
# t =  7.62939453125e-06
# #iter 21 x_co=104, 1st=0.030160367928264264, 2nd=1.6369392111829325e-07, # queries above err=[0], xi=1.7134020661916611 fake x=0.30769717159082943
# Total loss =  738.6641697360922 ; Total_loss - Total_loss_real_X =  0.36182765260343785 Total_loss_update =  0.018472555489211118
# t =  7.62939453125e-06
# #iter 22 x_co=115, 1st=-0.02719779592261018, 2nd=1.570163559542215e-07, # queries above err=[0], xi=-0.06813699976657872 fake x=1.253398672189237
# Total loss =  738.645697180603 ; Total_loss - Total_loss_real_X =  0.34335509711422674 Total_loss_update =  0.015660790157085103
# t =  7.62939453125e-06
# #iter 23 x_co=117, 1st=0.027546010673433097, 2nd=1.532068950936687e-07, # queries above err=[0], xi=1.1464353560044471 fake x=-0.2253004464942321
# Total loss =  738.6300363904459 ; Total_loss - Total_loss_real_X =  0.32769430695714163 Total_loss_update =  0.016463673122871114
# t =  7.62939453125e-06
# #iter 24 x_co=197, 1st=-0.02726088469112642, 2nd=1.5557226099429402e-07, # queries above err=[0], xi=0.06551327149859075 fake x=1.4024099859272963
# Total loss =  738.613572717323 ; Total_loss - Total_loss_real_X =  0.3112306338342705 Total_loss_update =  0.015879565969271425
# t =  7.62939453125e-06
# #iter 25 x_co=164, 1st=0.02525017724590417, 2nd=1.5591064404717932e-07, # queries above err=[0], xi=0.46696764573264027 fake x=-0.7686347428682277
# Total loss =  738.5976931513537 ; Total_loss - Total_loss_real_X =  0.2953510678649991 Total_loss_update =  0.01359373190871338
# t =  7.62939453125e-06
# #iter 26 x_co=170, 1st=-0.025142148389340147, 2nd=1.595002871400658e-07, # queries above err=[0], xi=-1.4146109082306395 fake x=-0.2119837978665009
# Total loss =  738.584099419445 ; Total_loss - Total_loss_real_X =  0.2817573359562857 Total_loss_update =  0.013174447446999693
# t =  7.62939453125e-06
# #iter 27 x_co=187, 1st=0.024113913184185876, 2nd=1.6407601399562258e-07, # queries above err=[0], xi=1.5444109467941116 fake x=0.42313457681005473
# Total loss =  738.570924971998 ; Total_loss - Total_loss_real_X =  0.268582888509286 Total_loss_update =  0.01178083996364876
# t =  7.62939453125e-06
# #iter 28 x_co=81, 1st=-0.02401015109483362, 2nd=1.5584825162261497e-07, # queries above err=[0], xi=-0.6412135177269986 fake x=0.5341792990046608
# Total loss =  738.5591441320344 ; Total_loss - Total_loss_real_X =  0.25680204854563726 Total_loss_update =  0.012296336928784513
# t =  7.62939453125e-06
# #iter 29 x_co=53, 1st=0.024509115030245887, 2nd=1.596117354621533e-07, # queries above err=[0], xi=0.7430513328973404 fake x=-0.4284772369544275
# Total loss =  738.5468477951056 ; Total_loss - Total_loss_real_X =  0.24450571161685275 Total_loss_update =  0.012510626574794514
# t =  7.62939453125e-06
# #iter 30 x_co=163, 1st=-0.023206847542493136, 2nd=1.5586878186062587e-07, # queries above err=[0], xi=-0.38730741363128973 fake x=0.7486108479649756
# Total loss =  738.5343371685308 ; Total_loss - Total_loss_real_X =  0.23199508504205824 Total_loss_update =  0.011485695050851064
# t =  7.62939453125e-06
# #iter 31 x_co=155, 1st=0.023251792345151623, 2nd=1.5407854997274946e-07, # queries above err=[0], xi=-0.07485157123043547 fake x=-1.226193515915371
# Total loss =  738.5228514734799 ; Total_loss - Total_loss_real_X =  0.22050938999120717 Total_loss_update =  0.011664201172493449
# t =  7.62939453125e-06
# #iter 32 x_co=15, 1st=-0.023234543231252403, 2nd=1.4981121599256449e-07, # queries above err=[0], xi=-2.5019621021677785 fake x=-1.3187029190008324
# Total loss =  738.5111872723074 ; Total_loss - Total_loss_real_X =  0.20884518881871372 Total_loss_update =  0.01197867894245519
# t =  7.62939453125e-06
# #iter 33 x_co=22, 1st=0.023094885299212553, 2nd=1.5777677763697516e-07, # queries above err=[0], xi=-0.7846813204329058 fake x=-1.9014489096853158
# Total loss =  738.499208593365 ; Total_loss - Total_loss_real_X =  0.19686650987625853 Total_loss_update =  0.011237561850293787
# t =  7.62939453125e-06
# #iter 34 x_co=6, 1st=-0.02180029470357714, 2nd=1.5978466002596922e-07, # queries above err=[0], xi=-1.3355876845569288 fake x=-0.2946676790690561
# Total loss =  738.4879710315147 ; Total_loss - Total_loss_real_X =  0.18562894802596475 Total_loss_update =  0.009887113299214434
# t =  7.62939453125e-06
# #iter 35 x_co=139, 1st=0.02142346973184206, 2nd=1.5828758916693472e-07, # queries above err=[0], xi=0.08559558741342531 fake x=-0.9470065494486035
# Total loss =  738.4780839182155 ; Total_loss - Total_loss_real_X =  0.1757418347267503 Total_loss_update =  0.009638642323466229
# t =  7.62939453125e-06
# #iter 36 x_co=57, 1st=-0.021104890872465587, 2nd=1.5925950014913656e-07, # queries above err=[0], xi=-0.9961680425298519 fake x=0.014870789403151341
# Total loss =  738.468445275892 ; Total_loss - Total_loss_real_X =  0.16610319240328408 Total_loss_update =  0.009296957899096014
# t =  7.62939453125e-06
# #iter 37 x_co=118, 1st=0.02053246902141126, 2nd=1.673081000135889e-07, # queries above err=[0], xi=2.1144110189807557 fake x=1.1781126159010968
# Total loss =  738.4591483179929 ; Total_loss - Total_loss_real_X =  0.15680623450418807 Total_loss_update =  0.008376220246645971
# t =  7.62939453125e-06
# #iter 38 x_co=122, 1st=-0.01908527460851417, 2nd=1.532423432122718e-07, # queries above err=[0], xi=-1.1210461153166906 fake x=-0.17085776219353133
# Total loss =  738.4507720977463 ; Total_loss - Total_loss_real_X =  0.1484300142575421 Total_loss_update =  0.007901307010570235
# t =  7.62939453125e-06
# #iter 39 x_co=19, 1st=0.019912462648430163, 2nd=1.5759137093711767e-07, # queries above err=[0], xi=1.2237216411839527 fake x=0.25970925439995596
# Total loss =  738.4428707907357 ; Total_loss - Total_loss_real_X =  0.14052870724697186 Total_loss_update =  0.00836376795268734
# t =  7.62939453125e-06
# #iter 40 x_co=13, 1st=-0.019505737765978193, 2nd=1.5541380709299461e-07, # queries above err=[0], xi=-1.2960553120955391 fake x=-0.3385022360634763
# Total loss =  738.434507022783 ; Total_loss - Total_loss_real_X =  0.13216493929428452 Total_loss_update =  0.008138014028077123
# t =  7.62939453125e-06
# #iter 41 x_co=55, 1st=0.01980692316103405, 2nd=1.6012090066838278e-07, # queries above err=[0], xi=1.7150168854173014 fake x=0.7712623186187582
# Total loss =  738.4263690087549 ; Total_loss - Total_loss_real_X =  0.1240269252662074 Total_loss_update =  0.00814455017336968
# t =  7.62939453125e-06
# #iter 42 x_co=69, 1st=-0.019503267821351145, 2nd=1.603310427359625e-07, # queries above err=[0], xi=-0.26378006468909043 fake x=0.664288026920376
# Total loss =  738.4182244585816 ; Total_loss - Total_loss_real_X =  0.11588237509283772 Total_loss_update =  0.007886356660947058
# t =  7.62939453125e-06
# #iter 43 x_co=24, 1st=0.019382695440682163, 2nd=1.5219534556730876e-07, # queries above err=[0], xi=0.9329608135807276 fake x=-0.03867356882964179
# Total loss =  738.4103381019206 ; Total_loss - Total_loss_real_X =  0.10799601843189066 Total_loss_update =  0.008205566191008984
# t =  7.62939453125e-06
# #iter 44 x_co=142, 1st=-0.019387600506389324, 2nd=1.5515112587112687e-07, # queries above err=[0], xi=-0.8212021404251316 fake x=0.1321628606150128
# Total loss =  738.4021325357296 ; Total_loss - Total_loss_real_X =  0.09979045224088168 Total_loss_update =  0.008053325857758864
# t =  7.62939453125e-06
# #iter 45 x_co=37, 1st=0.019011519806840793, 2nd=1.591522363813595e-07, # queries above err=[0], xi=2.107064410013959 fake x=1.1956955939484213
# Total loss =  738.3940792098718 ; Total_loss - Total_loss_real_X =  0.09173712638312281 Total_loss_update =  0.007549196806735381
# t =  7.62939453125e-06
# #iter 46 x_co=195, 1st=-0.01863593238125505, 2nd=1.523472182105479e-07, # queries above err=[0], xi=-1.4218572180640883 fake x=-0.4885885816929646
# Total loss =  738.3865300130651 ; Total_loss - Total_loss_real_X =  0.08418792957638743 Total_loss_update =  0.007577870506906947
# t =  7.62939453125e-06
# #iter 47 x_co=78, 1st=0.018212333606927977, 2nd=1.535224654259943e-07, # queries above err=[0], xi=0.9583489979249626 fake x=0.053275736911072236
# Total loss =  738.3789521425582 ; Total_loss - Total_loss_real_X =  0.07661005906948049 Total_loss_update =  0.007181881849078309
# t =  7.62939453125e-06
# #iter 48 x_co=179, 1st=-0.018289743711724205, 2nd=1.586311948282085e-07, # queries above err=[0], xi=-0.3310997219775387 fake x=0.5485486397668764
# Total loss =  738.3717702607091 ; Total_loss - Total_loss_real_X =  0.06942817722040218 Total_loss_update =  0.007009817146126807
# t =  7.62939453125e-06
# #iter 49 x_co=157, 1st=0.017670751236446902, 2nd=1.5768020708507573e-07, # queries above err=[0], xi=0.42928971834850804 fake x=-0.42571380643559575
# Total loss =  738.364760443563 ; Total_loss - Total_loss_real_X =  0.06241836007427537 Total_loss_update =  0.006582836091979516
# t =  7.62939453125e-06
# #iter 50 x_co=132, 1st=-0.017514117884526392, 2nd=1.5679731612446702e-07, # queries above err=[0], xi=1.2778864497394689 fake x=2.13008289359826
# Total loss =  738.358177607471 ; Total_loss - Total_loss_real_X =  0.055835523982295854 Total_loss_update =  0.006503035740706764
# t =  7.62939453125e-06
# #iter 51 x_co=2, 1st=0.0171939162568997, 2nd=1.6025016029678528e-07, # queries above err=[0], xi=0.44635294802757225 fake x=-0.37223700169987634
# Total loss =  738.3516745717303 ; Total_loss - Total_loss_real_X =  0.04933248824158909 Total_loss_update =  0.006132422100563417
# t =  7.62939453125e-06
# #iter 52 x_co=169, 1st=-0.016705818734285893, 2nd=1.5331428185293463e-07, # queries above err=[0], xi=0.4258321110031682 fake x=1.2571655037635043
# Total loss =  738.3455421496298 ; Total_loss - Total_loss_real_X =  0.04320006614102567 Total_loss_update =  0.006051090671121528
# t =  7.62939453125e-06
# #iter 53 x_co=191, 1st=0.016988335878135308, 2nd=1.5759080925580463e-07, # queries above err=[0], xi=2.1021467755152163 fake x=1.2796957870613346
# Total loss =  738.3394910589586 ; Total_loss - Total_loss_real_X =  0.037148975469904144 Total_loss_update =  0.006087658046567412
# t =  7.62939453125e-06
# #iter 54 x_co=89, 1st=-0.01728009626369409, 2nd=1.580516188505619e-07, # queries above err=[0], xi=-0.929893025972744 fake x=-0.09575622375274873
# Total loss =  738.3334034009121 ; Total_loss - Total_loss_real_X =  0.031061317423336732 Total_loss_update =  0.006280186064373083
# t =  7.62939453125e-06
# #iter 55 x_co=85, 1st=0.017039996957556536, 2nd=1.575564566543616e-07, # queries above err=[0], xi=-0.2442033306403616 fake x=-1.0693352380283003
# Total loss =  738.3271232148477 ; Total_loss - Total_loss_real_X =  0.02478113135896365 Total_loss_update =  0.0061260872837465286
# t =  7.62939453125e-06
# #iter 56 x_co=116, 1st=-0.01678202617612068, 2nd=1.6179783204601989e-07, # queries above err=[0], xi=-5.432485779512316 fake x=-4.641148237393876
# Total loss =  738.3209971275639 ; Total_loss - Total_loss_real_X =  0.01865504407521712 Total_loss_update =  0.005786225694919267
# t =  7.62939453125e-06
# #iter 57 x_co=161, 1st=0.016559999909985024, 2nd=1.4910686176238313e-07, # queries above err=[0], xi=-0.37533573880173693 fake x=-1.2226661115117483
# Total loss =  738.315210901869 ; Total_loss - Total_loss_real_X =  0.012868818380297853 Total_loss_update =  0.006113684811680287
# t =  7.62939453125e-06
# #iter 58 x_co=3, 1st=-0.0174314125024424, 2nd=1.5328489336924646e-07, # queries above err=[0], xi=-1.4976848322095682 fake x=-0.6300773315947755
# Total loss =  738.3090972170573 ; Total_loss - Total_loss_real_X =  0.006755133568617566 Total_loss_update =  0.006589366814978348
# t =  7.62939453125e-06
# #iter 59 x_co=68, 1st=0.01675914503142284, 2nd=1.6105701913609826e-07, # queries above err=[0], xi=0.38136491380073256 fake x=-0.4125286410223298
# Total loss =  738.3025078502424 ; Total_loss - Total_loss_real_X =  0.00016576675363921822 Total_loss_update =  0.005796965325998826
# t =  7.62939453125e-06
# #iter 60 x_co=126, 1st=-0.015809981478698276, 2nd=1.4967032238649843e-07, # queries above err=[0], xi=-2.575104580947259 fake x=-1.769196072771122
# Total loss =  738.2967108849164 ; Total_loss - Total_loss_real_X =  -0.005631198572359608 Total_loss_update =  0.005551456769580909
# t =  7.62939453125e-06
# #iter 61 x_co=162, 1st=0.016333113728779658, 2nd=1.5758510969888936e-07, # queries above err=[0], xi=-0.11807008432067853 fake x=-0.9088286071198289
# Total loss =  738.2911594281468 ; Total_loss - Total_loss_real_X =  -0.011182655341940517 Total_loss_update =  0.0056273280354162125
# t =  7.62939453125e-06
# #iter 62 x_co=77, 1st=-0.01612206615151801, 2nd=1.5097710329158788e-07, # queries above err=[0], xi=-0.5658643809448123 fake x=0.248839310192277
# Total loss =  738.2855321001114 ; Total_loss - Total_loss_real_X =  -0.01680998337735673 Total_loss_update =  0.005722809895814862
# t =  7.62939453125e-06
# #iter 63 x_co=151, 1st=0.016045157956358302, 2nd=1.579341953374761e-07, # queries above err=[0], xi=-0.3613356354136068 fake x=-1.1364359238831472
# Total loss =  738.2798092902156 ; Total_loss - Total_loss_real_X =  -0.022532793273171592 Total_loss_update =  0.005418647602027704
# t =  7.62939453125e-06
# #iter 64 x_co=5, 1st=-0.015395729209942921, 2nd=1.5646789072826378e-07, # queries above err=[0], xi=-0.8092635427424977 fake x=-0.05856580091036567
# Total loss =  738.2743906426135 ; Total_loss - Total_loss_real_X =  -0.027951440875199296 Total_loss_update =  0.005035599109305622
# t =  7.62939453125e-06
# #iter 65 x_co=149, 1st=0.015705938318102852, 2nd=1.5297242239691633e-07, # queries above err=[0], xi=1.6605574575713349 fake x=0.8772345681594769
# Total loss =  738.2693550435042 ; Total_loss - Total_loss_real_X =  -0.03298703998450492 Total_loss_update =  0.005360385714197946
# t =  7.62939453125e-06
# #iter 66 x_co=154, 1st=-0.015283929574659183, 2nd=1.5259576993617378e-07, # queries above err=[0], xi=-0.6901048440279082 fake x=0.07405217527667785
# Total loss =  738.26399465779 ; Total_loss - Total_loss_real_X =  -0.038347425698702864 Total_loss_update =  0.005088686866997705
# t =  7.62939453125e-06
# #iter 67 x_co=117, 1st=0.015455190793622231, 2nd=1.53130571622551e-07, # queries above err=[0], xi=-0.2253004464942321 fake x=-0.9953213957461583
# Total loss =  738.258905970923 ; Total_loss - Total_loss_real_X =  -0.04343611256570057 Total_loss_update =  0.005185183095477441
# t =  7.62939453125e-06
# #iter 68 x_co=135, 1st=-0.0158735743253291, 2nd=1.6775137110699598e-07, # queries above err=[0], xi=-1.23466448360907 fake x=-0.5127284401068565
# Total loss =  738.2537207878275 ; Total_loss - Total_loss_real_X =  -0.04862129566117801 Total_loss_update =  0.004992992428128673
# t =  7.62939453125e-06
# #iter 69 x_co=127, 1st=0.015538648846301184, 2nd=1.5497866995788094e-07, # queries above err=[0], xi=-0.013936240104857826 fake x=-0.7788833296830767
# Total loss =  738.2487277953994 ; Total_loss - Total_loss_real_X =  -0.05361428808930668 Total_loss_update =  0.005178824006407012
# t =  7.62939453125e-06
# #iter 70 x_co=100, 1st=-0.015228956876303767, 2nd=1.5811575701494074e-07, # queries above err=[0], xi=-0.30093460086347873 fake x=0.4338923544141992
# Total loss =  738.243548971393 ; Total_loss - Total_loss_real_X =  -0.058793112095713695 Total_loss_update =  0.0048757709619167144
# t =  7.62939453125e-06
# #iter 71 x_co=60, 1st=0.015471262545659448, 2nd=1.536227780474697e-07, # queries above err=[0], xi=-0.5617217770925707 fake x=-1.330073758209028
# Total loss =  738.2386732004311 ; Total_loss - Total_loss_real_X =  -0.06366888305763041 Total_loss_update =  0.0051793286216934575
# t =  7.62939453125e-06
# #iter 72 x_co=95, 1st=-0.015696450276725393, 2nd=1.525882804631045e-07, # queries above err=[0], xi=-1.3307596004616595 fake x=-0.5459390917185741
# Total loss =  738.2334938718094 ; Total_loss - Total_loss_real_X =  -0.06884821167932387 Total_loss_update =  0.0053673356301260355
# t =  7.62939453125e-06
# #iter 73 x_co=177, 1st=0.01492941630073874, 2nd=1.5387516296876087e-07, # queries above err=[0], xi=0.9910391911724064 fake x=0.25081312166218417
# Total loss =  738.2281265361793 ; Total_loss - Total_loss_real_X =  -0.0742155473094499 Total_loss_update =  0.004814999626546523
# t =  7.62939453125e-06
# #iter 74 x_co=173, 1st=-0.014962536255196168, 2nd=1.4112020160476757e-07, # queries above err=[0], xi=0.30094200592408765 fake x=1.10986298946077
# Total loss =  738.2233115365527 ; Total_loss - Total_loss_real_X =  -0.07903054693599643 Total_loss_update =  0.0052735256438154465
# t =  7.62939453125e-06
# #iter 75 x_co=39, 1st=0.015209011216181123, 2nd=1.5219311378076726e-07, # queries above err=[0], xi=0.7150745127647152 fake x=-0.0473485963754281
# Total loss =  738.2180380109089 ; Total_loss - Total_loss_real_X =  -0.08430407257981187 Total_loss_update =  0.0050522810593065515
# t =  7.62939453125e-06
# #iter 76 x_co=73, 1st=-0.014609887321021864, 2nd=1.585083598994241e-07, # queries above err=[0], xi=-2.61210467838802 fake x=-1.9088951158141034
# Total loss =  738.2129857298496 ; Total_loss - Total_loss_real_X =  -0.08935635363911842 Total_loss_update =  0.0044763127181113305
# t =  7.62939453125e-06
# #iter 77 x_co=196, 1st=0.014716400564259713, 2nd=1.4912220664713408e-07, # queries above err=[0], xi=2.4573921847801663 fake x=1.7044712851429473
# Total loss =  738.2085094171315 ; Total_loss - Total_loss_real_X =  -0.09383266635722975 Total_loss_update =  0.004827695648941699
# t =  7.62939453125e-06
# #iter 78 x_co=197, 1st=-0.014638972302540854, 2nd=1.5548923232287249e-07, # queries above err=[0], xi=1.4024099859272963 fake x=2.120700851215055
# Total loss =  738.2036817214826 ; Total_loss - Total_loss_real_X =  -0.09866036200617145 Total_loss_update =  0.004581414434369435
# t =  7.62939453125e-06
# #iter 79 x_co=71, 1st=0.01405580674533713, 2nd=1.5082257049078924e-07, # queries above err=[0], xi=1.8204942924505612 fake x=1.1094780647982752
# Total loss =  738.1991003070482 ; Total_loss - Total_loss_real_X =  -0.10324177644054089 Total_loss_update =  0.0043543475487695105
# t =  7.62939453125e-06
# #iter 80 x_co=32, 1st=-0.013936729966303796, 2nd=1.6259055307971466e-07, # queries above err=[0], xi=0.185301353390865 fake x=0.8392680776217336
# Total loss =  738.1947459594994 ; Total_loss - Total_loss_real_X =  -0.1075961239893104 Total_loss_update =  0.003971037755150064
# t =  7.62939453125e-06
# #iter 81 x_co=4, 1st=0.013460806322100671, 2nd=1.6517247471764908e-07, # queries above err=[0], xi=1.6791265979163494 fake x=1.0573656034431171
# Total loss =  738.1907749217443 ; Total_loss - Total_loss_real_X =  -0.11156716174446046 Total_loss_update =  0.003646536552764701
# t =  7.62939453125e-06
# #iter 82 x_co=15, 1st=-0.0134761264122083, 2nd=1.497426079670656e-07, # queries above err=[0], xi=-1.3187029190008324 fake x=-0.6320934993602398
# Total loss =  738.1871283851915 ; Total_loss - Total_loss_real_X =  -0.11521369829722516 Total_loss_update =  0.0040314535506240645
# t =  7.62939453125e-06
# #iter 83 x_co=146, 1st=0.014026894042909577, 2nd=1.533671635198493e-07, # queries above err=[0], xi=0.17982770862562278 fake x=-0.5179533955254432
# Total loss =  738.1830969316409 ; Total_loss - Total_loss_real_X =  -0.11924515184784923 Total_loss_update =  0.004264499021019219
# t =  7.62939453125e-06
# #iter 84 x_co=150, 1st=-0.013757311266309635, 2nd=1.5152283500399978e-07, # queries above err=[0], xi=0.36898329419770426 fake x=1.0616838718836754
# Total loss =  738.1788324326199 ; Total_loss - Total_loss_real_X =  -0.12350965086886845 Total_loss_update =  0.004152093684638203
# t =  7.62939453125e-06
# #iter 85 x_co=62, 1st=0.013879897976483369, 2nd=1.5435167417874993e-07, # queries above err=[0], xi=0.5241186663621291 fake x=-0.1619459214016301
# Total loss =  738.1746803389352 ; Total_loss - Total_loss_real_X =  -0.12766174455350665 Total_loss_update =  0.0041489531724892
# t =  7.62939453125e-06
# #iter 86 x_co=45, 1st=-0.013461960521664373, 2nd=1.62056288417959e-07, # queries above err=[0], xi=0.4992561097134856 fake x=1.1330273072803407
# Total loss =  738.1705313857627 ; Total_loss - Total_loss_real_X =  -0.13181069772599585 Total_loss_update =  0.0037173026257733
# t =  7.62939453125e-06
# #iter 87 x_co=59, 1st=0.013349120345347965, 2nd=1.4791693443789217e-07, # queries above err=[0], xi=-0.17753285039869335 fake x=-0.8660659527566196
# Total loss =  738.166814083137 ; Total_loss - Total_loss_real_X =  -0.13552800035176915 Total_loss_update =  0.004004647524766369
# t =  7.62939453125e-06
# #iter 88 x_co=170, 1st=-0.01336552764479948, 2nd=1.594035673849681e-07, # queries above err=[0], xi=-0.2119837978665009 fake x=0.4277188461417021
# Total loss =  738.1628094356122 ; Total_loss - Total_loss_real_X =  -0.13953264787653552 Total_loss_update =  0.003725225124867393
# t =  7.62939453125e-06
# #iter 89 x_co=193, 1st=0.012892857017312798, 2nd=1.511509588442665e-07, # queries above err=[0], xi=1.2145846756885563 fake x=0.5638134627753698
# Total loss =  738.1590842104873 ; Total_loss - Total_loss_real_X =  -0.1432578730014029 Total_loss_update =  0.0036556583487481475
# t =  7.62939453125e-06
# #iter 90 x_co=50, 1st=-0.01306874379631906, 2nd=1.555768995818568e-07, # queries above err=[0], xi=-0.3229239825505092 fake x=0.31795909660793203
# Total loss =  738.1554285521386 ; Total_loss - Total_loss_real_X =  -0.14691353135015106 Total_loss_update =  0.003649208826573158
# t =  7.62939453125e-06
# #iter 91 x_co=72, 1st=0.01306723430805623, 2nd=1.5592910102659394e-07, # queries above err=[0], xi=1.1466824285911388 fake x=0.5073207872292519
# Total loss =  738.151779343312 ; Total_loss - Total_loss_real_X =  -0.15056274017672422 Total_loss_update =  0.0036401304664650525
# t =  7.62939453125e-06
# #iter 92 x_co=6, 1st=-0.012962078958379086, 2nd=1.5971048747665944e-07, # queries above err=[0], xi=-0.2946676790690561 fake x=0.3245328247997996
# Total loss =  738.1481392128455 ; Total_loss - Total_loss_real_X =  -0.15420287064318927 Total_loss_update =  0.0034969602397723065
# t =  7.62939453125e-06
# #iter 93 x_co=55, 1st=0.01249797778059536, 2nd=1.600611454790537e-07, # queries above err=[0], xi=0.7712623186187582 fake x=0.17553995860705607
# Total loss =  738.1446422526058 ; Total_loss - Total_loss_real_X =  -0.15769983088296158 Total_loss_update =  0.0032439187021964244
# t =  7.62939453125e-06
# #iter 94 x_co=75, 1st=-0.012586209373383284, 2nd=1.5600109090007177e-07, # queries above err=[0], xi=-1.5563632778239778 fake x=-0.9408217043104445
# Total loss =  738.1413983339036 ; Total_loss - Total_loss_real_X =  -0.160943749585158 Total_loss_update =  0.00337551038512629
# t =  7.62939453125e-06
# #iter 95 x_co=157, 1st=0.012517733943247178, 2nd=1.576292648322911e-07, # queries above err=[0], xi=-0.42571380643559575 fake x=-1.0315830972164808
# Total loss =  738.1380228235184 ; Total_loss - Total_loss_real_X =  -0.1643192599702843 Total_loss_update =  0.0033043914153267906
# t =  7.62939453125e-06
# #iter 96 x_co=120, 1st=-0.012586020593218006, 2nd=1.5461827163313118e-07, # queries above err=[0], xi=-1.831730517815947 fake x=-1.2106932001052915
# Total loss =  738.1347184321031 ; Total_loss - Total_loss_real_X =  -0.16762365138561108 Total_loss_update =  0.0034055861879096483
# t =  7.62939453125e-06
# #iter 97 x_co=104, 1st=0.012811820418212605, 2nd=1.6356503552868013e-07, # queries above err=[0], xi=0.30769717159082943 fake x=-0.2899026291130875
# Total loss =  738.1313128459152 ; Total_loss - Total_loss_real_X =  -0.17102923757352073 Total_loss_update =  0.003335845897368017
# t =  7.62939453125e-06
# #iter 98 x_co=158, 1st=-0.012222384487329707, 2nd=1.54940767757333e-07, # queries above err=[0], xi=-0.6463326574118288 fake x=-0.04449367909648594
# Total loss =  738.1279770000178 ; Total_loss - Total_loss_real_X =  -0.17436508347088875 Total_loss_update =  0.0032049656390427117
# t =  7.62939453125e-06
# #iter 99 x_co=22, 1st=0.012205927800103877, 2nd=1.5768453092102558e-07, # queries above err=[0], xi=-1.9014489096853158 fake x=-2.4920194511519664
# Total loss =  738.1247720343788 ; Total_loss - Total_loss_real_X =  -0.17757004910993146 Total_loss_update =  0.003140715882409495
# t =  7.62939453125e-06
# #iter 100 x_co=163, 1st=-0.012147870636345148, 2nd=1.5577876252216396e-07, # queries above err=[0], xi=0.7486108479649756 fake x=1.3435629216539526
# Total loss =  738.1216313184964 ; Total_loss - Total_loss_real_X =  -0.18071076499234096 Total_loss_update =  0.003148968710661393
# t =  7.62939453125e-06
# #iter 101 x_co=147, 1st=0.012120794204357965, 2nd=1.523982977680522e-07, # queries above err=[0], xi=-0.7503787072818471 fake x=-1.3571723681787673
# Total loss =  738.1184823497857 ; Total_loss - Total_loss_real_X =  -0.18385973370300235 Total_loss_update =  0.003204495609679725
# t =  7.62939453125e-06
# #iter 102 x_co=98, 1st=-0.01213862997076931, 2nd=1.6009529624106483e-07, # queries above err=[0], xi=-0.5596027884520438 fake x=0.018867655653983184
# Total loss =  738.115277854176 ; Total_loss - Total_loss_real_X =  -0.18706422931268207 Total_loss_update =  0.003059407612454379
# t =  7.62939453125e-06
# #iter 103 x_co=155, 1st=0.01193707529375998, 2nd=1.5398699613019693e-07, # queries above err=[0], xi=-1.226193515915371 fake x=-1.8176243461416415
# Total loss =  738.1122184465636 ; Total_loss - Total_loss_real_X =  -0.19012363692513645 Total_loss_update =  0.0030760127111761904
# t =  7.62939453125e-06
# #iter 104 x_co=81, 1st=-0.011723172465843534, 2nd=1.5573778475096194e-07, # queries above err=[0], xi=0.5341792990046608 fake x=1.1084824974406127
# Total loss =  738.1091424338524 ; Total_loss - Total_loss_real_X =  -0.19319964963631264 Total_loss_update =  0.0029334142749348757
# t =  7.62939453125e-06
# #iter 105 x_co=102, 1st=0.01163515879104815, 2nd=1.637619034742725e-07, # queries above err=[0], xi=0.6407325190210967 fake x=0.09866983553137998
# Total loss =  738.1062090195775 ; Total_loss - Total_loss_real_X =  -0.19613306391124752 Total_loss_update =  0.0027479388514848324
# t =  7.62939453125e-06
# #iter 106 x_co=65, 1st=-0.011782168166614815, 2nd=1.5416819476391662e-07, # queries above err=[0], xi=-0.5743497624504738 fake x=0.00871997845355632
# Total loss =  738.103461080726 ; Total_loss - Total_loss_real_X =  -0.19888100276273235 Total_loss_update =  0.002993174431139778
# t =  7.62939453125e-06
# #iter 107 x_co=128, 1st=0.011757086843534381, 2nd=1.6033900338704535e-07, # queries above err=[0], xi=0.8561886081823626 fake x=0.29675233770134113
# Total loss =  738.1004679062949 ; Total_loss - Total_loss_real_X =  -0.20187417719387213 Total_loss_update =  0.0028657406528509455
# t =  7.62939453125e-06
# #iter 108 x_co=89, 1st=-0.01124369006001702, 2nd=1.5799973849500962e-07, # queries above err=[0], xi=-0.09575622375274873 fake x=0.44717219038303324
# Total loss =  738.097602165642 ; Total_loss - Total_loss_real_X =  -0.20473991784672307 Total_loss_update =  0.0026597263654366543
# t =  7.62939453125e-06
# #iter 109 x_co=33, 1st=0.011367065264830112, 2nd=1.5907303209824353e-07, # queries above err=[0], xi=0.7760405856680145 fake x=0.2308581344131969
# Total loss =  738.0949424392766 ; Total_loss - Total_loss_real_X =  -0.20739964421215973 Total_loss_update =  0.002700077438930748
# t =  7.62939453125e-06
# #iter 110 x_co=178, 1st=-0.011278407004569058, 2nd=1.54551588114556e-07, # queries above err=[0], xi=-0.4520582465446891 fake x=0.10469705938003032
# Total loss =  738.0922423618376 ; Total_loss - Total_loss_real_X =  -0.21009972165109048 Total_loss_update =  0.0027358904520724536
# t =  7.62939453125e-06
# #iter 111 x_co=164, 1st=0.011430975318394543, 2nd=1.5579562525982917e-07, # queries above err=[0], xi=-0.7686347428682277 fake x=-1.3284156766111723
# Total loss =  738.0895064713856 ; Total_loss - Total_loss_real_X =  -0.21283561210316293 Total_loss_update =  0.0027879651386228943
# t =  7.62939453125e-06
# #iter 112 x_co=76, 1st=-0.011205583817639031, 2nd=1.5000274265127322e-07, # queries above err=[0], xi=0.25418822609245595 fake x=0.8241232711903335
# Total loss =  738.0867185062469 ; Total_loss - Total_loss_real_X =  -0.21562357724178582 Total_loss_update =  0.002782572832416008
# t =  7.62939453125e-06
# #iter 113 x_co=119, 1st=0.011433803280216592, 2nd=1.579681387715495e-07, # queries above err=[0], xi=0.4965222139555145 fake x=-0.05569671383490199
# Total loss =  738.0839359334145 ; Total_loss - Total_loss_real_X =  -0.21840615007420183 Total_loss_update =  0.0027509755323080753
# t =  7.62939453125e-06
# #iter 114 x_co=192, 1st=-0.011158979560704552, 2nd=1.5574781100965274e-07, # queries above err=[0], xi=-0.6703189983444968 fake x=-0.12369007892107475
# Total loss =  738.0811849578822 ; Total_loss - Total_loss_real_X =  -0.2211571256065099 Total_loss_update =  0.0026576760747047956
# t =  7.62939453125e-06
# #iter 115 x_co=118, 1st=0.011073488219788041, 2nd=1.6722583532253366e-07, # queries above err=[0], xi=1.1781126159010968 fake x=0.672903535599807
# Total loss =  738.0785272818075 ; Total_loss - Total_loss_real_X =  -0.2238148016812147 Total_loss_update =  0.002437485538166584
# t =  7.62939453125e-06
# #iter 116 x_co=115, 1st=-0.010681783925692745, 2nd=1.5687863819307816e-07, # queries above err=[0], xi=1.253398672189237 fake x=1.7728801312670104
# Total loss =  738.0760897962693 ; Total_loss - Total_loss_real_X =  -0.2262522872193813 Total_loss_update =  0.00241768812884402
# t =  7.62939453125e-06
# #iter 117 x_co=148, 1st=0.010909503699080503, 2nd=1.6245665716801995e-07, # queries above err=[0], xi=-0.01224847097588138 fake x=-0.5245876346109747
# Total loss =  738.0736721081405 ; Total_loss - Total_loss_real_X =  -0.2286699753482253 Total_loss_update =  0.0024352728419216874
# t =  7.62939453125e-06
# #iter 118 x_co=42, 1st=-0.010815197966714818, 2nd=1.58494010437262e-07, # queries above err=[0], xi=0.6407266767430196 fake x=1.161335701614039
# Total loss =  738.0712368352986 ; Total_loss - Total_loss_real_X =  -0.231105248190147 Total_loss_update =  0.002453187222727138
# t =  7.62939453125e-06
# #iter 119 x_co=19, 1st=0.010758592267510858, 2nd=1.575140081535203e-07, # queries above err=[0], xi=0.25970925439995596 fake x=-0.2613970647897347
# Total loss =  738.0687836480759 ; Total_loss - Total_loss_real_X =  -0.23355843541287413 Total_loss_update =  0.002442693087346015
# t =  7.62939453125e-06
# #iter 120 x_co=101, 1st=-0.01068283122062641, 2nd=1.5550578037046573e-07, # queries above err=[0], xi=-0.5262976280902908 fake x=-0.0021786281486437797
# Total loss =  738.0663409549885 ; Total_loss - Total_loss_real_X =  -0.23600112850022015 Total_loss_update =  0.002439511682950979
# t =  7.62939453125e-06
# #iter 121 x_co=88, 1st=0.010731727023460369, 2nd=1.6141962246226408e-07, # queries above err=[0], xi=1.2321077019523041 fake x=0.7248795334389184
# Total loss =  738.0639014433056 ; Total_loss - Total_loss_real_X =  -0.23844064018317113 Total_loss_update =  0.002371692546034865
# t =  7.62939453125e-06
# #iter 122 x_co=171, 1st=-0.010535696977689968, 2nd=1.5393729196093737e-07, # queries above err=[0], xi=-0.8167610968328798 fake x=-0.29459399956516763
# Total loss =  738.0615297507595 ; Total_loss - Total_loss_real_X =  -0.240812332729206 Total_loss_update =  0.002396952020944809
# t =  7.62939453125e-06
# #iter 123 x_co=110, 1st=0.010603666859114735, 2nd=1.5054788234444468e-07, # queries above err=[0], xi=0.6762422451225267 fake x=0.138874620375515
# Total loss =  738.0591327987386 ; Total_loss - Total_loss_real_X =  -0.2432092847501508 Total_loss_update =  0.002482630695340049
# t =  7.62939453125e-06
# #iter 124 x_co=95, 1st=-0.010734399718185239, 2nd=1.5255630973624396e-07, # queries above err=[0], xi=-0.5459390917185741 fake x=-0.009107998676493811
# Total loss =  738.0566501680432 ; Total_loss - Total_loss_real_X =  -0.24569191544549085 Total_loss_update =  0.002510730139988482
# t =  7.62939453125e-06
# #iter 125 x_co=191, 1st=0.01039059959997446, 2nd=1.5753459302806812e-07, # queries above err=[0], xi=1.2796957870613346 fake x=0.7764794315886719
# Total loss =  738.0541394379032 ; Total_loss - Total_loss_real_X =  -0.24820264558547933 Total_loss_update =  0.0022781430417353477
# t =  7.62939453125e-06
# #iter 126 x_co=15, 1st=-0.010228747954118989, 2nd=1.4971181557273896e-07, # queries above err=[0], xi=-0.6320934993602398 fake x=-0.11083100979558724
# Total loss =  738.0518612948615 ; Total_loss - Total_loss_real_X =  -0.2504807886272147 Total_loss_update =  0.0023230799838529492
# t =  7.62939453125e-06
# #iter 127 x_co=2, 1st=0.010388157823553179, 2nd=1.6017338146530767e-07, # queries above err=[0], xi=-0.37223700169987634 fake x=-0.8670467744831564
# Total loss =  738.0495382148777 ; Total_loss - Total_loss_real_X =  -0.25280386861106763 Total_loss_update =  0.002239562182012378
# t =  7.62939453125e-06
# #iter 128 x_co=116, 1st=-0.009905564422239888, 2nd=1.6174002252275357e-07, # queries above err=[0], xi=-4.641148237393876 fake x=-4.173895557115871
# Total loss =  738.0472986526956 ; Total_loss - Total_loss_real_X =  -0.25504343079308 Total_loss_update =  0.0020165843648101145
# t =  7.62939453125e-06
# #iter 129 x_co=161, 1st=0.009800182715831607, 2nd=1.4905864232933357e-07, # queries above err=[0], xi=-1.2226661115117483 fake x=-1.7242771502881453
# Total loss =  738.0452820683308 ; Total_loss - Total_loss_real_X =  -0.2570600151578901 Total_loss_update =  0.002141839408523083
# t =  7.62939453125e-06
# #iter 130 x_co=3, 1st=-0.010218419504064435, 2nd=1.5322933625028238e-07, # queries above err=[0], xi=-0.6300773315947755 fake x=-0.1212951637011006
# Total loss =  738.0431402289223 ; Total_loss - Total_loss_real_X =  -0.2592018545664132 Total_loss_update =  0.0022651658116501494
# t =  7.62939453125e-06
# #iter 131 x_co=193, 1st=0.010002586902135624, 2nd=1.5112711900452605e-07, # queries above err=[0], xi=0.5638134627753698 fake x=0.05884994390341325
# Total loss =  738.0408750631107 ; Total_loss - Total_loss_real_X =  -0.26146702037806335 Total_loss_update =  0.002200688811171858
# t =  7.62939453125e-06
# #iter 132 x_co=67, 1st=-0.009936663750297114, 2nd=1.5761470783259704e-07, # queries above err=[0], xi=-1.5424936559688787 fake x=-1.0615060050200493
# Total loss =  738.0386743742995 ; Total_loss - Total_loss_real_X =  -0.2636677091892352 Total_loss_update =  0.002082383551169187
# t =  7.62939453125e-06
# #iter 133 x_co=52, 1st=0.009751574759206516, 2nd=1.576141324621496e-07, # queries above err=[0], xi=1.7420734686157355 fake x=1.270043391256827
# Total loss =  738.0365919907483 ; Total_loss - Total_loss_real_X =  -0.2657500927404044 Total_loss_update =  0.0020055316963407677
# t =  7.62939453125e-06
# #iter 134 x_co=195, 1st=-0.009642217806119291, 2nd=1.5227908727855892e-07, # queries above err=[0], xi=-0.4885885816929646 fake x=-0.005500029523228589
# Total loss =  738.034586459052 ; Total_loss - Total_loss_real_X =  -0.26775562443674517 Total_loss_update =  0.002029496898217076
# t =  7.62939453125e-06
# #iter 135 x_co=78, 1st=0.009942191521703947, 2nd=1.5346417176507572e-07, # queries above err=[0], xi=0.053275736911072236 fake x=-0.4409953411646918
# Total loss =  738.0325569621538 ; Total_loss - Total_loss_real_X =  -0.26978512133496224 Total_loss_update =  0.002141075478903076
# t =  7.62939453125e-06
# #iter 136 x_co=199, 1st=-0.009955490261983169, 2nd=1.5689604888582954e-07, # queries above err=[0], xi=-1.2607096686267178 fake x=-0.7766033861545718
# Total loss =  738.0304158866749 ; Total_loss - Total_loss_real_X =  -0.2719261968138653 Total_loss_update =  0.0020998533891543048
# t =  7.62939453125e-06
# #iter 137 x_co=167, 1st=0.009907535363200548, 2nd=1.5547562612208887e-07, # queries above err=[0], xi=-0.9531195905335121 fake x=-1.4392954497566908
# Total loss =  738.0283160332857 ; Total_loss - Total_loss_real_X =  -0.2740260502030196 Total_loss_update =  0.0020986643925198223
# t =  7.62939453125e-06
# #iter 138 x_co=57, 1st=-0.009887188028868454, 2nd=1.5915714147249823e-07, # queries above err=[0], xi=0.014870789403151341 fake x=0.488825382825678
# Total loss =  738.0262173688932 ; Total_loss - Total_loss_real_X =  -0.27612471459553944 Total_loss_update =  0.0020417084245991646
# t =  7.62939453125e-06
# #iter 139 x_co=54, 1st=0.009457911395188479, 2nd=1.615390035220613e-07, # queries above err=[0], xi=0.8380472973740598 fake x=0.39135556409465133
# Total loss =  738.0241756604686 ; Total_loss - Total_loss_real_X =  -0.2781664230201386 Total_loss_update =  0.0018407207800237302
# t =  7.62939453125e-06
# #iter 140 x_co=126, 1st=-0.009510031417387044, 2nd=1.4961655390436493e-07, # queries above err=[0], xi=-1.769196072771122 fake x=-1.2842511933815985
# Total loss =  738.0223349396886 ; Total_loss - Total_loss_real_X =  -0.28000714380016234 Total_loss_update =  0.0020093705809358653
# t =  7.62939453125e-06
# #iter 141 x_co=55, 1st=0.009569797414834547, 2nd=1.60035412955074e-07, # queries above err=[0], xi=0.17553995860705607 fake x=-0.28068256560641497
# Total loss =  738.0203255691076 ; Total_loss - Total_loss_real_X =  -0.2820165143810982 Total_loss_update =  0.0019022358985694154
# t =  7.62939453125e-06
# #iter 142 x_co=79, 1st=-0.00917038480550536, 2nd=1.5621247837225275e-07, # queries above err=[0], xi=-0.9106347776540881 fake x=-0.4627545288185499
# Total loss =  738.0184233332091 ; Total_loss - Total_loss_real_X =  -0.2839187502796676 Total_loss_update =  0.0017895089927151275
# t =  7.62939453125e-06
# #iter 143 x_co=59, 1st=0.009457109470822456, 2nd=1.4788383079318097e-07, # queries above err=[0], xi=-0.8660659527566196 fake x=-1.353962559783467
# Total loss =  738.0166338242163 ; Total_loss - Total_loss_real_X =  -0.28570825927238275 Total_loss_update =  0.002010347208852181
# t =  7.62939453125e-06
# #iter 144 x_co=122, 1st=-0.009740791975349383, 2nd=1.5315358357451978e-07, # queries above err=[0], xi=-0.17085776219353133 fake x=0.31438289161470584
# Total loss =  738.0146234770075 ; Total_loss - Total_loss_real_X =  -0.28771860648123493 Total_loss_update =  0.002059379275920037
# t =  7.62939453125e-06
# #iter 145 x_co=68, 1st=0.009486174127915747, 2nd=1.6099658090689124e-07, # queries above err=[0], xi=-0.4125286410223298 fake x=-0.8620646784109833
# Total loss =  738.0125640977316 ; Total_loss - Total_loss_real_X =  -0.28977798575715497 Total_loss_update =  0.001857973452842998
# t =  7.62939453125e-06
# #iter 146 x_co=109, 1st=-0.009079587902848907, 2nd=1.575236620441734e-07, # queries above err=[0], xi=0.7420301617406605 fake x=1.181784782684996
# Total loss =  738.0107061242787 ; Total_loss - Total_loss_real_X =  -0.29163595920999796 Total_loss_update =  0.0017396502640849576
# t =  7.62939453125e-06
# #iter 147 x_co=139, 1st=0.009261588868959336, 2nd=1.58199083424645e-07, # queries above err=[0], xi=-0.9470065494486035 fake x=-1.393660941736419
# Total loss =  738.0089664740146 ; Total_loss - Total_loss_real_X =  -0.2933756094740829 Total_loss_update =  0.001802363720798894
# t =  7.62939453125e-06
# #iter 148 x_co=169, 1st=-0.009260988784370427, 2nd=1.532373347106619e-07, # queries above err=[0], xi=1.2571655037635043 fake x=1.718252466146747
# Total loss =  738.0071641102938 ; Total_loss - Total_loss_real_X =  -0.2951779731948818 Total_loss_update =  0.0018604835040605394
# t =  7.62939453125e-06
# #iter 149 x_co=118, 1st=0.009445255715434087, 2nd=1.6720651242312686e-07, # queries above err=[0], xi=0.672903535599807 fake x=0.24192999720535652
# Total loss =  738.0053036267898 ; Total_loss - Total_loss_real_X =  -0.29703845669894235 Total_loss_update =  0.0017735765073894072
# t =  7.62939453125e-06
# #iter 150 x_co=129, 1st=-0.009004134404153596, 2nd=1.5225634034460845e-07, # queries above err=[0], xi=0.6989369778601406 fake x=1.1501240589774626
# Total loss =  738.0035300502824 ; Total_loss - Total_loss_real_X =  -0.29881203320633176 Total_loss_update =  0.0017700461403364898
# t =  7.62939453125e-06
# #iter 151 x_co=24, 1st=0.00911991209317331, 2nd=1.5210923575375395e-07, # queries above err=[0], xi=-0.03867356882964179 fake x=-0.49610409304697234
# Total loss =  738.001760004142 ; Total_loss - Total_loss_real_X =  -0.30058207934666825 Total_loss_update =  0.0018176093041120112
# t =  7.62939453125e-06
# #iter 152 x_co=38, 1st=-0.009126865202554235, 2nd=1.4980925175267003e-07, # queries above err=[0], xi=-1.4556797322237751 fake x=-0.990872287762441
# Total loss =  737.999942394838 ; Total_loss - Total_loss_real_X =  -0.30239968865078026 Total_loss_update =  0.0018483323675582142
# t =  7.62939453125e-06
# #iter 153 x_co=34, 1st=0.009383128969796761, 2nd=1.546391234082559e-07, # queries above err=[0], xi=-0.34899894218479033 fake x=-0.8119321978214356
# Total loss =  737.9980940624704 ; Total_loss - Total_loss_real_X =  -0.3042480210183385 Total_loss_update =  0.0018925697758049864
# t =  7.62939453125e-06
# #iter 154 x_co=179, 1st=-0.008957241089458279, 2nd=1.585443379053736e-07, # queries above err=[0], xi=0.5485486397668764 fake x=0.9795846962155663
# Total loss =  737.9962014926946 ; Total_loss - Total_loss_real_X =  -0.30614059079414346 Total_loss_update =  0.0016821807487303886
# t =  7.62939453125e-06
# #iter 155 x_co=151, 1st=0.008837992250106952, 2nd=1.578742528575326e-07, # queries above err=[0], xi=-1.1364359238831472 fake x=-1.56353868775842
# Total loss =  737.9945193119459 ; Total_loss - Total_loss_real_X =  -0.30782277154287385 Total_loss_update =  0.0016446410101025322
# t =  7.62939453125e-06
# #iter 156 x_co=154, 1st=-0.008858256487479954, 2nd=1.525317779182789e-07, # queries above err=[0], xi=0.07405217527667785 fake x=0.5171279364351038
# Total loss =  737.9928746709357 ; Total_loss - Total_loss_real_X =  -0.3094674125529764 Total_loss_update =  0.0017100593584018497
# t =  7.62939453125e-06
# #iter 157 x_co=7, 1st=0.00890864819250492, 2nd=1.5901970606956538e-07, # queries above err=[0], xi=-1.556106152496416 fake x=-1.9835223104095356
# Total loss =  737.9911646115773 ; Total_loss - Total_loss_real_X =  -0.31117747191137823 Total_loss_update =  0.0016590041381050469
# t =  7.62939453125e-06
# #iter 158 x_co=145, 1st=-0.008784736074482158, 2nd=1.502657331196081e-07, # queries above err=[0], xi=0.7911277789976816 fake x=1.2371524046638713
# ...
# t =  7.62939453125e-06
# #iter 159 x_co=39, 1st=0.00879978580144325, 2nd=1.52148970126481e-07, # queries above err=[0], xi=-0.0473485963754281 fake x=-0.48860717087574645
# Total loss =  737.9877984557978 ; Total_loss - Total_loss_real_X =  -0.3145436276909095 Total_loss_update =  0.0016918093266440337
# t =  7.62939453125e-06
# #iter 160 x_co=135, 1st=-0.008699592890980323, 2nd=1.6769286214555927e-07, # queries above err=[0], xi=-0.5127284401068565 fake x=-0.1169296829186437
# Total loss =  737.9861066464712 ; Total_loss - Total_loss_real_X =  -0.3162354370175535 Total_loss_update =  0.0015002293724819538
# t =  7.62939453125e-06
# #iter 161 x_co=60, 1st=0.00863736876689769, 2nd=1.5356180550418748e-07, # queries above err=[0], xi=-1.330073758209028 fake x=-1.7592032140538398
# Total loss =  737.9846064170987 ; Total_loss - Total_loss_real_X =  -0.3177356663900355 Total_loss_update =  0.001614931190374591
# t =  7.62939453125e-06
# #iter 162 x_co=27, 1st=-0.008914822155757562, 2nd=1.5932075660377786e-07, # queries above err=[0], xi=-0.09207951963609193 fake x=0.33482465061808264
# Total loss =  737.9829914859083 ; Total_loss - Total_loss_real_X =  -0.31935059758041007 Total_loss_update =  0.001658168193785059
# t =  7.62939453125e-06
# #iter 163 x_co=196, 1st=0.008883316575114986, 2nd=1.490688167116698e-07, # queries above err=[0], xi=1.7044712851429473 fake x=1.2498200147257785
# Total loss =  737.9813333177145 ; Total_loss - Total_loss_real_X =  -0.3210087657741951 Total_loss_update =  0.0017597014606280936
# t =  7.62939453125e-06
# #iter 164 x_co=5, 1st=-0.00900398985033335, 2nd=1.5640110592867788e-07, # queries above err=[0], xi=-0.05856580091036567 fake x=0.3806573779518739
# Total loss =  737.9795736162539 ; Total_loss - Total_loss_real_X =  -0.3227684672348232 Total_loss_update =  0.0017230730086339463
# t =  7.62939453125e-06
# #iter 165 x_co=117, 1st=0.008611398612075494, 2nd=1.530732423879732e-07, # queries above err=[0], xi=-0.9953213957461583 fake x=-1.424526111426399
# Total loss =  737.9778505432453 ; Total_loss - Total_loss_real_X =  -0.32449154024345717 Total_loss_update =  0.0016103586405051828
# t =  7.62939453125e-06
# #iter 166 x_co=173, 1st=-0.008854229799099222, 2nd=1.410699215507306e-07, # queries above err=[0], xi=1.10986298946077 fake x=1.5887206485924912
# Total loss =  737.9762401846048 ; Total_loss - Total_loss_real_X =  -0.32610189888396235 Total_loss_update =  0.0018473233889153562
# t =  7.62939453125e-06
# #iter 167 x_co=66, 1st=0.009097900774831968, 2nd=1.5492443683406036e-07, # queries above err=[0], xi=0.4523483753367411 fake x=0.0043139926673058104
# Total loss =  737.9743928612158 ; Total_loss - Total_loss_real_X =  -0.3279492222728777 Total_loss_update =  0.0017759765024720764
# t =  7.62939453125e-06
# #iter 168 x_co=45, 1st=-0.008747539253954217, 2nd=1.6201711312565588e-07, # queries above err=[0], xi=1.1330273072803407 fake x=1.5449493990796963
# Total loss =  737.9726168847134 ; Total_loss - Total_loss_real_X =  -0.3297251987753498 Total_loss_update =  0.0015699504559734123
# t =  7.62939453125e-06
# #iter 169 x_co=131, 1st=0.008569463057984006, 2nd=1.5975726509745561e-07, # queries above err=[0], xi=0.03378726998479056 fake x=-0.3754574335374491
# Total loss =  737.9710469342574 ; Total_loss - Total_loss_real_X =  -0.3312951492313232 Total_loss_update =  0.0015279919758768301
# t =  7.62939453125e-06
# #iter 170 x_co=123, 1st=-0.008480903671680862, 2nd=1.533171697280127e-07, # queries above err=[0], xi=-0.7674125139224012 fake x=-0.3453843731240398
# Total loss =  737.9695189422815 ; Total_loss - Total_loss_real_X =  -0.3328231412072 Total_loss_update =  0.001559443441124131
# t =  7.62939453125e-06
# #iter 171 x_co=194, 1st=0.008376058392265406, 2nd=1.5427784998780562e-07, # queries above err=[0], xi=1.0957132450052962 fake x=0.6814978920143682
# Total loss =  737.9679594988404 ; Total_loss - Total_loss_real_X =  -0.33438258464832415 Total_loss_update =  0.001511648933046672
# t =  7.62939453125e-06
# #iter 172 x_co=189, 1st=-0.00842288005816716, 2nd=1.620263683497706e-07, # queries above err=[0], xi=-0.9325632396177808 fake x=-0.535952023137064
# Total loss =  737.9664478499074 ; Total_loss - Total_loss_real_X =  -0.3358942335813708 Total_loss_update =  0.001455494728247686
# t =  7.62939453125e-06
# #iter 173 x_co=64, 1st=0.00824123282536382, 2nd=1.5996625113051923e-07, # queries above err=[0], xi=1.2224841395492112 fake x=0.829428628125821
# Total loss =  737.9649923551791 ; Total_loss - Total_loss_real_X =  -0.3373497283096185 Total_loss_update =  0.0014113376495288321
# t =  7.62939453125e-06
# #iter 174 x_co=77, 1st=-0.008186531754512227, 2nd=1.5090370616701023e-07, # queries above err=[0], xi=0.248839310192277 fake x=0.6627342514381558
# Total loss =  737.9635810175296 ; Total_loss - Total_loss_real_X =  -0.33876106595914734 Total_loss_update =  0.0014763005565328058
# t =  7.62939453125e-06
# #iter 175 x_co=157, 1st=0.00820990584699377, 2nd=1.5759320280557745e-07, # queries above err=[0], xi=-1.0315830972164808 fake x=-1.4290406629999897
# Total loss =  737.962104716973 ; Total_loss - Total_loss_real_X =  -0.34023736651568015 Total_loss_update =  0.0014217189252576645
# t =  7.62939453125e-06
# #iter 176 x_co=150, 1st=-0.007986323409154839, 2nd=1.514796759512203e-07, # queries above err=[0], xi=1.0616838718836754 fake x=1.463921411408257
# Total loss =  737.9606829980478 ; Total_loss - Total_loss_real_X =  -0.3416590854409378 Total_loss_update =  0.0013996335392221226
# t =  7.62939453125e-06
# #iter 177 x_co=56, 1st=0.00819023976180544, 2nd=1.6518630221872338e-07, # queries above err=[0], xi=-0.21394396220927617 fake x=-0.5922233328898195
# Total loss =  737.9592833645086 ; Total_loss - Total_loss_real_X =  -0.34305871898015994 Total_loss_update =  0.0013498757313072929
# t =  7.62939453125e-06
# #iter 178 x_co=89, 1st=-0.008097191695856765, 2nd=1.5796654838614332e-07, # queries above err=[0], xi=0.44717219038303324 fake x=0.8382465708388356
# Total loss =  737.9579334887773 ; Total_loss - Total_loss_real_X =  -0.34440859471146723 Total_loss_update =  0.001379679630758801
# t =  7.62939453125e-06
# #iter 179 x_co=159, 1st=0.008083238170130791, 2nd=1.6494248009245274e-07, # queries above err=[0], xi=0.036233977164531354 fake x=-0.33765522988158575
# Total loss =  737.9565538091465 ; Total_loss - Total_loss_real_X =  -0.34578827434222603 Total_loss_update =  0.0013167784341021616
# t =  7.62939453125e-06
# #iter 180 x_co=100, 1st=-0.007651304559451955, 2nd=1.5804848404508017e-07, # queries above err=[0], xi=0.4338923544141992 fake x=0.8032399094730676
# Total loss =  737.9552370307124 ; Total_loss - Total_loss_real_X =  -0.3471050527763282 Total_loss_update =  0.0012312751396166277
# t =  7.62939453125e-06
# #iter 181 x_co=22, 1st=0.007781611022099177, 2nd=1.5763736673115252e-07, # queries above err=[0], xi=-2.4920194511519664 fake x=-2.868636885250386
# Total loss =  737.9540057555728 ; Total_loss - Total_loss_real_X =  -0.3483363279159448 Total_loss_update =  0.0012768924057127151
# t =  7.62939453125e-06
# #iter 182 x_co=166, 1st=-0.007626091958636838, 2nd=1.5604937262864257e-07, # queries above err=[0], xi=0.6373676179024793 fake x=1.0102141299002738
# Total loss =  737.9527288631671 ; Total_loss - Total_loss_real_X =  -0.34961322032165754 Total_loss_update =  0.0012388469425559379
# t =  7.62939453125e-06
# #iter 183 x_co=88, 1st=0.007704647451459268, 2nd=1.613989324404572e-07, # queries above err=[0], xi=0.7248795334389184 fake x=0.36067765030032833
# Total loss =  737.9514900162245 ; Total_loss - Total_loss_real_X =  -0.3508520672642135 Total_loss_update =  0.0012225857577732313
# t =  7.62939453125e-06
# #iter 184 x_co=120, 1st=-0.007569165803233746, 2nd=1.5457385171612843e-07, # queries above err=[0], xi=-1.2106932001052915 fake x=-0.8370973328601037
# Total loss =  737.9502674304667 ; Total_loss - Total_loss_real_X =  -0.3520746530219867 Total_loss_update =  0.0012320664206981746
# t =  7.62939453125e-06
# #iter 185 x_co=17, 1st=0.007658029967155144, 2nd=1.515236763331535e-07, # queries above err=[0], xi=1.122701261986934 fake x=0.7371104859084738
# Total loss =  737.949035364046 ; Total_loss - Total_loss_real_X =  -0.3533067194426849 Total_loss_update =  0.0012865527451140224
# t =  7.62939453125e-06
# #iter 186 x_co=48, 1st=-0.007728447978653463, 2nd=1.541930178658307e-07, # queries above err=[0], xi=-0.15590435034192746 fake x=0.22649544674029298
# Total loss =  737.9477488113009 ; Total_loss - Total_loss_real_X =  -0.3545932721877989 Total_loss_update =  0.0012876384967057675
# t =  7.62939453125e-06
# #iter 187 x_co=127, 1st=0.0076714377918545296, 2nd=1.5492215004585882e-07, # queries above err=[0], xi=-0.7788833296830767 fake x=-1.1566758242919781
# Total loss =  737.9464611728042 ; Total_loss - Total_loss_real_X =  -0.35588091068450467 Total_loss_update =  0.001262740035826937
# t =  7.62939453125e-06
# #iter 188 x_co=65, 1st=-0.007452459349424512, 2nd=1.5413164778209253e-07, # queries above err=[0], xi=0.00871997845355632 fake x=0.3776108157541889
# Total loss =  737.9451984327684 ; Total_loss - Total_loss_real_X =  -0.3571436507203316 Total_loss_update =  0.0011977936467246764
# t =  7.62939453125e-06
# #iter 189 x_co=72, 1st=0.007579582657629036, 2nd=1.5588043839530677e-07, # queries above err=[0], xi=0.5073207872292519 fake x=0.1363465516383583
# Total loss =  737.9440006391217 ; Total_loss - Total_loss_real_X =  -0.3583414443670563 Total_loss_update =  0.0012251053940417478
# t =  7.62939453125e-06
# #iter 190 x_co=144, 1st=-0.007505846972062358, 2nd=1.5277349417606337e-07, # queries above err=[0], xi=0.06466648319788904 fake x=0.4395028915021788
# Total loss =  737.9427755337276 ; Total_loss - Total_loss_real_X =  -0.35956654976109803 Total_loss_update =  0.0012258170792165402
# t =  7.62939453125e-06
# #iter 191 x_co=137, 1st=0.0074426104035956175, 2nd=1.5488795827956167e-07, # queries above err=[0], xi=-0.005209770781624198 fake x=-0.3718141972466449
# Total loss =  737.9415497166484 ; Total_loss - Total_loss_real_X =  -0.36079236684031457 Total_loss_update =  0.0011887959261684955
# t =  7.62939453125e-06
# #iter 192 x_co=69, 1st=-0.007342385610971336, 2nd=1.602241177036703e-07, # queries above err=[0], xi=0.664288026920376 fake x=1.0139105271377087
# Total loss =  737.9403609207222 ; Total_loss - Total_loss_real_X =  -0.36198116276648307 Total_loss_update =  0.0011184595434770017
# t =  7.62939453125e-06
# #iter 193 x_co=37, 1st=0.007276919199578957, 2nd=1.5906753962270757e-07, # queries above err=[0], xi=1.1956955939484213 fake x=0.8466709741089482
# Total loss =  737.9392424611788 ; Total_loss - Total_loss_real_X =  -0.36309962230996007 Total_loss_update =  0.0011065926360060985
# t =  7.62939453125e-06
# #iter 194 x_co=29, 1st=-0.00729524854588548, 2nd=1.48779188365988e-07, # queries above err=[0], xi=0.788006119298527 fake x=1.1621063544952133
# Total loss =  737.9381358685428 ; Total_loss - Total_loss_real_X =  -0.36420621494596617 Total_loss_update =  0.001189081958159477
# t =  7.62939453125e-06
# #iter 195 x_co=146, 1st=0.00740085753233477, 2nd=1.5331761552363267e-07, # queries above err=[0], xi=-0.5179533955254432 fake x=-0.8862350296410728
# Total loss =  737.9369467865846 ; Total_loss - Total_loss_real_X =  -0.36539529690412564 Total_loss_update =  0.0011875349971433025
# t =  7.62939453125e-06
# #iter 196 x_co=135, 1st=-0.007212893683528954, 2nd=1.6768222600860597e-07, # queries above err=[0], xi=-0.1169296829186437 fake x=0.21125066710115603
# Total loss =  737.9357592515875 ; Total_loss - Total_loss_real_X =  -0.36658283190126895 Total_loss_update =  0.0010313498266896204
# t =  7.62939453125e-06
# #iter 197 x_co=19, 1st=0.007175040890520457, 2nd=1.5748932744880148e-07, # queries above err=[0], xi=-0.2613970647897347 fake x=-0.6089839052340679
# Total loss =  737.9347279017608 ; Total_loss - Total_loss_real_X =  -0.36761418172795857 Total_loss_update =  0.0010866079898050884
# t =  7.62939453125e-06
# #iter 198 x_co=75, 1st=-0.007113003901934922, 2nd=1.5596501657201055e-07, # queries above err=[0], xi=-0.9408217043104445 fake x=-0.592872438103518
# Total loss =  737.933641293771 ; Total_loss - Total_loss_real_X =  -0.36870078971776366 Total_loss_update =  0.0010783345721847581
# t =  7.62939453125e-06
# #iter 199 x_co=53, 1st=0.007076136244422493, 2nd=1.5948161413678447e-07, # queries above err=[0], xi=-0.4284772369544275 fake x=-0.7669904596715837
# Total loss =  737.9325629591988 ; Total_loss - Total_loss_real_X =  -0.3697791242899484 Total_loss_update =  0.0010436552911414765
# t =  7.62939453125e-06
# #iter 200 x_co=95, 1st=-0.007020823928931108, 2nd=1.525255458947964e-07, # queries above err=[0], xi=-0.009107998676493811 fake x=0.3420766856596109
# Total loss =  737.9315193039076 ; Total_loss - Total_loss_real_X =  -0.3708227795810899 Total_loss_update =  0.0010742546921846952
# t =  7.62939453125e-06
# #iter 201 x_co=110, 1st=0.007125692926416072, 2nd=1.5052269180164325e-07, # queries above err=[0], xi=0.138874620375515 fake x=-0.2222983163655225
# Total loss =  737.9304450492155 ; Total_loss - Total_loss_real_X =  -0.3718970342732746 Total_loss_update =  0.0011213105244678445
# t =  7.62939453125e-06
# #iter 202 x_co=73, 1st=-0.007190939022278409, 2nd=1.584425259128422e-07, # queries above err=[0], xi=-1.9088951158141034 fake x=-1.5626338419859995
# Total loss =  737.929323738691 ; Total_loss - Total_loss_real_X =  -0.37301834479774243 Total_loss_update =  0.0010848618652516961
# t =  7.62939453125e-06
# #iter 203 x_co=177, 1st=0.007047271389492682, 2nd=1.538117324107271e-07, # queries above err=[0], xi=0.25081312166218417 fake x=-0.0987467783307262
# Total loss =  737.9282388768257 ; Total_loss - Total_loss_real_X =  -0.3741032066629941 Total_loss_update =  0.001073315675057529
# t =  7.62939453125e-06
# #iter 204 x_co=199, 1st=-0.007062523128004372, 2nd=1.568742824244984e-07, # queries above err=[0], xi=-0.7766033861545718 fake x=-0.4331259563498726
# Total loss =  737.9271655611507 ; Total_loss - Total_loss_real_X =  -0.37517652233805165 Total_loss_update =  0.001056920995551991
# t =  7.62939453125e-06
# #iter 205 x_co=152, 1st=0.0070167917956673875, 2nd=1.5335374307631775e-07, # queries above err=[0], xi=1.1047157300100559 fake x=0.7556282419652218
# Total loss =  737.9261086401551 ; Total_loss - Total_loss_real_X =  -0.37623344333360365 Total_loss_update =  0.0010672273082263928
# t =  7.62939453125e-06
# #iter 206 x_co=20, 1st=-0.0070550590957889625, 2nd=1.4942391158803473e-07, # queries above err=[0], xi=-0.571288903350919 fake x=-0.21106657540479368
# Total loss =  737.9250414128469 ; Total_loss - Total_loss_real_X =  -0.37730067064183004 Total_loss_update =  0.0011072727679675154
# t =  7.62939453125e-06
# #iter 207 x_co=28, 1st=0.007001580451842848, 2nd=1.4613005914297816e-07, # queries above err=[0], xi=0.6546541708993887 fake x=0.28910433178565037
# Total loss =  737.9239341400789 ; Total_loss - Total_loss_real_X =  -0.37840794340979755 Total_loss_update =  0.0011151321947409087
# t =  7.62939453125e-06
# #iter 208 x_co=32, 1st=-0.006999577431689108, 2nd=1.625354750266011e-07, # queries above err=[0], xi=0.8392680776217336 fake x=1.1678273522640832
# Total loss =  737.9228190078842 ; Total_loss - Total_loss_real_X =  -0.37952307560453846 Total_loss_update =  0.0010020052919799127
# t =  7.62939453125e-06
# #iter 209 x_co=155, 1st=0.006907637197441474, 2nd=1.5394017381667333e-07, # queries above err=[0], xi=-1.8176243461416415 fake x=-2.1599722086351614
# Total loss =  737.9218170025922 ; Total_loss - Total_loss_real_X =  -0.3805250808965184 Total_loss_update =  0.0010303420592663315
# t =  7.62939453125e-06
# #iter 210 x_co=98, 1st=-0.0070735308390865725, 2nd=1.6005277560784023e-07, # queries above err=[0], xi=0.018867655653983184 fake x=0.3560486716994915
# Total loss =  737.9207866605329 ; Total_loss - Total_loss_real_X =  -0.3815554229557847 Total_loss_update =  0.0010391632324626698
# t =  7.62939453125e-06
# #iter 211 x_co=128, 1st=0.006718985003373756, 2nd=1.603012373264861e-07, # queries above err=[0], xi=0.29675233770134113 fake x=-0.02303176562336018
# Total loss =  737.9197474973005 ; Total_loss - Total_loss_real_X =  -0.3825945861882474 Total_loss_update =  0.0009361490710944054

# %%
import matplotlib.pyplot as plt


## plot distribution of fake_X and real_X
# plt.hist(fake_X, bins=100, density=True, alpha=0.6, color='blue', label='fake_X_after')
# plt.hist(fake_X_original, bins=100, density=True, alpha=0.6, color='green', label='fake_X_original')
# plt.hist(real_X, bins=100, density=True, alpha=0.6, color='red',label='real_X')

# plot fake_X, real_X, and fake_X_after
# initialize the x-axis to be # data points
x_axis = np.arange(start=1, stop=num_points+1, step=1) 
plt.scatter(x_axis, fake_X, s = np.full(len(fake_X),20),label="fake_X_after", color='deeppink')
plt.scatter(x_axis, fake_X_original, s = np.full(len(fake_X),20),label="fake_X_original", color='cornflowerblue')
plt.scatter(x_axis, real_X, s = np.full(len(fake_X),20),label="real_X",color='gold', alpha=0.4)

# plot the difference between fake_X_original and fake_X_after

plt.quiver(x_axis, fake_X_original, x_axis-x_axis, fake_X - fake_X_original, angles='xy', scale_units='xy', scale=1, color='black', alpha=1)

 

plt.legend()

plt.xlabel('coordinates of the data set')
plt.ylabel('data value')
# plt.grid(True)

# plt.grid(True)
plt.figure(figsize=(8, 40), dpi= 100)
plt.show()

# %%
print(epsilon)
abs(fake_X-real_X)
# Out:
# 25
# array([1.97077925e-01, 4.17202018e-01, 3.29532255e-02, 8.18704836e-01,
#        8.97365603e-01, 5.90657378e-01, 9.54671752e-02, 2.30352231e+00,
#        7.98943297e-02, 8.98308088e-01, 7.25251890e-01, 4.87396582e-01,
#        3.02385021e+00, 7.88502236e-01, 1.95404837e+00, 4.49168990e-01,
#        1.11373079e-03, 1.06711049e+00, 1.12399475e+00, 1.18983905e-01,
#        1.58933425e-01, 7.07731443e-01, 2.13863689e+00, 1.36499911e+00,
#        2.83895907e-01, 1.67459334e-02, 2.84091398e-01, 2.64824651e-01,
#        4.91043318e-02, 9.62106354e-01, 1.10320403e+00, 2.79001704e-01,
#        1.35782735e+00, 9.50858134e-01, 2.21932198e-01, 4.26655977e-01,
#        1.34855984e+00, 9.76670974e-01, 6.00872288e-01, 4.91392829e-01,
#        1.86405356e+00, 5.03449104e-01, 2.81335702e-01, 2.81554597e-01,
#        6.15623928e-01, 1.28494940e+00, 1.91949694e-01, 6.83088970e-01,
#        2.93504553e-01, 1.44545814e-01, 3.72040903e-01, 7.28270466e-01,
#        1.91004339e+00, 1.40699046e+00, 8.61355564e-01, 2.00682566e-01,
#        1.52223333e-01, 1.03882538e+00, 1.52218979e+00, 4.33962560e-01,
#        1.65920321e+00, 4.79613223e-01, 8.80540786e-02, 3.28092017e-01,
#        1.52942863e+00, 3.27610816e-01, 9.65686007e-01, 1.59150601e+00,
#        1.82064678e-01, 9.39105271e-02, 7.29537364e-01, 1.89947806e+00,
#        2.26346552e-01, 1.39263384e+00, 8.62315735e-01, 9.71275619e-02,
#        6.58767288e-02, 1.87265749e-01, 1.06099534e+00, 4.72754529e-01,
#        1.09439201e+00, 1.62848250e+00, 3.04191578e-01, 1.24654450e+00,
#        5.13270157e-01, 1.19335238e-01, 2.43689518e-01, 9.24352741e-01,
#        9.70677650e-01, 8.82465708e-02, 1.25266850e+00, 2.43108765e-01,
#        1.05472908e+00, 3.40720574e-01, 3.13525358e-01, 1.97923314e-01,
#        1.46386900e+00, 1.32970686e-01, 4.03951328e-01, 1.59029318e+00,
#        3.32399095e-02, 1.32178628e-01, 8.48669836e-01, 1.61570028e+00,
#        5.60097371e-01, 2.25754342e+00, 3.03829358e-01, 3.44207339e-01,
#        2.98829106e-01, 7.11784783e-01, 4.52298316e-01, 1.43553641e-01,
#        2.56601297e-02, 3.06499004e-01, 1.61535709e-01, 1.91288013e+00,
#        3.37389556e+00, 5.94526111e-01, 5.19299972e-02, 6.35696714e-01,
#        3.57097333e-01, 2.07331815e-01, 1.85617108e-01, 9.05384373e-01,
#        4.16902654e-01, 1.14113119e+00, 1.32425119e+00, 8.76675824e-01,
#        3.56968234e-01, 2.04012406e+00, 7.65775455e-01, 1.17545743e+00,
#        1.88008289e+00, 1.04974130e+00, 1.29694826e+00, 7.48749333e-01,
#        5.35002857e-01, 4.31814197e-01, 9.12415487e-01, 1.34366094e+00,
#        6.46056549e-01, 1.48475943e+00, 1.37837139e-01, 7.41733741e-01,
#        3.49502892e-01, 1.01715240e+00, 9.86235030e-01, 7.07172368e-01,
#        4.54123654e-02, 3.97234568e-01, 8.63921411e-01, 7.23538688e-01,
#        7.35628242e-01, 4.74831264e-01, 1.18712794e+00, 1.24997221e+00,
#        1.35309239e+00, 4.69040663e-01, 1.94493679e-01, 6.23447701e-02,
#        1.40697720e-02, 9.84277150e-01, 8.78828607e-01, 6.33562922e-01,
#        1.98841568e+00, 8.47336011e-01, 3.40214130e-01, 5.59295450e-01,
#        5.16119401e-01, 8.08252466e-01, 2.17718846e-01, 7.04594000e-01,
#        5.88454376e-02, 7.78720649e-01, 1.86404706e+00, 5.82255887e-02,
#        9.04750272e-01, 2.38746778e-01, 2.46970594e-02, 1.17958470e+00,
#        2.94010276e-01, 5.51112269e-01, 2.21121368e-01, 1.89215488e-01,
#        6.67601238e-01, 3.89306595e-01, 3.13702811e-01, 6.83134577e-01,
#        8.53707760e-01, 1.08595202e+00, 2.92021098e-01, 1.07647943e+00,
#        6.46309921e-01, 4.51150056e-01, 9.85021080e-02, 2.95500030e-01,
#        8.69820015e-01, 1.77070085e+00, 7.98104273e-01, 1.06312596e+00])

# %%
# ### stochastic gradient descent 
# #### COORDINATE DESCENT LOOP STARTS HERE ###
# #### In this loop, we do coordinate descent, NOT multivariate Newton's method ####

# # initialize number of coordinate descent iterations = 0
# num_iter_descent = 0

# x_coord_changed = np.full(num_points, False, dtype=bool)
# x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}


# # while we don't have |q(X) - noisy_output|<lambda/2 for all q, continue coordinate descent 
# while not np.all(error < Llambda/2):
    
#     # calculate the current total loss, which includes two copies of loss for each query function
#     total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
#     total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
#     total_loss = total_loss_plus + total_loss_minus 

#     ### compute the partial derivative of the loss function with respect to each coordinate 
#     query_loss_gradient = np.zeros(num_points) # initialize the partial derivative of the current query wrt each coordinate to be zero

#     # go thru all queries one by one, starting with q_0 all the way to q_{k-1}
#     current_q = 0

#     while current_q < k:
#         num_iter_q = 0 
#         x_coord_changed = np.full(num_points, False, dtype=bool)
#         x_coord_changed = {i: x_coord_changed[i] for i in range(len(x_coord_changed))}

#         sampled_queries_q = sampled_queries[current_q]
#         fake_output_q = fake_output[current_q]
#         real_data_noisy_output_q = real_data_noisy_output[current_q]

#         # we want to gradient descent on one query until it satisfies the error bound
#         while not error[current_q] < Llambda/2:

#             query_loss_plus = np.exp((fake_output_q-real_data_noisy_output_q)/Llambda-1)
#             query_loss_minus = np.exp((real_data_noisy_output_q-fake_output_q)/Llambda-1)
#             query_loss = query_loss_plus + query_loss_minus

#             for i in range(num_points):
#                 # fix xi    
#                 xi = fake_X[i]

#                 # calculate the dq_j/dx_i for all j = 1, ..., k
#                 # query_grad_wrt_xi_array = 2*xi*sampled_queries_q/num_points
#                 loss_gradient_plus = np.sum(2*sampled_queries_q*xi*np.exp((fake_output_q-real_data_noisy_output_q)/Llambda - 1)/(Llambda*num_points))
#                 loss_gradient_minus = np.sum(-2*sampled_queries_q*xi*np.exp(-(fake_output_q-real_data_noisy_output_q)/Llambda - 1)/(Llambda*num_points))
#                 query_loss_gradient[i] = loss_gradient_plus + loss_gradient_minus

#             # create a dictionary for query_loss_gradient
#             loss_gradient_dict = {i: query_loss_gradient[i] for i in range(len(query_loss_gradient))}


#             # find the coordinate with the max absolute value part_derivative 
#             filtered_loss_grad_dict = {k: v for k, v in loss_gradient_dict.items() if not x_coord_changed[k]}
#             x_coord_descent = max(filtered_loss_grad_dict, key=lambda k: abs(filtered_loss_grad_dict[k]))

        
            

#             # update x value at the coordinate x_coord_descent
#             # First, we calculate the 2nd derivative wrt x_coord_descent
#             xi = fake_X[x_coord_descent] 
#             # quadratic query

#             loss_hessian_wrt_chosen_xi_plus = (2*sampled_queries_q)/(Llambda*num_points)*np.exp((fake_output_q-real_data_noisy_output_q)/Llambda -1)*(1+2*sampled_queries_q*xi**2/(Llambda*num_points))
#             loss_hessian_wrt_chosen_xi_minus = -(2*sampled_queries_q)/(Llambda*num_points)*np.exp(-(fake_output_q-real_data_noisy_output_q)/Llambda -1)*(1-2*sampled_queries_q*xi**2/(Llambda*num_points))
#             loss_hessian_wrt_chosen_x_coord = loss_hessian_wrt_chosen_xi_plus + loss_hessian_wrt_chosen_xi_minus
#             # loss_hessian_wrt_chosen_x_coord = sampled_queries_q/num_points # linear queries

            
#             ### Backtracking Line Search Sub-routine ###
#             # Backtracking line search 
#             # initialize a step size, constants alpha1 and alpha2
#             t = 1
#             alpha1 = 0.2 # usually 0 < alpha1 < 0.5
#             alpha2 = 0.5 # usually 0 < alpha2 < 1

#             # initialize AG_condition = 0
#             AG_condition = 0

#             # make a copy of the curent fake_X
#             fake_X_copy_linesearch = copy.copy(fake_X)

#             while AG_condition == 0: 

#                 # calculate f(x+t*Delta x)
#                 fake_X_copy_linesearch[x_coord_descent] = xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
#                 # update fake_output_q 
#                 sum_fake_X_squared_linesearch = np.sum(np.square(fake_X_copy_linesearch))
#                 fake_output_q_linesearch = sampled_queries_q*sum_fake_X_squared_linesearch /num_points
#                 # fake_output_q_linesearch = sampled_queries_q*np.sum(fake_X_copy_linesearch) /num_points
#                 # loss_current_stepsize = np.sum(np.square(fake_output_q_linesearch-real_data_noisy_output_q))/Llambda
#                 loss_current_stepsize_plus = np.exp((fake_output_q_linesearch-real_data_noisy_output_q)/Llambda-1)
#                 loss_current_stepsize_minus = np.exp((real_data_noisy_output_q-fake_output_q_linesearch)/Llambda-1)
#                 loss_current_stepsize = loss_current_stepsize_plus + loss_current_stepsize_minus 

#                 print('loss_current', loss_current_stepsize)

#                 # calculate f(x)+alpha1*t*grad_f*Delta x
#                 loss_damped_stepsize = query_loss + alpha1*t*query_loss_gradient[x_coord_descent]*(- query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord)
#                 print('loss_dampened', loss_damped_stepsize)
                
#                 # if loss_current_stepsize > loss_damped_stepsize or -1>xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord or xi - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord>1:
#                 if loss_current_stepsize > loss_damped_stepsize:
#                     t = t* alpha2
                    
                    
#                     print("t = ", t)

#                 else: 
#                     AG_condition = 1 
#                     print("t = ", t)
#             ############



#             # update fake_X at coordinate = x_coord_descent using 2nd order Newton's method 
#             xi_update = - t*query_loss_gradient[x_coord_descent]/loss_hessian_wrt_chosen_x_coord
#             fake_X[x_coord_descent] = xi + xi_update

#             if fake_X[x_coord_descent] <= -1 or fake_X[x_coord_descent] >= 1:
#                 x_coord_changed[x_coord_descent] = True 
                
#             # if xi+xi_update <= 1 and xi+xi_update >= -1:
#             #     fake_X[x_coord_descent] = xi + xi_update
#             # # if the proposed update will overshoot, we skip this coordinate 
#             # else:
#             #     x_coord_changed[x_coord_descent] = True
            

#             # update fake_output
#             sum_fake_X_squared = np.sum(np.square(fake_X))
#             fake_output = sampled_queries*sum_fake_X_squared /num_points # quadratic query 
#             # fake_output_q = sampled_queries_q*np.sum(fake_X)/num_points # linear query


#             # update error
#             error = abs(fake_output-real_data_noisy_output)

#             # update total loss
#             total_loss_plus = np.sum(np.exp((fake_output-real_data_noisy_output)/Llambda-1))
#             total_loss_minus = np.sum(np.exp((real_data_noisy_output-fake_output)/Llambda-1))
#             total_loss = total_loss_plus + total_loss_minus 

#             # update query loss
#             query_loss_plus = np.exp((fake_output_q-real_data_noisy_output_q)/Llambda-1)
#             query_loss_minus = np.exp((real_data_noisy_output_q-fake_output_q)/Llambda-1)
#             query_loss = query_loss_plus + query_loss_minus

#             num_iter_q = num_iter_q + 1 
#             print(f"current_q={current_q},#iter_q={num_iter_q}, x_co={x_coord_descent}, query_loss={query_loss}, total_loss={total_loss}")

#         current_q = current_q + 1 
#     # print current progress
#     # print(f"#iter {num_iter_descent} x_co={x_coord_descent}, 1st={query_loss_gradient[x_coord_descent]}, 2nd={loss_hessian_wrt_chosen_x_coord}, # queries above err={sum(error>Llambda/2)}, xi={xi} fake x={fake_X[x_coord_descent]}")
#     # print('Total loss = ', total_loss)
    
#     num_iter_descent += 1
